# %% [markdown]
# # Product Insight Validation Using LLMs: Business Goals🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies and prompts for validating Business Goals using a Large Language Model (LLM). The goal is to have a sandbox where we can fine-tune prompts using the same cross validation sets.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing business goals for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key

# %% [markdown]
# # 1 - Load Business Goals
#
# Let's take a glimpse at the data we have. All these business goals have been validated by human validators during the month of April '25
#
# These datasets will act as makeshift cross-validation sets, that we can use to test the performance of different prompting strategies and approaches.
#
#
# We have two datasets:
#
# - A small set of 20 cases ( 10 valid, 10 invalids ) for quick experimentation
# - A bigger set of 200 cases ( 100 valid, 100 invalids ) for testing and measuring results

# %%
# We load all the data 

business_goals_20 = pd.read_csv('./cases/business_goals_cv20.csv')
business_goals_200 = pd.read_csv('./cases/business_goals_cv200.csv')

# Now let's print one of the datasets to see its shape

business_goals_20[:5]
# Out:
#       ID       Case Number                                 UPN  \
# 0  28380  2504040040013287  gig_wfh_ossal@microsoftsupport.com
# 1  26505  2504020030000826  gig_wfh_kuman@microsoftsupport.com
# 2  26155  2504030030000687  gig_wfh_jibal@microsoftsupport.com
# 3  27892  2503310040001537  gig_wfh_sirai@microsoftsupport.com
# 4  26026  2503270040000491  gig_wfh_jewan@microsoftsupport.com
#
#              Line Of Business  \
# 0   Business Advisor Reactive
# 1   Business Advisor Reactive
# 2   Business Advisor Reactive
# 3             Proactive Grace
# 4  Trials Nurturing Proactive
#
#                             Business Goals and Needs  \
# 0  Save time and money\nThe customer's business i...
# 1  After discussing it became clear that the cust...
# 2  Simplify everyday task\n\nThe business needs t...
# 3  The customer is a tech company offering web an...
# 4  Business offers a delightful range of homemade...
#
#    Business Goal Validation                    Business Goal Comment
# 0                         1                             BG is clear.
# 1                         1      It details the need of the customer
# 2                         1  Valid: Business goals is clearly stated
# 3                         1                                    Valid
# 4                         1                             BG is clear.

# %%
# Column explanation
data = [
    ["Business Goals and Needs", "Raw Business Goals and Needs captured by the ambassador as they figure in the tracker"],
    ["Business Goal Validation", "Validation done by a human validator - 0 is invalid, 1 is valid"],
    ["Business Goal comment", "Comment/Explanation provided by a human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                 Column Name  \
# 0  Business Goals and Needs
# 1  Business Goal Validation
# 2     Business Goal comment
#
#                                                                              Explanation
# 0  Raw Business Goals and Needs captured by the ambassador as they figure in the tracker
# 1                        Validation done by a human validator - 0 is invalid, 1 is valid
# 2                                      Comment/Explanation provided by a human validator

# %% [markdown]
# ## 1.1 Defining Performance
#
# These 2 datasets have already been evaluated by human validators.
#
# This means we can use the previous labels to calculate Sensitivity, Recall and F1 for this dataset, which will give us performance metrics we can analyse and optimise. We will be looking at the following metrics.
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$

# %% [markdown]
# We will create a dataframe where we will store the results of our tests as we run them.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])


test_results
# Out:
# Empty DataFrame
# Columns: [test_name, sensitivity, precision, f1_score]
# Index: []

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "This feedback highlights a usability issue, as the user is unable to effectively use the app due to the overcrowded and difficult-to-read menu interface."
# }
# ```

# %% [markdown]
# The model is giving us back a JSON wrapped in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "This feedback highlights a usability issue, as the user is unable to effectively use the app due to the overcrowded and difficult-to-read menu interface."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through the rows of one of our datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the entry
#     - 2. Evaluate if the LLM did a good job or not
#           - LLM => Valid, Human => Valid, then *true positive*
#           - LLM => Invalid, Human => Invalid, then *true negative*
#           - LLM => Valid, Human => Invalid, then *false positive*
#           - LLM => Invalid, Human => Valid, then *false negative*
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store, dataset):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for index, row in dataset.iterrows():
        # avoid token limit if needed every 10 rows 
        print(row_counter)
        if row_counter >= 10:
            print(f"Rate limit is close, continuing in {60} seconds...")
            time.sleep(61)
            row_counter = 0
                
        llm_res = send_prompt(prompt, row['Business Goals and Needs'])
        llm_res = clean_llm_response(llm_res)
        row_counter += 1
        print(row['Business Goals and Needs'],llm_res)

        try:
            llm_res = json.loads(llm_res)
        except json.JSONDecodeError as e:
            print(f"[WARN] Failed to parse LLM response as JSON: {e}")
            continue

        human_validation = row['Business Goal Validation']
        if llm_res['valid'] == True and human_validation == 1:
            tp += 1
        elif llm_res['valid'] == False and human_validation == 0:
            tn += 1
        elif llm_res['valid'] == True and human_validation == 0:
            fp += 1
        elif llm_res['valid'] == False and human_validation == 1:
            tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Loose Zero Shot Prompt
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe high level criteria that is frequently mentioned by human validators to mark insights as valid or invalid. These are drawn from analysing the reasons as to why validators mark insights as valid or invalid.

# %%
loose_zero_shot_prompt = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Set 1: Valid Business Goals Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Clarity: the entry mentions a business goal or need that is clear and easy to understand

    - B) Specificity: The entry should clearly refer to a specific, concrete business goal or need

    - C) Actionable: The entry should focus on the practical applicability of Microsoft 365 products to address the business need described

## Set 2: Invalid Business Goal Criteria

Meeting any of the criteria below is enough for the entry to be considered invalid.

    - D) Focus on tools: The entry just lists the M365 applications being used, but there is no business goal or need mentioned

    - E) Vague business goal or need: The entry does not include any details nor actionable business goals/needs

    - F) Technical issue: The entry only describes a technical issue experienced by the customer and there is no business goal or need

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
# Test Loose Zero Shot Prompt here 
test_results = analyse_test_prompt('loose_zero_shot_200', loose_zero_shot_prompt, test_results, business_goals_200)
# Out:
# 0
# Save time and money
# The customer's business imports and sells car parts from Europe to LATAM. Their goal is to implement a collaboration platform to enhance engagement and improve daily operations. {
#   "valid": true,
#   "reasoning": "The entry is valid because it satisfies all the criteria under Set 1: Valid Business Goals Criteria. It clearly mentions a business goal (importing and selling car parts from Europe to LATAM), is specific (the need for a collaboration platform to enhance engagement and improve operations), and is actionable by pointing to the implementation of such a platform through Microsoft 365 products."
# }
# 1
# After discussing it became clear that the customer aims to enhance efficiency in daily operations by establishing a generic email address connected to a centralized mailbox for their company. This setup would allow multiple users to access the mailbox simultaneously and receive notifications when customers send inquiries, thereby improving communication and enabling faster responses. {
#   "valid": true,
#   "reasoning": "The entry clearly mentions a business goal of enhancing efficiency in daily operations (Clarity). It specifies the need for a centralized email address and mailbox accessible by multiple users to improve communication and response times (Specificity). Additionally, it focuses on a practical, actionable application of Microsoft 365 tools, such as shared mailboxes, to achieve this goal (Actionable). Therefore, it meets all criteria of Set 1."
# }
# 2
# Simplify everyday task
#
# The business needs to utilize Microsoft Office desktop apps like Outlook, Word, and Excel to create detailed project documentation, manage budgets, and track progress efficiently. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria for Valid Business Goals: (A) Clarity, as it clearly mentions using Microsoft Office apps for project documentation, budget management, and progress tracking; (B) Specificity, as the specific tasks needed to address these business goals are detailed; (C) Actionable, as it focuses on practical use of Microsoft Office apps to achieve these goals."
# }
# 3
# The customer is a tech company offering web and app development services. They use Outlook for communication and MS Access for database management. Their business needs include finding a storage solution that can be used for sharing files efficiently and keep data secure. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1: Valid Business Goals Criteria. (A) Clarity: The business goal of finding a storage solution for efficient file sharing and data security is clear. (B) Specificity: The entry specifically describes a need for a storage solution. (C) Actionable: It focuses on the practical application of Microsoft 365 products, as this can be addressed through solutions like OneDrive or SharePoint. Therefore, the entry is considered valid."
# }
# 4
# Business offers a delightful range of homemade jams and jellies made from fresh, high-quality fruits. they mainly need Word for documents, excel for sales report and PPT for marketing poster   and OneDrive to backup data, they want to automate their order processing, inventory management, and  management  documents, like recipes and marketing posters in Realtime. it will enhance a quick way to handle orders and manage supplies and be able to update recipes and  manage marketing posters. {
#   "valid": true,
#   "reasoning": "The entry provides a clear and specific business goal focused on automating order processing and inventory management, as well as real-time document management for recipes and marketing posters. It is actionable, as it outlines how Microsoft 365 products will enable the business to improve efficiency, handle orders, and update materials effectively. This meets all criteria of Set 1: Valid Business Goals."
# }
# 5
# Connect email with Teams channels for smoother workflows. Enable employees to work from anywhere with synchronized email and Teams. {
#   "valid": true,
#   "reasoning": "The entry is valid as it satisfies all the criteria in Set 1. It mentions a clear and specific business goal (connecting email with Teams channels for smoother workflows and enabling employees to work from anywhere with synchronized email and Teams). It is actionable, as there is a direct application of Microsoft 365 products (Teams and email synchronization) to address the business need described."
# }
# 6
# CX runs a residential facility that provides care for individuals with chronic multiple substance abuse disorders. His main goal is to stay secure as he handles much sensitive data like patients' information. CX need to keep the data secure and protected against any unauthorized access.  {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the criteria for valid business goals. (A) Clarity: The business goal is clear and easy to understand, focusing on security and protection of sensitive data. (B) Specificity: The entry specifically mentions the need to secure and protect patients' information against unauthorized access. (C) Actionable: The goal is practical and provides a use case for Microsoft 365 products, such as implementing security features to safeguard sensitive data."
# }
# 7
# This university needs to utilize the Microsoft 365 platform for its students and faculty. By leveraging Microsoft 365, the institution aims to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities. {
#   "valid": true,
#   "reasoning": "The entry is valid under Set 1 criteria. It clearly mentions a business goal (enhancing collaboration, streamlining communication, and providing a robust digital environment for academic and administrative activities), is specific about the target audience (students and faculty), and emphasizes actionable outcomes through the utilization of Microsoft 365."
# }
# 8
# he customer's organization focuses on supporting women who have been victims of gender-based violence. Since the customer is a small non-profit business, she is looking to be 100% connected with her customers by updating them about their programs and meetings. Goal captured save time and money. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1 (Valid Business Goals Criteria). It mentions a clear and understandable business goal (Clarity), focuses on a specific and concrete need (connecting with their customers and updating them about programs and meetings, and saving time and money - Specificity), and discusses the practical applicability of Microsoft 365 tools in supporting those objectives (Actionable)."
# }
# 9
# Cx has a technology company specialized in manufacturing many types of electrical machines, like food industry machines and medical machines. Cx spends too much time in meetings with clients discussing the status of the orders and discussing the payment for the purchased machines. Cx needs a tool to store the catalogues of machines and share it with clients. {
#   "valid": true,
#   "reasoning": "The entry meets all the Valid Business Goals Criteria: A) It clearly states a business need to store and share catalogs of machines with clients, which is easy to understand. B) The business need is specific and refers to a concrete action—storing catalogs and sharing them with clients. C) The need is actionable, as Microsoft 365 products like SharePoint or OneDrive could address the issue described. It does not meet any of the Invalid Business Goal Criteria."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# To reconstruct the business cloud workspace for a law firm, ensuring sufficient storage for emails and documents, as other providers offer limited data storage. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets all criteria of Set 1: Valid Business Goals Criteria. The business goal to 'reconstruct the business cloud workspace for a law firm' is clear (A) and specific (B), as it focuses on addressing storage limitations for emails and documents compared to other providers. It is actionable (C) since Microsoft 365 products can be applied to achieve sufficient storage for the firm's needs."
# }
# 1
#
# During our conversation we recognized that the customer business goal is to be able to collaborate on daily tasks with his staff members in an easy way by sharing files online and grant them access to certain files. {
#   "valid": true,
#   "reasoning": "The entry is valid because: (A) It mentions a clear and understandable business goal of improving collaboration and file sharing. (B) It specifically identifies the goal of sharing files online and granting access to certain files within a team. (C) It is actionable since Microsoft 365 products, such as OneDrive or SharePoint, can be used to address this business need."
# }
# 2
# The customer's goal is to save time and reduce costs by activating a trial subscription to leverage the features of Microsoft 365. This will allow them to test its effectiveness in streamlining their operations, enhancing productivity, and ensuring a secure and reliable communication system for their business. {
#   "valid": true,
#   "reasoning": "The entry is valid because it satisfies the criteria set in Valid Business Goals Criteria. (A) It clearly mentions the business goals of saving time, reducing costs, and improving productivity. (B) It is specific and refers concretely to testing Microsoft 365 features to streamline operations, enhance productivity, and secure communication. (C) It is actionable as it focuses on leveraging MS365 features during a trial subscription to address clear business needs."
# }
# 3
# Cx provides an AI-powered Applicant Tracking System that simplifies resume analysis, improves job matching, and enhances candidate engagement. The platform delivers tailored interview questions and clear matching scores, empowering recruiters to make informed decisions. Cx is actively seeking to connect with a wider audience and engage more clients, showcasing the system's transformative potential to revolutionize hiring processes and build lasting partnerships. {
#   "valid": true,
#   "reasoning": "The entry explicitly describes a clear and actionable business goal of connecting with a wider audience and engaging more clients to showcase the transformative potential of their Applicant Tracking System. It provides specificity in discussing the product's features that enhance the hiring process and aligns this with the desired business outcomes, meeting Set 1 criteria A, B, and C."
# }
# 4
# 1-business industry: Event Management industry
#
# 2-daily tasks:
#
# Venue Selection:
# Vendor Management:
# Budgeting: .
# Scheduling:
# Financial Reconciliation:
# Reporting:
#
# 3- detect business need
#
# Cst needs a tool helps in organizing tasks into buckets, assigning tasks to team members, and tracking progress. {
#   "valid": true,
#   "reasoning": "The entry is valid because it clearly states a specific and actionable business need: a tool to help organize tasks into buckets, assign tasks to team members, and track progress. This satisfies Criteria A (Clarity), Criteria B (Specificity), and Criteria C (Actionable) of the Valid Business Goals Criteria."
# }
# 5
# The customer runs her healthcare agency. She uses Outlook for sending emails. She needs a solution to build health agents for patients. By embracing this new approach, they can build effective health agents for patients, leading to improved operational efficiency and patient care. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets the 'Valid Business Goals Criteria.' It provides clarity about a business goal (building health agents for patients), specificity (focus on improving operational efficiency and patient care by building health agents), and actionable potential (a solution leveraging Microsoft 365 products can address this goal effectively)."
# }
# 6
# Customer run a small booking keeping business which provide financial record-keeping services to his clients, as well as other small businesses, and individuals. Customer hope to be able to reach his business clients and other individual through email communications. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the 'Valid Business Goals Criteria': (A) Clarity: The business goal of reaching clients through email communication is clearly understood, (B) Specificity: It is specific to the context of a bookkeeping business aiming to communicate with clients and individuals, and (C) Actionable: Microsoft 365 products like Outlook and Exchange can be used to support email communications."
# }
# 7
# [Business Goal] The customer's business is physiotherapy clinic, where maintaining security and efficiency in daily operations is crucial. To address their need to stay secure and simplify everyday tasks, customer chose to implement email encryption enhance email security and reduce spam, ensuring secure communication.
#
# value added:
# The customer runs a physiotherapy clinic, where secure communication and efficient data management are critical. Observing their challenges with spam emails and disorganized file handling, I recommended email encryption along with DKIM and DMARC protocol setups to enhance email security. Also, I suggested implementing OneDrive and SharePoint synchronization for streamlined file management and collaboration and these solutions will minimize data breaches, improve workflows, and enable the clinic to focus on delivering exceptional patient care. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1: Valid Business Goals. A) Clarity: The business goals of managing security and improving operational efficiency in a physiotherapy clinic are clear and easy to understand. B) Specificity: The needs for email encryption and improved file handling are specific and concrete business goals. C) Actionable: The solution includes the implementation of Microsoft 365 tools like email encryption, OneDrive, SharePoint synchronization, and DKIM/DMARC to directly address these needs, showing practical applicability."
# }
# 8
# Customer runs a small health service that provides medical care for their patients within their environment. Customer would like to be able to reach different people regarding their medical services through email communication to boost their business reach. {
#   "valid": true,
#   "reasoning": "The entry clearly mentions a business goal related to improving communication and boosting business reach via email. It is clear, specific, and actionable as it aligns with leveraging Microsoft 365 tools for email communication to address a business need."
# }
# 9
# The client operates a manufacturing business specializing in locksmith products, safe technician tools, and access control installation solutions. With a custom domain in place, he leverages O365 applications and services to efficiently manage business operations, aiming to grow his business and build his brand in the market. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it lacks specificity and actionable details regarding the business goal (criteria B and C). While it mentions growing the business and building the brand, these goals are generic and do not specify a concrete, practical application of Microsoft 365 products to address this need. Additionally, the entry focuses on the use of O365 tools without a clear connection to a specific business need (criteria D)."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer's business goal is to enhance communication efficiency by implementing email templates in Outlook for quick and consistent replies. As a lawyer, she believes that this will allow her to save time by responding promptly to frequently asked questions and common client inquiries without sacrificing professionalism and ensure clarity, reduce repetitive tasks, and maintain a high level of client service.  {
#   "valid": true,
#   "reasoning": "The entry is valid because it satisfies all criteria in Set 1. (A) The business goal is clear: enhancing communication efficiency. (B) The goal is specific: implementing email templates in Outlook for quick and consistent replies tailored to frequently asked questions and client inquiries. (C) The entry focuses on how a Microsoft 365 application, Outlook, can be practically applied to achieve the described business goal, making it actionable."
# }
# 1
# The client aims to improve Microsoft apps and account usability by addressing mobile file access issues, simplifying admin portal navigation, and enhancing ease of use for multi-account devices. Their goal is to boost productivity, minimize downtime, and enhance user satisfaction. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets Set 1 criteria. It clearly states a business goal (improving app/account usability and enhancing productivity and user satisfaction), is specific (mentions mobile file access, admin portal navigation, and multi-account device usability), and is actionable (focuses on using Microsoft 365 products to address the described needs)."
# }
# 2
# Customer industry is human resources management, so he is looking for a solution that can help him enhance his productivity and reduce the recruitment time, by interviewing online and evaluate the CVs faster. {
#   "valid": true,
#   "reasoning": "The entry is valid under Set 1: Valid Business Goals Criteria. It meets all three criteria:
# - A) Clarity: The business goal of enhancing productivity and reducing recruitment time is clear and easy to understand.
# - B) Specificity: It specifically mentions the aims of interviewing online and faster CV evaluation, connected to human resources management.
# - C) Actionable: Microsoft 365 products can practically address these goals using tools like Teams for interviews and OneDrive/SharePoint for document management and CV evaluation."
# }
# [WARN] Failed to parse LLM response as JSON: Invalid control character at: line 3 column 109 (char 127)
# 3
# The customer who is starting a consultancy business aims to set up her business email and migrate to Microsoft 365. She is looking for an efficient want to manage her emails and work with different clients effectively. {
#   "valid": true,
#   "reasoning": "The entry is valid because it clearly mentions a business goal or need that is understandable (Clarity), refers to a specific and concrete business goal of email setup and migration for a consultancy business (Specificity), and focuses on the practical applicability of Microsoft 365 to manage emails and workflow effectively (Actionable)."
# }
# 4
# Build brand, stay secure and engage with customers.
# as customer is a new customer to M365 he is aiming for keeping his data secure with MS and to be able to build his brand through branding his emails and communications and appearance and finally to be able to engage with his customers and to be interactive with them. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria from Set 1. (A) Clarity: It clearly outlines the business goals of building a brand, staying secure, and engaging with customers. (B) Specificity: It refers to specific goals such as branding emails, communications, and being interactive with customers, as well as ensuring data security. (C) Actionable: The goals are practically applicable via Microsoft 365 products, like brand-related tools for emails, security features for keeping data safe, and communication tools for customer engagement."
# }
# 5
# The AI and machine learning business aims to leverage Microsoft Office applications such as Word, Excel, PowerPoint, and Outlook to enhance their operational efficiency and productivity. {
#   "valid": false,
#   "reasoning": "The entry does not mention a specific, actionable business goal or need (violates criterion B under Set 1). It is focused on tools without detailing how they address a clear business objective or operational issue (violates criterion D under Set 2)."
# }
# 6
# The customer, a business accounting firm, specializes in tailored solutions for small and medium-sized enterprises, including bookkeeping, compliance, tax planning, business advisory, and financial management. Their main goal is to streamline accounting processes, enabling business owners to focus on growth. They seek the best features to manage tasks and explore automation for frequent meetings, extensive data analysis, and effective tracking of all activities. {
#   "valid": true,
#   "reasoning": "The entry clearly outlines the business goal of streamlining accounting processes, which is clear and easy to understand (Criterion A: Clarity). It is specific in focusing on automation for frequent meetings, data analysis, and tracking activities related to accounting (Criterion B: Specificity). Moreover, it seeks actionable insights into using Microsoft 365 features to manage tasks, indicating practical applicability of the tools to address the business need (Criterion C: Actionable). It does not meet any of the invalid criteria."
# }
# 7
# Cx is learning institution, and they are currently using outlook for communication, word for document management and excel. They require a collaboration platform that integrates seamlessly with other M365 tools. They want a tool that will enable them to conduct classes online and enhance learning in the institution. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria outlined in Set 1 for Valid Business Goals Criteria. It clearly mentions a business goal or need (a collaboration platform for conducting classes online and enhancing learning). The goal is specific and concrete as it refers to the seamless integration with M365 tools and online class facilitation. Additionally, it is actionable by focusing on practical applicability of M365 tools in addressing the mentioned needs."
# }
# 8
# The customer operates a financial advisory firm and seeks to leverage on Microsoft to improve collaboration with clients on various files and documents. Goal aligns with simplify tasks {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the criteria in Set 1: (A) The business goal of improving collaboration with clients on files and documents is clear and easy to understand, (B) it is specific to a financial advisory firm's need to improve client collaboration, and (C) it is actionable, as Microsoft 365 products like SharePoint or OneDrive can be practically implemented to simplify tasks and address the need."
# }
# 9
# [Business Goal] The customer's business is the American Federation of Employee Local Union, where safeguarding communication and maintaining secure email exchanges are critical. therefore, customer chose stay secure.
#
# Value added:  The customer operates in the American Federation of Employee Local Union, where secure communication and email protection are essential and the need to safeguard sensitive information, I recommended email encryption along with DKIM and DMARC protocols.  ensure secure email exchanges, authenticate emails to prevent phishing, and reduce junk emails appearing to come from their domain, the customer can enhance email security, protect their organization, and maintain trust in their communications. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria under Set 1: Valid Business Goals Criteria. It presents a clear and easy-to-understand business need (safeguarding communication and maintaining secure email exchanges). It is specific in detailing the challenges related to secure communication (phishing, junk emails, etc.) and the suggested solution (email encryption, DKIM, and DMARC protocols). The entry is also actionable as it directly ties the use of Microsoft 365 features to address these security needs."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The cx is running an interior design firm specializing in bold, functional, and visually striking designs for commercial and residential spaces. They need Microsoft 365 to streamline communication, improve project collaboration, and organize their workflow efficiently. They want to be able to coordinate seamlessly with clients and contractors, get easy access to design files and proposals, track budgets and timelines, ensuring projects stay on schedule. This will help boost productivity, maintain structured workflows, and enhance client interactions, ultimately leading to better project execution and business growth. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all criteria under Set 1 for Valid Business Goals Criteria. (A) Clarity: The entry clearly outlines the business goals and needs for streamlining communication, improving project collaboration, organizing workflow efficiently, coordinating with clients and contractors, managing files and proposals, tracking budgets and timelines. (B) Specificity: It is specific about the concrete business goals such as enhancing productivity, maintaining structured workflows, and boosting client interactions. (C) Actionable: The entry focuses on the practical applicability of Microsoft 365 products to achieve these goals, making it actionable."
# }
# 1
# An upcoming nonprofit focused on health initiatives, access to food, shelter, education, and poverty alleviation. They will use OneDrive, Exchange Online, and Office suites for operations. They need a method to gather community information and create questionnaires to better understand and meet community needs. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria of Set 1. It is clear and easy to understand (Clarity), specifies a concrete business goal related to gathering and understanding community needs (Specificity), and focuses on how Microsoft 365 products can support the creation of questionnaires and gathering data for community initiatives (Actionable)."
# }
# 2
# As part of the company's business goals, they have subscribed to Copilot Studio to develop multiple agents aimed at automating routine processes. Currently, they are focusing on creating an agent for the HR department to handle vacation requests and assist with the onboarding process for new hires. This initiative aims to enhance both experiences while saving time, ultimately increasing overall productivity and employee satisfaction. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1 (Valid Business Goals Criteria). A) Clarity: The business goal of automating routine processes for HR is clear and easy to understand. B) Specificity: The entry describes a specific goal of creating an agent to handle vacation requests and assist with onboarding in the HR department. C) Actionable: It focuses on using Copilot Studio, a Microsoft 365 product, to achieve the stated business goal, making it practical and actionable."
# }
# 3
# business goal identified as save time and money. As the customer runs a startup company, it is important to minimize expenses and reduce costs as much as possible.  {
#   "valid": true,
#   "reasoning": "The entry meets the Valid Business Goals Criteria. It is clear and easy to understand (Clarity), specifies a concrete business goal of saving time and money for a startup (Specificity), and is actionable as Microsoft 365 products can be applied to help minimize expenses and reduce costs (Actionable)."
# }
# 4
# as per our call we recognized customers need is that Customer wanted to have a personalized email address using it for communication with his clients {
#   "valid": true,
#   "reasoning": "The entry mentions a clear and specific business goal (Clarity and Specificity criteria met) - wanting a personalized email address for communication with clients. Additionally, this is actionable as Microsoft 365 products such as Outlook or custom domain integration could address this business need (Actionable criteria met)."
# }
# 5
# The customer is a civil engineer aiming to enhance team collaboration by using a shared mailbox to manage client inquiries and follow-ups, aligning with the goal to Engage with customers and simplify tasks. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all criteria under Set 1 for Valid Business Goals. It is clear (A), describing the need to enhance team collaboration and manage client inquiries and follow-ups. It is specific (B), as it refers to the use of a shared mailbox for this purpose. It is actionable (C), focusing on the practical applicability of Microsoft 365 to address the described business goal of engaging with customers and simplifying tasks."
# }
# 6
# [Business Goal]The customer business is in the charter school finance and non-profit sector, emphasizing effective fund utilization and financial sustainability. Identifying the importance of data protection, the customer chose stay secure.
#
# value added: The customer business is in the charter school finance and non-profit sector, focusing on effective fund utilization and financial sustainability. Observing the need to protect sensitive financial data and ensure secure communication, I recommended enhanced security measures. I offered email encryption and data protection solutions to safeguard their critical information. These tools help the customer maintain compliance, protect client trust, and ensure the secure management of financial resources, supporting their mission and operational goals effectively. {
#   "valid": true,
#   "reasoning": "The entry clearly mentions a business goal related to financial sustainability and data protection, making it satisfy clarity (A). The goal is specific, as it focuses on protecting sensitive financial data and ensuring secure communication in the charter school finance and non-profit sector, satisfying specificity (B). Furthermore, the entry emphasizes actionable Microsoft 365 solutions like email encryption and data protection to address the business needs, satisfying actionability (C)."
# }
# 7
# The customer operates an e-commerce store, selling a wide range of products online. With a growing catalog and an increasing number of customers, it is crucial to manage inventory, fulfill orders quickly, and keep track of customer inquiries. Without an efficient system, delays in order processing, miscommunication, and poor customer support can negatively impact the business and its reputation. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets all the criteria for Valid Business Goals. It clearly identifies the business goals (managing inventory, fulfilling orders quickly, and keeping track of customer inquiries), is specific in describing the business challenges (delays, miscommunication, and poor customer support), and the need for an efficient system implies the applicability of solutions like Microsoft 365 to address these goals."
# }
# 8
# The customer, owner of a law firm, requires a comprehensive solution for efficient file saving and sharing to enhance collaboration and productivity. Currently, he saves all his documents and contracts from clients on an external storage HD, which is not as efficient as having them in a single online location. The identified business goal is to save time and money. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all criteria under the Valid Business Goals Criteria: (A) Clarity - The business goal, enhancing collaboration and productivity, is clear. (B) Specificity - The entry discusses a specific need for efficient file saving and sharing for a law firm. (C) Actionable - The described goal is practical and relevant to Microsoft 365 products, such as OneDrive or SharePoint, which can address the stated needs of online file storage and collaboration."
# }
# 9
#  Customer  have a training and consulting business, and you aim to use the office apps to complete your task of drafting document and preparing for presentations. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it primarily focuses on the tools (Office apps) without clearly mentioning a specific business goal or need (violating criterion D). While it mentions drafting documents and preparing presentations, these tasks are not described in the context of a clear and actionable business goal. Therefore, the entry lacks clarity and specificity (violating criteria A and B)."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Being a consultant, their clients are individuals seeking a safe and affirming space to navigate mental health challenges, relationships, and self-discovery. They aim to support their well-being and empower them by offering personalized and efficient services, to enhance client engagement and satisfaction. Additionally, they focus on streamlining administrative tasks and integrating various tools to reduce manual effort and improve overall efficiency. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets all the Set 1 criteria for Valid Business Goals. It mentions a clear and understandable business goal (supporting client well-being and empowering them), specifics of the business goals (enhancing client engagement, satisfaction, and streamlining administrative tasks), and the focus on actionable objectives (reducing manual effort and improving efficiency through integration of tools aligns with practical application of solutions like Microsoft 365)."
# }
# 1
# The customer runs a metal recycling business, providing services like metal collection and processing. They use Word for drafting letters and Excel for tracking metals and scrap collections. They need a solution with custom domain professional emails and tools for collaboration and document management. Implementing this solution will enhance their communication, streamline operations, and boost efficiency, leading to better overall business performance. {
#   "valid": true,
#   "reasoning": "The entry meets Set 1 criteria as it outlines a clear business goal (enhancing communication, streamlining operations, and boosting efficiency for better performance), is specific (custom domain professional emails, tools for collaboration and document management), and actionable by implementing Microsoft 365 solutions. There is no focus solely on tools nor any vague or irrelevant business goal mentioned."
# }
# 2
# Customer is from the education sector and is a school student. School students primarily focus on learning and completing academic tasks, which fall under the education business category. Their most important business goal is to achieve academic success, which includes understanding and retaining knowledge, completing assignments efficiently, and collaborating with peers and teachers. {
#   "valid": true,
#   "reasoning": "The entry is valid based on Set 1 criteria. It clearly mentions the business goal (academic success), is specific (understanding and retaining knowledge, completing assignments efficiently, collaborating), and is actionable as Microsoft 365 products can support these goals (e.g., through tools like Teams for collaboration, OneNote for knowledge retention, etc.)."
# }
# 3
# The customer aims to enhance document management by using OneDrive for easier access and file sharing. By implementing OneDrive, they aim to achieve faster document retrieval and improved file sharing efficiency. This addresses the need for a centralized, secure platform for managing business documents, ultimately boosting productivity. {
#   "valid": true,
#   "reasoning": "The entry satisfies all the criteria for Valid Business Goals: it has clarity (the goal is to enhance document management), specificity (focused on using OneDrive for faster document retrieval and file sharing efficiency), and it's actionable (it identifies how Microsoft 365 products, specifically OneDrive, can address the business need of centralized document management and boosting productivity)."
# }
# 4
# The customer operates in the content marketing sector, providing tailored marketing solutions to clients from diverse industries. requires a robust communication system. This system will facilitate clear, consistent, and efficient interactions, enabling the customer to better understand client needs, deliver timely updates, and maintain strong relationships. By implementing this system, the customer aims to enhance overall client satisfaction and improve the efficiency of their content marketing services. {
#   "valid": true,
#   "reasoning": "The entry is valid as it clearly outlines a business goal or need related to the creation of a robust communication system (Clarity: A). It specifies that the system is intended for facilitating clear, consistent, and efficient interactions to better understand client needs and deliver updates (Specificity: B). Furthermore, the business need is actionable as Microsoft 365 products could practically address this requirement, such as using Teams for communication or Outlook for scheduling (Actionable: C)."
# }
# 5
# Customer's organization provides comprehensive and gentle dental care to help patients. Their goal is to protect their business from security threats and hackers to avoid more account hacks. They want to put strong security measures in place to keep their data safe and ensure their operations remain secure. {
#   "valid": true,
#   "reasoning": "The entry is valid because it satisfies all the criteria for Valid Business Goals. The business goal is clear (protect the business from security threats and hackers), specific (placing strong security measures and preventing account hacks), and actionable (security measures can directly relate to Microsoft 365 security features)."
# }
# 6
# I learned that the customer works as an accountant, providing both accounting and consultancy services and requires a exchange email to effectively communicate with her clients and manage business correspondence. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the criteria for Valid Business Goals. (A) Clarity: The need for effective communication and business correspondence is clear and easy to understand. (B) Specificity: The entry specifically mentions the need for an Exchange email to facilitate client communication. (C) Actionable: The reference to Exchange email indicates a practical application of Microsoft 365 to meet the business need."
# }
# 7
# As a consultant, customer focuses on helping individuals secure houses and land below market value, particularly in key growth areas. They use advanced mortgage reduction strategies to achieve this. To engage their clients effectively, they aim to simplify document management, providing a clear and broader perspective and to accommodate all their clients' important files and documents. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets the criteria for clarity, specificity, and actionability. It clearly outlines the business goal of simplifying document management to better engage clients in their real estate services (Clarity and Specificity). Furthermore, it implies a practical use for Microsoft 365 products, such as improving document handling and providing broader access, which makes it actionable."
# }
# 8
# CX runs a marketing agency that specializes in strategic and authentic communication. BG captured as simplify daily tasks as the CX want to have an option to access and edit his business files using his smart phone.  {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1: Valid Business Goals Criteria. (A) Clarity: The business goal is clear—to simplify daily tasks by accessing and editing business files using a smartphone; (B) Specificity: It refers to a specific need related to mobile file management; (C) Actionable: The goal is actionable as it can be addressed with the practical use of Microsoft 365 tools like OneDrive and mobile Office applications."
# }
# 9
# While discussing with customer, I realized the need to implement a general mailbox that can be accessed by all front-end staffs to send emails in response to customers queries with the impact of streamlining email management and reduce response times for customers emails. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria from Set 1 for a valid business goal. It mentions a clear and specific business goal (implement a general mailbox for front-end staff to respond to customer queries). The goal is actionable as it directly ties into the practical application of Microsoft 365 products, such as shared mailboxes in Outlook, to streamline communication and reduce response times."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# - The customer offers contract consulting services and aims to streamline daily tasks by utilizing OneDrive for storing all client data. This efficient data-sharing solution will enhance the customer experience for his clients.
#  {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all criteria in Set 1. (A) Clarity: The business goal of streamlining daily tasks and enhancing customer experience is clear. (B) Specificity: It specifically refers to utilizing OneDrive for storing all client data and data sharing. (C) Actionable: It focuses on the practical applicability of using OneDrive to address the stated business need."
# }
# 1
# Customer is an agricultural company and primarily focus on crop production. They are seeking a method to improve their operations and increase crop production while maintaining the same workforce. {
#   "valid": true,
#   "reasoning": "The entry is valid based on the Valid Business Goals Criteria. It clearly describes the business goal (improving operations and increasing crop production) which is specific, actionable, and addresses the company's need for operational efficiency while maintaining the same workforce."
# }
# 2
# Build your brand
#
# The leadership development firm plans to create a business domain to strengthen their brand identity. This effort is anticipated to improve their professional image and ensure consistent branding in all communications. Consequently, the firm can present a cohesive and professional appearance to their clients and partners. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for valid business goals. It clearly mentions a business goal—strengthening brand identity (Clarity). The goal is specific as it refers to creating a business domain for consistent branding (Specificity). It is actionable as Microsoft 365 products like domain integration in email or SharePoint could be utilized to support this branding initiative (Actionable)."
# }
# 3
# Customer owns an edtech company and wanted to have a mailbox which can be used by multiple users, I recommended and helped setting up a shared mailbox. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets the Set 1 criteria: A) Clarity, as the business goal is to set up a mailbox usable by multiple users; B) Specificity, since the goal is clearly defined as creating a shared mailbox to address the need; and C) Actionable, as the solution involves applying Microsoft 365 tools (shared mailbox functionality) to meet the identified business goal."
# }
# 4
# cxr operates a communications advisory firm seeking a tool that can deliver value for their clients by enhancing their data analysis and reporting capabilities. Implementing such a solution will enable the firm to run more intelligent and effective campaigns, providing deeper insights and more accurate performance metrics. This will improve decision-making, optimize strategies, and ultimately increase client satisfaction and retention. {
#   "valid": true,
#   "reasoning": "The entry conforms to the Valid Business Goals Criteria. It mentions a clear and specific business goal of enhancing data analysis and reporting capabilities (clarity and specificity). Additionally, it focuses on the actionable implementation of a solution to improve decision-making, optimize strategies, and increase client satisfaction and retention, which are practical business needs (actionable)."
# }
# 5
# A health insurance company aims to enhance its operational efficiency and improve internal communication. They seek to centralize their communication and collaboration tools to streamline operations, ensure secure and easy access to critical information, and improve team collaboration. This transition will help reduce overhead and operational costs while boosting productivity and maintaining high standards of service. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the Valid Business Goals Criteria. It is clear and easy to understand (criteria A), specifies concrete business goals such as enhancing operational efficiency and improving internal communication (criteria B), and is actionable by describing the need to centralize communication and collaboration tools, which can be addressed practically using Microsoft 365 products (criteria C)."
# }
# 6
# Cx, who runs a business, needed a tool that will help them with online and remote storage of all their sensitive documents such as recipes, contact information, and order numbers securely on the cloud for access only by authorized personnel. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets Set 1: Valid Business Goals Criteria. It has clarity (A), as it clearly mentions the need for secure storage of sensitive business documents. The business goal is specific (B), referring to storing recipes, contact information, and order numbers. It is actionable (C) since Microsoft 365 products, like OneDrive or SharePoint, can address the described need for secure cloud storage accessible only to authorized personnel."
# }
# 7
#  The cx, operating in the agriculture sector, seeks a comprehensive solution to facilitate collaboration by integrating meetings, chat, and file management into a single platform. {
#   "valid": true,
#   "reasoning": "The entry is valid because it outlines a clear business need (facilitate collaboration), specifies the goal (integrating meetings, chat, and file management into a single platform), and focuses on the practical applicability of Microsoft 365 products to address this business need, meeting all criteria under Set 1."
# }
# 8
# The customer, a battery technology solutions firm, requires a tool that enables the creation of surveys, quizzes, and polls with ease. This tool will streamline the process of collecting valuable information and feedback from clients, employees, and partners, aiding in understanding customer needs, improving products, and enhancing overall service quality. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria from Set 1 for a valid business goal. It mentions a clear and understandable business need (A: Clarity), specifies the need for a tool to create surveys, quizzes, and polls (B: Specificity), and clearly outlines how the solution will be used to address business needs, such as collecting feedback to improve products and services (C: Actionable)."
# }
# 9
# The customer wants to set up their professional email within Microsoft 365 to improve client interaction. They also seek an efficient way to manage their emails, ensuring a seamless and effective communication experience. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals. It is clear (Criterion A), as it explicitly mentions the goal of setting up professional email and improving client interaction. It is specific (Criterion B), as it refers to a need for efficient email management to enhance communication. Additionally, it is actionable (Criterion C) because Microsoft 365 provides tools like Outlook and Exchange Online that are practical for achieving these goals."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# : Cx, who is in consultancy, needs a free tool for communication that can help her with online meetings, though infrequent, and also have messaging and file sharing capabilities to enhance communication. {
#   "valid": true,
# ...
# }
# 7
# - Marc Wallert, a distinguished keynote speaker and expert in resilience, seeks to engage with his audience via Microsoft Teams. His objective is to efficiently reach the maximum number of followers and fans.
#  {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria of Set 1. It has clarity (A), as the business goal of efficiently reaching the maximum number of followers and fans is clearly stated. It has specificity (B), since it elaborates on Marc Wallert's objective tied to his role as a keynote speaker and his use of Microsoft Teams. Lastly, it is actionable (C), as it specifies the practical applicability of Microsoft Teams in addressing the business need described."
# }
# 8
# The customer, who operates a law firm, heavily relies on Microsoft 365 Business Premium for external collaboration and file storage. Additionally, they require a license with fewer functionalities to assign to entry-level positions within the firm. {
#   "valid": true,
#   "reasoning": "The entry meets the criteria for Set 1: Valid Business Goals Criteria. It clearly mentions a business need (entry-level licenses with fewer functionalities), is specific about the firm's requirement for differentiated licensing, and is actionable as Microsoft 365 products can be utilized to address this need. It does not meet any of the criteria for Set 2: Invalid Business Goal Criteria."
# }
# 9
# The customer works in a small accounting office and needs to update calculation spreadsheets. They mentioned that they intend to use only one account for four employees due to financial constraints. {
#   "valid": false,
#   "reasoning": "The entry mentions the need to update calculation spreadsheets, but it does not provide clarity (criteria A), specificity (criteria B), or actionable business goals tied to Microsoft 365 products (criteria C). Furthermore, the mention of financial constraints and account sharing is a technical issue and does not describe a business goal or need (criteria F)."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer aims for his business to become a leading and popular entity in his region, primarily utilizing Microsoft Outlook.
#  {
#   "valid": false,
#   "reasoning": "The entry mentions a vague business goal of becoming a leading and popular entity in the region but lacks specificity and actionable elements. Additionally, the mention of Microsoft Outlook does not demonstrate practical applicability to address the business goal described. This violates criteria E (Vague business goal or need)."
# }
# 1
# This company is a residential letting agency and property management firm. They aim to simplify everyday tasks by staying organized using Outlook email, as they transition from another email provider to Microsoft 365. The goal captured is simplifying everyday task. {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets the criteria for valid business goals (Set 1). It is clear and understandable, as it states a business goal of simplifying everyday tasks. It is specific as it mentions the company aims to stay organized using Outlook email and transitioning from another email provider to Microsoft 365. It is actionable as it describes how the firm plans to use Microsoft 365 applications to achieve this goal."
# }
# 2
# Customer is an executive search and recruitment firm, specializing in finding top talent for businesses across industries. They help companies identify, assess, and place high-level professionals in leadership roles, ensuring the right fit for long-term success.  {
#   "valid": false,
#   "reasoning": "The entry does not specify any actionable business goal or need related to Microsoft 365 products (Criteria E). While it describes the nature of the customer’s business, it fails to mention a specific, clear, or actionable business goal (Criteria A, B, C)."
# }
# 3
# Customer's organization provides professional consulting solutions to help businesses improve operations and achieve their goals. Their goal is to save money by combining subscriptions from different accounts and managing them efficiently. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria of Set 1 for Valid Business Goals. It mentions a clear and understandable business goal (saving money by combining subscriptions from different accounts and managing them efficiently). The goal is specific and concrete, as it directly refers to subscription management and cost-saving measures. Additionally, it's actionable with practical applicability to Microsoft 365 products, which can assist in subscription and account management."
# }
# 4
# Customer made me understand that she is establishing a new company and need to build up the brand; by adding her business domain to her email address so he can have a customized emails address that has her domain in it, so that anyone email is sent to knows the email is coming from her company the keep the image of the company professional {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets all the criteria under Set 1: Valid Business Goals Criteria. It clearly specifies a business goal (building the brand for a new company) that is easy to understand (Clarity: A). It is specific in stating the need to add a business domain to the email address to create a customized and professional image (Specificity: B). The goal is actionable as it highlights a practical application of Microsoft 365 products, such as setting up customized email addresses (Actionable: C)."
# }
# 5
# I learned that the customer is providing counseling services, and she is actively using Microsoft Teams to schedule and conduct meetings with her clients. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it focuses on the tools being used (Microsoft Teams) without specifying a clear business goal or actionable need. This fails to meet the criteria for Set 1 as it lacks specificity and clarity. Additionally, the entry meets criterion D from Set 2, as the focus is simply on the tools being used rather than a business need."
# }
# 6
# Customer is a designing and manufacturing high-quality progressive, line, and transfer dies for the metal stamping industry, established in 1994, they serve sectors including automative, appliance, ATV, motorcycle, and aerospace, the company emphasizes delivering precision-engineered tools on time and at competitive prices, utilizing advanced CAD software and simulation technology to meet diverse manufacturing needs. {
#   "valid": false,
#   "reasoning": "The entry provides background information about the customer, including their industry, history, and focus areas, but it does not articulate a clear business goal or need (criterion E). Additionally, the description lacks actionable business goals related to Microsoft 365's practical application (criterion C)."
# }
# 7
# Aims to streamline real estate operations by automating data collection and analysis using Dynamics 365 Sales and Power BI for enhanced sales and customer insights. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1: Valid Business Goals Criteria. It clearly states a business goal (streamlining real estate operations), is specific (automation of data collection and analysis for enhanced sales and customer insights), and is actionable (mentions the use of Dynamics 365 Sales and Power BI to achieve the goal)."
# }
# 8
#  Customer runs a drywall business and wants to simplify the way the way their account is set up, that is they don't want to be opening all their Microsoft apps and their  daily applications that they use in managing their clients, which leads to recommending the teams have that have the ability to accept add-in and still do lots of tasks without having to leave the app  and be able  to manage all their  clients within and be able to use all the Microsoft applications and services  {
#   "valid": true,
#   "reasoning": "The entry specifies a clear and actionable business goal of simplifying account setup and workflow management for a drywall business. It outlines a specific need for integrating Microsoft 365 products (e.g., Teams with add-ins) to manage clients and daily tasks without switching between multiple applications. This satisfies the Clarity, Specificity, and Actionable criteria under the Valid Business Goals Criteria."
# }
# 9
# The customer operates a private business providing legal professional services. She was unfamiliar with managing users and license assignments in the Microsoft 365 admin center. This lack of knowledge was impacting her ability to efficiently utilize the platform for her business operations. {
#   "valid": true,
#   "reasoning": "The entry clearly mentions a business goal related to efficient utilization of the Microsoft 365 platform for business operations, which is easy to understand (Clarity) and refers to a specific need of managing users and license assignments (Specificity). It also points to a practical way Microsoft 365 tools can address the issue by improving platform usage (Actionable). Therefore, it meets all criteria under Set 1: Valid Business Goals Criteria."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# cx wanted to setup email communication for ease of contact with his clients. {
#   "valid": true,
#   "reasoning": "The entry meets the Valid Business Goals Criteria. It is clear (A) that the business goal is to improve email communication for client interactions, it is specific (B) as it outlines the objective of setting up email communication for ease of contact, and it is actionable (C) since Microsoft 365 products, such as Outlook or Exchange, can be directly applied to achieve this goal."
# }
# 1
# Customer operates an educational company that offers educational services and work training. Currently, they utilize Office apps like Outlook for email communication with participants. To enhance their operations, they will need to integrate Microsoft Teams and other Microsoft 365 services in the future. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it meets Criteria E (Vague business goal or need). While the customer mentions the use of Microsoft 365 tools like Outlook and plans to utilize Teams in the future, it does not define any specific, actionable business goal or need. There is no clear mention of how integrating Teams or other services would address a particular business requirement or enhance their operations."
# }
# 2
# The customer's goal is to simplify their tasks and complete their SharePoint migration efficiently by increasing storage capacity in their testing tenant, ensuring smooth data transfer and effective testing. {
#   "valid": true,
#   "reasoning": "The entry is valid because it mentions a clear business goal or need (simplifying tasks and completing SharePoint migration efficiently), is specific (focuses on storage capacity increase in testing tenant to ensure smooth data transfer and effective testing), and is actionable (Microsoft 365 products like SharePoint can practically address the described business need). It meets all the criteria under Set 1: Valid Business Goals Criteria."
# }
# 3
# The company specializes in marketing and lacks extensive experience in managing users within Microsoft 365. They need to understand how to efficiently assign licenses and update the domain for users to streamline their operations and ensure seamless collaboration. {
#   "valid": true,
#   "reasoning": "The entry is valid as it conforms to all the criteria under Set 1: Valid Business Goals Criteria. The business goal is clear and easy to understand (Clarity), it specifies the need to efficiently assign licenses and update the domain for users (Specificity), and it focuses on the practical applicability of Microsoft 365 products to streamline operations and ensure seamless collaboration (Actionable)."
# }
# 4
# Customer would like to get a refund for $72 and make sure that the Business Basic has been completely cancelled as this is impacting her financially. {
#   "valid": false,
#   "reasoning": "The entry does not mention any clear business goal or need related to Microsoft 365 products and their practical applicability (criteria A, B, and C are not met). Additionally, the focus is on requesting a refund and cancellation, which aligns more with a financial concern rather than a business goal."
# }
# 5
# According to the customer, their business goal is to simplify their daily tasks and operations to improve overall efficiency. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Set 1. It clearly mentions a business goal (clarity), specifies the business goal as simplifying daily tasks and operations to improve overall efficiency (specificity), and is actionable as it can involve leveraging Microsoft 365 products to achieve the goal of simplifying operations and improving efficiency."
# }
# 6
# The customer operates in the Electrical and Automation Solutions industry, offering services such as Industrial Panel Solutions and Motor Protection Systems. They primarily use Outlook and require solutions for desktop and mobile applications, as they are currently using the web version under the Business Basic plan. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it primarily focuses on the tools (Outlook and Business Basic plan) without clearly mentioning a specific and actionable business goal or need (criteria D). While the industry's context is mentioned, there is no clarity or specificity regarding the business challenges or needs related to Microsoft 365 beyond the mention of desktop and mobile applications. Thus, it also fails criteria B and C."
# }
# 7
# The customer selected all the business goals as important to her. She runs an outlet that sell smoothies and healthy drinks. Her business need is to use office Apps to connect with her customers while looking to optimize her budget.  {
#   "valid": false,
#   "reasoning": "The entry is invalid because it does not meet the Specificity criteria (B) of Set 1. While the entry mentions general business goals such as connecting with customers and optimizing the budget, it lacks specific, actionable details related to how Microsoft 365 products would concretely address these goals. It is overly vague and does not describe a clear or actionable business need, thus also meeting the criteria for E (Vague business goal or need) in Set 2."
# }
# 8
# Simplifying everyday tasks
#
# I learned that the customer is a nurse who owns a clinic. Their business needs include using Outlook for communicating with their clients and other Office applications to enhance business productivity. {
#   "valid": false,
#   "reasoning": "The entry does not meet requirements of Set 1. While it mentions some elements of productivity (e.g., 'simplifying everyday tasks' and 'enhance business productivity'), these goals are vague and lack specificity or clarity (violates criteria A and B). Additionally, it includes a focus on Microsoft 365 tools, such as Outlook, without tying them to a clear, actionable business need (violates criteria D and E)."
# }
# 9
# The customer aims to access a critical planner file within their tenant to enhance project management and data accessibility. This will reduce project delays and improve team coordination. The expected outcome is increase in project completion rates and less time spent searching for documents {
#   "valid": true,
#   "reasoning": "The entry meets all criteria for Set 1. It clearly articulates a business goal (enhancing project management and data accessibility while reducing delays and improving coordination), is specific regarding the intended outcome (increase in project completion rates and reduction in time spent searching for documents), and is actionable as it focuses on the practical use of Microsoft 365 tools (Planner)."
# }
# 1570.4623348712921

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.615385  0.761905
# 1  loose_zero_shot_20_no_negative_criteria          1.0   0.642857  0.782609
# 2                      loose_zero_shot_200          1.0   0.720000  0.837209

# %%
loose_zero_shot_no_negative_criteria = 
"""
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Valid Business Goals Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Clarity: the entry mentions a business goal or need that is clear and easy to understand

    - B) Specificity: The entry should clearly refer to a specific, concrete business goal or need

    - C) Actionable: The entry should focus on the practical applicability of Microsoft 365 products to address the business need described

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''


"""

# %%
test_results = analyse_test_prompt('loose_zero_shot_200_no_negative_criteria', loose_zero_shot_no_negative_criteria, test_results, business_goals_200)

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.615385  0.761905
# 1  loose_zero_shot_20_no_negative_criteria          1.0   0.642857  0.782609

# %% [markdown]
# ### 3.2 Detailed Zero Shot Prompt
#
# In the prompt below, we provide a detailed list of criteria based on the latest version of the insights framework available at GigPlus. This has a detailed set of tiered criteria.

# %%
loose_detailed_zero_shot_prompt = '''
You are an AI assistant that validates entries based on specific criteria. 

## PROMPT MISSING ##

## Response ##

You will respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''

You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Set 1: Product Feedback and Limitations Criteria

Meeting criteria A) and B) is a must have for the entry to be considered valid

    - A) Actionability: the entry mentions product feedback, limitations that are specific, actionable and valuable for a product team.

    - B) Specificity: The entry should clearly refer to a specific product feature or a product limitation
    
Meeting at least one of the following criteria C), D) and E) is enough to check the entry as valid

    - C) Support of Objectives: The entry should explain how the feedback aligns customer business objectives or business case, regardless of whether the feedback is positive or negative. 

    - D) Impact on Customer Experience: The entry must explain how it impacts customer workflows, satisfaction, or any stage of the customer's experience
    
    - E) Positive Feedback: The entry provides positive feedback about a feature or aspect of the product

##Set 1 end##
      
##Set 2: Valid Deployment Blockers## 

Meeting any of the following criteria is enough to check the entry as valid

    - Technical Barriers: The entry contains concrete obstacles that prevents or limits the successful implementation, adoption, or performance of a technology, system or product.  

    - Organizational Readiness: The entry refers to a shortage of trained personnel or expertise to adopt, implement or maintain a the product.

    - Compatibility:  The entry explains clearly how the product cannot be adopted or used due to lack of compatibility, outdated systems, or proprietary formats 

    - Support and Documentation: The entry explains how poor documentation prevents the deployment, adoption or use of the product 

    - Security and Compliance: The entry explains risks related to data protection, cybersecurity threats, or compliance with privacy laws that prevent deployment, adoption or use of the product.

## Set 2 end ## 

## Examples of valid Entries for Set 1 ## 

    - “The Product seems very hard to use, doing basic actions like managing the calendar requires many clicks and it's confusing.” – [ Valid, Meets Criteria A), B) and D) ]

    - “The Product is not able to perform scheduled updates, forcing the customer to do manual work and waste time” – [ Valid, Meets Criteria A), B) and C) ]

    - “The customer mentioned how happy he was with the new data visualization suite and the FabricView feature. It has really helped his team make better decisions” – [ Valid, Meets Criteria A), B) and E) ]

    - “The customer was frustrated because the product is unstable when running alongside another application” – [ Valid - Meets criteria A) and B) and D) ]

## Examples of valid Entries for Set 1 end ##

## Examples of invalid Entries for Set 1 ## 

    - “The Product seems slow sometimes.” – [ Invalid - Does not meet criteria A) and B) ]

    - “The customer does not like the product, he prefers the older version. Also thinks the competition is better” – [ Invalid - Does not meet criteria A) and B) ]

    - “We heard from another company that they had issues with the product.” – [ Invalid, Does not meet criteria A) and B) ]  

    - “We really love the product, the new functionalities are really cool and helps us make more money which is what we want” – [ Invalid, Does not meet criteria A) and B) even though meets C) and E) ] 

    - “We need time to adjust to new workflows.” - [ Invalid, Does not meet criteria A) and B) ]

    - "Product is a bit expensive, should rethink the price point" - [ Invalid, Does not meet criteria A) and B) ]

## Examples of invalid Entries for Set 1 end ##

## Examples of valid Entries for Set 2 ## 

    - “The customer raised a concern about the lack of multi-tenancy support. They need a way to manage multiple teams and departments separately within the product.” – [ Valid, Technical Barrier ]

    - “The customer said that while they see the value in our solution, they can't deploy because their team would need extensive training to use it effectively.” – [ Valid, Organizational Readiness ]

    - “he customer mentioned that they were excited to deploy the product, but they discovered it's not compatible with their existing infrastructure. Their systems run on Linux, while the software only supports Windows, making it impossible for them to implement” – [ Valid, Compatibility ]

    - “The customer said that when they encountered an issue, they couldn’t find sufficient troubleshooting guides or FAQs to resolve it on their own, making them overly reliant on support.” – [ Valid, Support and Documentation ]

    - "The product only provides US-based data hosting but the customer requires GDPR, so legally they cannot use it." - [Valid, Security and Compliance]

## Examples of valid Entries for Set 2 end ##

## Examples of invalid Entries for Set 2 ## 

    - “Our office is moving next month, so we can’t focus on deployment right now.” – [ Invalid, Does not meet any of the criteria ]

    - “The system doesn't seem to work as expected in our environment.” – [ Invalid, Does not meet any of the criteria ]

    - “The customer mentioned that they are facing some challenges with the new system.” – [ Invalid, Does not meet any of the criteria ]

    - “The customer said that they are not sure how to proceed with the migration.” – [ Invalid, Does not meet any of the criteria ]

    - "They have concerns about security that need to be cleared before they proceed with the deployment" - [Invalid, Does not meet any of the criteria]

## Examples of valid Entries for Set 2 end ##

Meeting the criteria of one of the sets is enough to consider an entry as valid. You must emit a final single judgement 

## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('few shot', few_shot_prompt, test_results)

print(test_results)

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store, true_positives, true_negatives, false_positives, false_negatives):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                try:
                    llm_res = json.loads(llm_res)
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON: {e}, moving to next case")  # Log the error
                    next
                    
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
# print test results store
