# %% [markdown]
# # Product Insight Validation Using LLMs: Business Goals🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies and prompts for validating Business Goals using a Large Language Model (LLM). The goal is to have a sandbox where we can fine-tune prompts using the same cross validation sets.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing business goals for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key

# %% [markdown]
# # 1 - Load Business Goals
#
# Let's take a glimpse at the data we have. All these business goals have been validated by human validators during the month of April '25
#
# These datasets will act as makeshift cross-validation sets, that we can use to test the performance of different prompting strategies and approaches.
#
#
# We have two datasets:
#
# - A small set of 20 cases ( 10 valid, 10 invalids ) for quick experimentation
# - A bigger set of 200 cases ( 100 valid, 100 invalids ) for testing and measuring results

# %%
# We load all the data 

business_goals_20 = pd.read_csv('./cases/business_goals_cv20.csv')
business_goals_200 = pd.read_csv('./cases/business_goals_cv200.csv')

# Now let's print one of the datasets to see its shape

business_goals_20[:5]
# Out:
#       ID       Case Number                                 UPN  \
# 0  28380  2504040040013287  gig_wfh_ossal@microsoftsupport.com
# 1  26505  2504020030000826  gig_wfh_kuman@microsoftsupport.com
# 2  26155  2504030030000687  gig_wfh_jibal@microsoftsupport.com
# 3  27892  2503310040001537  gig_wfh_sirai@microsoftsupport.com
# 4  26026  2503270040000491  gig_wfh_jewan@microsoftsupport.com
#
#              Line Of Business  \
# 0   Business Advisor Reactive
# 1   Business Advisor Reactive
# 2   Business Advisor Reactive
# 3             Proactive Grace
# 4  Trials Nurturing Proactive
#
#                             Business Goals and Needs  \
# 0  Save time and money\nThe customer's business i...
# 1  After discussing it became clear that the cust...
# 2  Simplify everyday task\n\nThe business needs t...
# 3  The customer is a tech company offering web an...
# 4  Business offers a delightful range of homemade...
#
#    Business Goal Validation                    Business Goal Comment
# 0                         1                             BG is clear.
# 1                         1      It details the need of the customer
# 2                         1  Valid: Business goals is clearly stated
# 3                         1                                    Valid
# 4                         1                             BG is clear.

# %%
# Column explanation
data = [
    ["Business Goals and Needs", "Raw Business Goals and Needs captured by the ambassador as they figure in the tracker"],
    ["Business Goal Validation", "Validation done by a human validator - 0 is invalid, 1 is valid"],
    ["Business Goal comment", "Comment/Explanation provided by a human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                 Column Name  \
# 0  Business Goals and Needs
# 1  Business Goal Validation
# 2     Business Goal comment
#
#                                                                              Explanation
# 0  Raw Business Goals and Needs captured by the ambassador as they figure in the tracker
# 1                        Validation done by a human validator - 0 is invalid, 1 is valid
# 2                                      Comment/Explanation provided by a human validator

# %% [markdown]
# ## 1.1 Defining Performance
#
# These 2 datasets have already been evaluated by human validators.
#
# This means we can use the previous labels to calculate Sensitivity, Recall and F1 for this dataset, which will give us performance metrics we can analyse and optimise. We will be looking at the following metrics.
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$

# %% [markdown]
# We will create a dataframe where we will store the results of our tests as we run them.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])


test_results
# Out:
# Empty DataFrame
# Columns: [test_name, sensitivity, precision, f1_score]
# Index: []

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue related to the app's menu design being convoluted and difficult to navigate, which impacts the user's ability to use the app effectively."
# }
# ```

# %% [markdown]
# The model is giving us back a JSON wrapped in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue related to the app's menu design being convoluted and difficult to navigate, which impacts the user's ability to use the app effectively."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through the rows of one of our datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the entry
#     - 2. Evaluate if the LLM did a good job or not
#           - LLM => Valid, Human => Valid, then *true positive*
#           - LLM => Invalid, Human => Invalid, then *true negative*
#           - LLM => Valid, Human => Invalid, then *false positive*
#           - LLM => Invalid, Human => Valid, then *false negative*
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store, dataset):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for index, row in dataset.iterrows():
        # avoid token limit if needed every 10 rows 
        print(row_counter)
        if row_counter >= 10:
            print(f"Rate limit is close, continuing in {60} seconds...")
            time.sleep(61)
            row_counter = 0
                
        llm_res = send_prompt(prompt, row['Business Goals and Needs'])
        llm_res = clean_llm_response(llm_res)
        row_counter += 1
        print(row['Business Goals and Needs'],llm_res)

        try:
            llm_res = json.loads(llm_res)
        except json.JSONDecodeError as e:
            print(f"[WARN] Failed to parse LLM response as JSON: {e}")
            continue

        human_validation = row['Business Goal Validation']
        if llm_res['valid'] == True and human_validation == 1:
            tp += 1
        elif llm_res['valid'] == False and human_validation == 0:
            tn += 1
        elif llm_res['valid'] == True and human_validation == 0:
            fp += 1
        elif llm_res['valid'] == False and human_validation == 1:
            fn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Loose Zero Shot Prompt
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe high level criteria that is frequently mentioned by human validators to mark insights as valid or invalid. These are drawn from analysing the reasons as to why validators mark insights as valid or invalid.

# %%
loose_zero_shot_prompt = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Set 1: Valid Business Goals Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Clarity: the entry mentions a business goal or need that is clear and easy to understand

    - B) Specificity: The entry should clearly refer to a specific, concrete business goal or need

    - C) Actionable: The entry should focus on the practical applicability of Microsoft 365 products to address the business need described

## Set 2: Invalid Business Goal Criteria

Meeting any of the criteria below is enough for the entry to be considered invalid.

    - D) Focus on tools: The entry just lists the M365 applications being used, but there is no business goal or need mentioned

    - E) Vague business goal or need: The entry does not include any details nor actionable business goals/needs

    - F) Technical issue: The entry only describes a technical issue experienced by the customer and there is no business goal or need

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
# Test Loose Zero Shot Prompt here 
# done - test_results = analyse_test_prompt('loose_zero_shot_20', loose_zero_shot_prompt, test_results, business_goals_20)
# done - test_results = analyse_test_prompt('loose_zero_shot_200', loose_zero_shot_prompt, test_results, business_goals_200)

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20     0.900000   0.642857  0.750000
# 1  loose_zero_shot_20_no_negative_criteria     0.777778   0.538462  0.636364
# 2                      loose_zero_shot_200     0.900000   0.638298  0.746888

# %%
loose_zero_shot_no_negative_criteria = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Valid Business Goals Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Clarity: the entry mentions a business goal or need that is clear and easy to understand

    - B) Specificity: The entry should clearly refer to a specific, concrete business goal or need

    - C) Actionable: The entry should focus on the practical applicability of Microsoft 365 products to address the business need described

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('loose_zero_shot_20_no_negative_criteria', loose_zero_shot_no_negative_criteria, test_results, business_goals_20)
# Out:
# 0
# Save time and money
# The customer's business imports and sells car parts from Europe to LATAM. Their goal is to implement a collaboration platform to enhance engagement and improve daily operations. {
#   "valid": true,
#   "reasoning": "The entry meets all the validity criteria. (A) It is clear and easy to understand, as it specifies the customer's goal of enhancing engagement and improving daily operations. (B) It is specific, as it identifies the business context—importing and selling car parts—and the goal to implement a collaboration platform. (C) It is actionable, as it focuses on leveraging a Microsoft 365 product (e.g., Teams or SharePoint) to address collaboration and operational improvements."
# }
# 1
# After discussing it became clear that the customer aims to enhance efficiency in daily operations by establishing a generic email address connected to a centralized mailbox for their company. This setup would allow multiple users to access the mailbox simultaneously and receive notifications when customers send inquiries, thereby improving communication and enabling faster responses. {
#   "valid": true,
#   "reasoning": "The entry satisfies the Valid Business Goals Criteria. It is clear and easy to understand (Clarity), as it mentions the goal of enhancing efficiency through centralized communication. It is specific (Specificity), as it talks about creating a shared mailbox with notifications for customer inquiries. It is actionable (Actionable), as it directly connects the business goal to the practical use of Microsoft 365 products, such as setting up a shared mailbox configuration."
# }
# 2
# Simplify everyday task
#
# The business needs to utilize Microsoft Office desktop apps like Outlook, Word, and Excel to create detailed project documentation, manage budgets, and track progress efficiently. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for valid business goals. It is clear (A) as it outlines the need to create detailed project documentation, manage budgets, and track progress. It is specific (B) since it mentions specific tools (Outlook, Word, Excel) and their intended use cases. It is actionable (C) as it identifies Microsoft 365 products that can address the described business needs."
# }
# 3
# The customer is a tech company offering web and app development services. They use Outlook for communication and MS Access for database management. Their business needs include finding a storage solution that can be used for sharing files efficiently and keep data secure. {
#   "valid": true,
#   "reasoning": "The entry meets all three criteria: (A) Clarity, as it clearly mentions the business need of finding a storage solution for efficient file sharing and data security; (B) Specificity, as it specifies the concrete business goal of secure and efficient file sharing; and (C) Actionable, since Microsoft 365 products like OneDrive or SharePoint can practically address the described need."
# }
# 4
# Business offers a delightful range of homemade jams and jellies made from fresh, high-quality fruits. they mainly need Word for documents, excel for sales report and PPT for marketing poster   and OneDrive to backup data, they want to automate their order processing, inventory management, and  management  documents, like recipes and marketing posters in Realtime. it will enhance a quick way to handle orders and manage supplies and be able to update recipes and  manage marketing posters. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals. (A) Clarity: The business goal is clear and discusses the need for automation in order processing, inventory management, and document management. (B) Specificity: The entry specifies multiple concrete business needs, such as managing recipes, marketing posters, automating order processing, and inventory handling. (C) Actionable: The entry directly focuses on leveraging Microsoft 365 products like Word, Excel, PowerPoint, and OneDrive to address these needs, making it practical and implementable."
# }
# 5
# Connect email with Teams channels for smoother workflows. Enable employees to work from anywhere with synchronized email and Teams. {
#   "valid": false,
#   "reasoning": "The entry mentions a general business need (smoother workflows and synchronized email with Teams), but it lacks clarity in terms of how these goals will be achieved. It is also insufficiently specific, as it doesn't refer to a concrete, actionable business goal. The entry doesn't clearly outline practical steps or how Microsoft 365 products will directly address the described need."
# }
# 6
# CX runs a residential facility that provides care for individuals with chronic multiple substance abuse disorders. His main goal is to stay secure as he handles much sensitive data like patients' information. CX need to keep the data secure and protected against any unauthorized access.  {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for a valid business goal. It satisfies Clarity (clearly mentions the need to secure patient data), Specificity (the specific goal is to secure sensitive data like patients' information), and Actionability (Microsoft 365 products can practically address data security and protection)."
# }
# 7
# This university needs to utilize the Microsoft 365 platform for its students and faculty. By leveraging Microsoft 365, the institution aims to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities. {
#   "valid": true,
#   "reasoning": "The entry fulfills all the criteria for valid business goals. It is clear (A) in mentioning the need to utilize Microsoft 365, specific (B) in referring to goals like enhancing collaboration, streamlining communication, and supporting academic and administrative activities, and actionable (C) as it focuses on the practical application of Microsoft 365 products to address these needs."
# }
# 8
# he customer's organization focuses on supporting women who have been victims of gender-based violence. Since the customer is a small non-profit business, she is looking to be 100% connected with her customers by updating them about their programs and meetings. Goal captured save time and money. {
#   "valid": false,
#   "reasoning": "The entry fails to meet all three criteria. While the context and intent are somewhat clear (Criterion A: Clarity), it lacks specificity about the business goal or need (Criterion B). For instance, 'save time and money' is too vague, and the connection to specific tasks or objectives is not clearly outlined. Furthermore, the entry does not provide actionable details on how Microsoft 365 products would address the business need mentioned (Criterion C: Actionable)."
# }
# 9
# Cx has a technology company specialized in manufacturing many types of electrical machines, like food industry machines and medical machines. Cx spends too much time in meetings with clients discussing the status of the orders and discussing the payment for the purchased machines. Cx needs a tool to store the catalogues of machines and share it with clients. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for valid business goals:
#   - Clarity: The need to reduce time spent in client meetings for discussing orders and payments is clearly stated.
#   - Specificity: It refers specifically to providing a tool to store and share machine catalogues with clients.
#   - Actionable: Microsoft 365 products, such as SharePoint or OneDrive, can be practically applied to store and share catalogues, addressing the described business need."
# }
# [WARN] Failed to parse LLM response as JSON: Invalid control character at: line 3 column 76 (char 94)
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer, who owns a transport business, requires centralizing the management of network resources, user accounts, and permissions, making it easier to administer and secure the transport business's IT environment. This will ultimately support the business's operations run smoothly {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals. It is clear (A), as it specifically mentions centralizing the management of network resources and permissions. It is specific (B), focusing on an actionable business need for the transport business's IT environment. It is also actionable (C), as the described need can practically be addressed through Microsoft 365 products like Azure AD or Microsoft Endpoint Manager."
# }
# 1
# Customer made me understand that the reason he signed up for the Microsoft 365 was because he needed to save time and money as GoDaddy was charging her al for just email service , and knowing that Microsoft will provider her email service and also provides her other services, emails service and the Microsoft application and a lower cost, this made her to sign up for the Microsoft 365 Business subscription. {
#   "valid": false,
#   "reasoning": "The entry does not meet all the required criteria for validity. While it mentions a need (saving time and money), it lacks clarity and specificity in defining a concrete business goal. Additionally, it does not clearly describe how Microsoft 365 products are practically applied to address the need. Hence, it is invalid."
# }
# 2
# Save time and money. Customer applied for EDU pricing to be able to acquire Office 365 A3 for the users to use Office desktop apps with a discounted price. {
#   "valid": false,
#   "reasoning": "The entry does not meet the Valid Business Goals Criteria: While it mentions a business need related to saving costs, it lacks clarity (Criterion A) as the connection between EDU pricing and the business goal needs to be better explained. It fails to explicitly articulate a specific and actionable business goal (Criteria B and C), such as how Microsoft 365 tools will practically help save time and money in the described use case."
# }
# 3
# Customer is a business owner who runs a service of consulting and providing technological  consultation to assist both  small scale and  business and offers different  solutions  business after the assessment of customer business and request needs,  {
#   "valid": false,
#   "reasoning": "The entry fails to meet the Valid Business Goals Criteria because it lacks specificity and clarity. While it mentions the nature of the business and services offered, it does not describe a clear and specific business goal or need. Additionally, the entry is not actionable as it fails to focus on how Microsoft 365 products could practically address any defined business need."
# }
# 4
# Customer wants to save time and cut costs by using OneDrive for easy file sharing and syncing across devices. This will improve document access and collaboration with clients. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals. It is clear (mentions a goal of saving time and reducing costs while improving access and collaboration), specific (identifies using OneDrive for file sharing and syncing), and actionable (focuses on the practical application of Microsoft 365 products, in this case, OneDrive, to address the business need)."
# }
# 5
# The client operates a Nonprofit charitable trust he aims to setup emails on his phone to engage with clients through the use of a professional email address using his primary domain name. {
#   "valid": true,
#   "reasoning": "The entry is valid because it meets all the criteria for Business Goals: (A) Clarity - the need to set up emails on a phone to engage with clients is clear; (B) Specificity - the goal of using professional email addresses tied to the client's primary domain name is specific and concrete; (C) Actionable - Microsoft 365 offers a practical solution through email hosting and mobile synchronization capabilities."
# }
# 6
# The customer sought assistance from Copilot to create a custom signature in the Exchange Admin Center. However, they did not receive the exact steps for inserting an image correctly on the first attempt. This led the admin to raise a support request for further help. Additionally, Copilot did not mention that the image should be uploaded online first, which added to the confusion. {
#   "valid": false,
#   "reasoning": "The entry does not meet the Valid Business Goals Criteria. While the entry describes a scenario where a business problem occurred, it lacks clarity in expressing a concrete business need (Criterion A), does not specify a clear business goal (Criterion B), and does not focus on actionable application of Microsoft 365 products for addressing a business need (Criterion C). The described situation revolves around troubleshooting and technical issues rather than articulating a business goal."
# }
# 7
# The customer who operates a business leasing ISO tank container, aims to set up 5 additional business emails to enhance communication, streamline operations, and support business growth. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals. A) Clarity: The entry clearly mentions the need to set up additional business emails to enhance communication. B) Specificity: It specifies the exact goal of setting up 5 additional business emails. C) Actionable: It describes how setting up business emails can support business growth and streamline operations, which can be practically addressed using Microsoft 365 products."
# }
# 8
# I learned that customer business is daycare, the business needs of the customer is having OneDrive for storage and sharing files and Office Apps to access existing documents to drive existing projects planning execution. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria outlined for valid business goals. (A) It is clear and easy to understand that the business is a daycare and the need is for storage, sharing files, and accessing documents. (B) The entry refers to specific business needs related to file storage management and project execution. (C) It is actionable as it focuses on the practical applicability of Microsoft 365 products, such as OneDrive and Office Apps, to address the described business needs."
# }
# 9
# The customer explained that the main reason for subscribing to use Microsoft word and excel. They relay on excel primarily for creating and managing invoices, while word is used to create various documents. This combination of tools helps the customer streamline their workflow by organizing important data in a clear and structured way. It ensures they can easily access and manage their information, keeping everything orderly and readily available for a quick reference of further use {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for valid business goals. It is clear and easy to understand (Clarity), as it mentions the customer's reliance on Microsoft Word and Excel. It specifies the business goal of streamlining workflow and organizing important data in a clear, structured way (Specificity). Finally, it focuses on the practical applicability of Microsoft 365 products, such as Excel for managing invoices and Word for creating documents (Actionable)."
# }
# 101.5353422164917

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20     0.900000   0.642857  0.750000
# 1  loose_zero_shot_20_no_negative_criteria     0.777778   0.538462  0.636364
# 2                      loose_zero_shot_200     0.900000   0.638298  0.746888
# 3                    detailed_zero_shot_20     0.555556   0.625000  0.588235
# 4                     detailed_few_shot_20     0.400000   0.500000  0.444444

# %% [markdown]
# ### 3.2 Detailed Zero Shot Prompt
#
# In the prompt below, we provide a detailed list of criteria based on the latest version of the insights framework available at GigPlus. This has a detailed set of tiered criteria.

# %%
detailed_zero_shot_prompt = '''
You are an AI assistant that validates **Business Goals or Needs** by checking if they are well-defined and actionable for Microsoft 365 (including Copilot) solutions. A **Business Goal or Need** should describe a **specific technical need** tied to a business outcome that Microsoft 365 can achieve, rather than a vague goal.

**Example of a well-defined Business Goal/Need:**  
*A customer service team wants to respond to customers faster and more personally. To do this, they **need an AI-based email assistant** that can draft personalized replies and provide real-time customer sentiment analysis.*  
(This example clearly states a technical need – an AI email assistant – and the desired outcome of faster, more personal responses.)

## Validation Criteria:

**Core Requirements (must have all):**  
1. **Technical Need & Outcome** – Does it clearly specify the **technical solution or capability needed** *and* the **business outcome** desired? (e.g. “need X tool to achieve Y result”).  
2. **M365 Actionable** – Is it **actionable with Microsoft 365 and Copilot**? (i.e. the need can be addressed by a specific Microsoft 365 product, service, or feature).  
3. **Clarity & Feasibility** – Is it **specific, achievable, and clear**? (Avoids vagueness or unrealistic goals. It should be realistic and well-defined enough to guide solution design.)

**Additional Characteristics (at least one is typically present in a valid need):**  
- **User-Centric Pain Point** – Reflects a real user or team problem that Microsoft 365 can solve.  
- **Collaboration Improvement** – Aims to enhance communication or teamwork (a common strength of M365 tools).  
- **Customer Experience** – Targets improving how the business serves or engages customers (via M365 capabilities).  
- **Process Optimization** – Involves streamlining workflows or business processes (which M365 features can support).  
- **Integration** – Involves connecting multiple M365 services or integrating M365 with other systems.  
- **Data Management** – Focuses on better organizing, accessing, or analyzing data (using M365 analytics, databases, etc.).  
- **Mobile/Remote Support** – Addresses needs for remote work or mobile productivity (leveraging M365’s cloud/mobile tools).  
- **Cost/ROI Focus** – Indicates potential for cost savings or high return on investment using M365.  
- **Time-Saving Automation** – Centers on automating tasks or reducing manual effort (a key benefit of many M365/Copilot solutions).

*A Business Goal/Need that meets all core requirements and is aligned with Microsoft 365 capabilities (and ideally touches on one or more additional characteristics) should be marked **Valid**. If it misses any core requirement (e.g., too vague, not tied to M365, etc.), mark it **Invalid**.*

## Response ##

You will respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('detailed_zero_shot_20', detailed_zero_shot_prompt, test_results, business_goals_20)
# Out:
# 0
# Save time and money
# The customer's business imports and sells car parts from Europe to LATAM. Their goal is to implement a collaboration platform to enhance engagement and improve daily operations. {
#   "valid": false,
#   "reasoning": "The Business Goal/Need is too vague and lacks clarity on the specific technical solution or capability needed, which violates the 'Technical Need & Outcome' criterion. While it mentions a general goal to 'save time and money' and improve collaboration, it does not specify how Microsoft 365 (or Copilot) tools would be used to achieve this result. It also does not provide a clear or actionable technical need tied to a business outcome, such as automation, workflow optimization, or specific M365 features. Without these details, it is not actionable within Microsoft 365."
# }
# 1
# After discussing it became clear that the customer aims to enhance efficiency in daily operations by establishing a generic email address connected to a centralized mailbox for their company. This setup would allow multiple users to access the mailbox simultaneously and receive notifications when customers send inquiries, thereby improving communication and enabling faster responses. {
#   "valid": true,
#   "reasoning": "The business goal/need is well-defined and actionable within Microsoft 365. Specifically: 1. **Technical Need & Outcome**: The need for a centralized mailbox accessible by multiple users is clearly described, along with the business outcome of improved communication and faster responses. This matches the criteria. 2. **M365 Actionable**: Microsoft 365 provides solutions for shared mailboxes, where users can collaborate on communication effectively. Features like shared mailboxes in Exchange Online can fulfill this need. 3. **Clarity & Feasibility**: The technical requirement is specific, achievable, and clear.It also aligns with several additional characteristics: - **Collaboration Improvement**: Addresses enhanced teamwork by enabling shared access to customer inquiries. - **Customer Experience**: Targets a faster and more reliable way to respond to customer inquiries. - **Process Optimization**:
# [WARN] Failed to parse LLM response as JSON: Unterminated string starting at: line 3 column 16 (char 34)
# 2
# Simplify everyday task
#
# The business needs to utilize Microsoft Office desktop apps like Outlook, Word, and Excel to create detailed project documentation, manage budgets, and track progress efficiently. {
#   "valid": false,
#   "reasoning": "This description is too vague and lacks a sufficiently specific technical need or desired business outcome. While it mentions using Microsoft Office desktop apps for documentation, budget management, and progress tracking, it does not provide clear details about any technical solution or capability required to simplify tasks. For it to be valid, it should specify how Microsoft 365 features (e.g., Automations, Copilot functionalities, SharePoint collaboration, or Excel's data analysis tools) would achieve a defined improvement in efficiency or business output."
# }
# 3
# The customer is a tech company offering web and app development services. They use Outlook for communication and MS Access for database management. Their business needs include finding a storage solution that can be used for sharing files efficiently and keep data secure. {
#   "valid": true,
#   "reasoning": "This business need is valid because it clearly specifies a technical need ('finding a storage solution that can be used for sharing files efficiently and keeping data secure') and a desired business outcome (efficient file sharing and data security). It is actionable with Microsoft 365, as OneDrive or SharePoint can provide secure file storage, sharing, and data management capabilities. The goal is specific, achievable, and aligned with M365's strengths in data management and collaboration. Additionally, it addresses a user-centric pain point related to secure and efficient file sharing, which is a common use case for M365 solutions."
# }
# 4
# Business offers a delightful range of homemade jams and jellies made from fresh, high-quality fruits. they mainly need Word for documents, excel for sales report and PPT for marketing poster   and OneDrive to backup data, they want to automate their order processing, inventory management, and  management  documents, like recipes and marketing posters in Realtime. it will enhance a quick way to handle orders and manage supplies and be able to update recipes and  manage marketing posters. {
#   "valid": true,
#   "reasoning": "The Business Goal/Need is well-defined and actionable for Microsoft 365 solutions. It specifies a technical need: automating order processing, inventory management, and document management (e.g., recipes and marketing posters in real time) using Microsoft 365 capabilities like Excel, Word, PowerPoint, and OneDrive. The desired business outcomes are clear: quicker order handling, seamless supply management, and streamlined updates to recipes and marketing materials. Additionally, this aligns with M365's strengths in workflow optimization, collaboration, and cloud-based data management. The request meets all core requirements and several additional characteristics, including process optimization, collaboration improvement, and data management."
# }
# 5
# Connect email with Teams channels for smoother workflows. Enable employees to work from anywhere with synchronized email and Teams. {
#   "valid": true,
#   "reasoning": "This is a valid Business Goal/Need because it specifies a technical need and business outcome: connecting email with Teams channels to improve workflows and enabling employees to work from anywhere by synchronizing email and Teams. This is achievable with Microsoft 365, specifically by leveraging integrations between Outlook and Teams via connectors or automation tools like Power Automate. The goal is clear, feasible, and actionable using M365 capabilities, specifically enhancing collaboration and remote work support."
# }
# 6
# CX runs a residential facility that provides care for individuals with chronic multiple substance abuse disorders. His main goal is to stay secure as he handles much sensitive data like patients' information. CX need to keep the data secure and protected against any unauthorized access.  {
#   "valid": true,
#   "reasoning": "This Business Goal/Need meets all the core requirements for validation. It specifies a technical need (data security and protection against unauthorized access), along with the desired business outcome (keeping sensitive patient information secure). Microsoft 365 is actionable in this context, as solutions like Microsoft Purview for compliance management, Azure Information Protection for securing data, and security tools such as Multi-Factor Authentication (MFA) are designed to address such needs. The goal is clear, feasible, and tied to a real user or team pain point involving sensitive data management. Additionally, it concerns data management, which is a key area Microsoft 365 excels in."
# }
# 7
# This university needs to utilize the Microsoft 365 platform for its students and faculty. By leveraging Microsoft 365, the institution aims to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities. {
#   "valid": false,
#   "reasoning": "While the goal to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities suggests a focus on Microsoft 365 capabilities, the need is too vague and does not specify a clear technical solution or actionable use case. It does not describe specific tools, features, or outcomes within Microsoft 365, such as Teams for virtual classrooms, SharePoint for document management, or Copilot for workflow automation. To be valid, the need should detail a specific scenario or technical requirement tied to measurable outcomes."
# }
# 8
# he customer's organization focuses on supporting women who have been victims of gender-based violence. Since the customer is a small non-profit business, she is looking to be 100% connected with her customers by updating them about their programs and meetings. Goal captured save time and money. {
#   "valid": false,
#   "reasoning": "The Business Goal/Need lacks a clear technical need that ties the desired business outcome to a Microsoft 365 solution. While it describes a general need to be connected with customers and save time and money, it fails to specify what specific Microsoft 365 tool or capability is required to achieve this (e.g., utilizing Teams for virtual meetings, SharePoint for program updates, or email campaigns through Outlook). Furthermore, the goal is somewhat vague and does not outline actionable, well-defined solutions that Microsoft 365 or Copilot can directly support."
# }
# 9
# Cx has a technology company specialized in manufacturing many types of electrical machines, like food industry machines and medical machines. Cx spends too much time in meetings with clients discussing the status of the orders and discussing the payment for the purchased machines. Cx needs a tool to store the catalogues of machines and share it with clients. {
#   "valid": true,
#   "reasoning": "The business need clearly specifies a technical solution – a tool to store and share machine catalogs – and ties it to a business outcome of reducing time spent in client meetings to discuss orders and payments. Microsoft 365 provides actionable solutions for this need, such as using SharePoint or OneDrive to store and share catalogs efficiently with clients, supported by Teams for collaboration. The need is specific, achievable, and tied to M365 capabilities. Additionally, this aligns with process optimization and collaboration improvement characteristics."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer, who owns a transport business, requires centralizing the management of network resources, user accounts, and permissions, making it easier to administer and secure the transport business's IT environment. This will ultimately support the business's operations run smoothly {
#   "valid": true,
#   "reasoning": "This Business Goal/Need is valid as it meets all core criteria. The **technical need** is to centralize the management of network resources, user accounts, and permissions, which is actionable through Microsoft 365 tools like Azure Active Directory, Microsoft Entra, and Security & Compliance features. The **business outcome** desired is smoother transportation business operations through secure and efficient IT administration. It is both specific and feasible. Additionally, this need reflects real user pain points related to IT administration, aligns with Microsoft 365's strengths in security and centralized management, and supports process optimization by streamlining IT workflows."
# }
# 1
# Customer made me understand that the reason he signed up for the Microsoft 365 was because he needed to save time and money as GoDaddy was charging her al for just email service , and knowing that Microsoft will provider her email service and also provides her other services, emails service and the Microsoft application and a lower cost, this made her to sign up for the Microsoft 365 Business subscription. {
#   "valid": false,
#   "reasoning": "The described need is too vague and does not specify a clear technical solution or actionable capability tied to a business outcome. While the customer expressed general motivations such as cost savings and access to email services, there is no specific business goal or technical need outlined that Microsoft 365 is expected to fulfill. For the need to be valid, it must clearly include specific features or capabilities the customer intends to leverage (e.g., 'needs shared mailboxes for team collaboration' or 'requires automated task tracking with Planner to streamline workflow'). The statement lacks technical detail and actionable M365 alignment."
# }
# 2
# Save time and money. Customer applied for EDU pricing to be able to acquire Office 365 A3 for the users to use Office desktop apps with a discounted price. {
#   "valid": false,
#   "reasoning": "The provided statement lacks clarity in terms of a specific technical need or business outcome tied to a Microsoft 365 solution. While it mentions acquiring Office 365 A3 with EDU pricing to save costs, it does not define a specific technical capability or solution (e.g., how Office desktop apps will be utilized) or clearly articulate the desired business outcome (e.g., improving student collaboration, enhancing productivity, etc.). Additionally, it's not actionable in the sense that it doesn't define a problem or goal to be solved using Microsoft 365 features or Copilot. For validity, it should describe a more specific use case or goal tied to leveraging M365 capabilities."
# }
# 3
# Customer is a business owner who runs a service of consulting and providing technological  consultation to assist both  small scale and  business and offers different  solutions  business after the assessment of customer business and request needs,  {
#   "valid": false,
#   "reasoning": "The described scenario is too vague and lacks a well-defined **technical need** or **business outcome**. It does not specify any specific problem, capability, or solution required that ties to Microsoft 365. While the customer seems to provide technological consultations, the description does not clarify what specific tool, process, or functionality they aim to achieve through Microsoft 365. It also lacks clarity and actionable steps that could lead to a solution design."
# }
# 4
# Customer wants to save time and cut costs by using OneDrive for easy file sharing and syncing across devices. This will improve document access and collaboration with clients. {
#   "valid": true,
#   "reasoning": "This Business Goal/Need meets all core requirements. It clearly specifies a technical capability needed – using OneDrive for file sharing and syncing – and connects it to a business outcome of saving time, cutting costs, and improving document access and collaboration with clients. The solution is actionable with Microsoft 365 (via OneDrive) and is specific and feasible. Additionally, it aligns with characteristics such as collaboration improvement, cost savings, and mobile/remote support."
# }
# 5
# The client operates a Nonprofit charitable trust he aims to setup emails on his phone to engage with clients through the use of a professional email address using his primary domain name. {
#   "valid": false,
#   "reasoning": "The business goal or need is vague and does not clearly specify a technical solution or capability that is actionable within Microsoft 365. While it mentions setting up emails on a phone, it does not align with a specific business outcome or technical need tied to Microsoft 365 capabilities. For example, specifying the need for Microsoft Outlook or Exchange integration with a primary domain name would make it actionable. It also lacks clarity regarding feasibility, as there's no mention of how Microsoft 365 will assist in the setup or the professional domain requirements."
# }
# 6
# The customer sought assistance from Copilot to create a custom signature in the Exchange Admin Center. However, they did not receive the exact steps for inserting an image correctly on the first attempt. This led the admin to raise a support request for further help. Additionally, Copilot did not mention that the image should be uploaded online first, which added to the confusion. {
#   "valid": false,
#   "reasoning": "The described scenario does not meet the core requirement of specifying a clear business outcome tied to a technical solution. While it mentions a support issue with Copilot, the actual business goal or need is vague and lacks clarity on the desired outcome. There is no mention of how this issue ties to a broader business purpose or actionable use of Microsoft 365 features (e.g., improving communication, team collaboration, or process optimization). Furthermore, Copilot in Microsoft 365 can assist with tasks but the request mainly focuses on resolving a procedural error rather than a defined business goal or technical need."
# }
# 7
# The customer who operates a business leasing ISO tank container, aims to set up 5 additional business emails to enhance communication, streamline operations, and support business growth. {
#   "valid": false,
#   "reasoning": "The need to set up 5 additional business emails is not well-defined in terms of a technical solution tied to a specific business outcome. While Microsoft 365 offers email hosting via Outlook and Exchange, the goal lacks clarity on how these new email accounts directly contribute to enhancing communication, streamlining operations, or supporting growth. Additionally, it does not specify additional technical requirements or outcomes beyond simply creating email accounts, such as implementing collaborative tools, automation, or integrations to achieve business growth. Without clear details about the desired outcomes beyond email creation, it is too vague to be actionable or validate as meeting the criteria."
# }
# 8
# I learned that customer business is daycare, the business needs of the customer is having OneDrive for storage and sharing files and Office Apps to access existing documents to drive existing projects planning execution. {
#   "valid": true,
#   "reasoning": "The business need is well-defined and actionable within Microsoft 365. It specifies the technical need for OneDrive for storage and sharing files and Office apps to access existing documents. The desired business outcome of driving project planning and execution aligns well with Microsoft 365 capabilities, such as seamless file storage, sharing, and collaboration using OneDrive and Office apps. It is clear, feasible, and tied to a concrete workflow, making it a valid need."
# }
# 9
# The customer explained that the main reason for subscribing to use Microsoft word and excel. They relay on excel primarily for creating and managing invoices, while word is used to create various documents. This combination of tools helps the customer streamline their workflow by organizing important data in a clear and structured way. It ensures they can easily access and manage their information, keeping everything orderly and readily available for a quick reference of further use {
#   "valid": false,
#   "reasoning": "While the scenario describes the customer's use of Microsoft Word and Excel for creating documents and managing invoices, it does not clearly define a specific technical need tied to a business outcome that Microsoft 365 (or Copilot) can uniquely address. The description primarily talks about existing use cases of Word and Excel without specifying a new goal, pain point, or actionable requirement for a Microsoft 365 capability. To be valid, the need would need to describe, for example, a requirement for automation in invoice management, integration of Word and Excel with other tools, or leveraging Copilot for document generation and organization."
# }
# 108.72600603103638

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20     0.900000   0.642857  0.750000
# 1  loose_zero_shot_20_no_negative_criteria     0.777778   0.538462  0.636364
# 2                      loose_zero_shot_200     0.900000   0.638298  0.746888
# 3                    detailed_zero_shot_20     0.555556   0.625000  0.588235

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''
You are an AI assistant that validates **Business Goals or Needs** by checking if they are well-defined and actionable for Microsoft 365 (including Copilot) solutions. A **Business Goal or Need** should describe a **specific technical need** tied to a business outcome that Microsoft 365 can achieve, rather than a vague goal.

**Example of a well-defined Business Goal/Need:**  
*A customer service team wants to respond to customers faster and more personally. To do this, they **need an AI-based email assistant** that can draft personalized replies and provide real-time customer sentiment analysis.*  
(This example clearly states a technical need – an AI email assistant – and the desired outcome of faster, more personal responses.)

## Validation Criteria:

**Core Requirements (must have all):**  
1. **Technical Need & Outcome** – Does it clearly specify the **technical solution or capability needed** *and* the **business outcome** desired? (e.g. “need X tool to achieve Y result”).  
2. **M365 Actionable** – Is it **actionable with Microsoft 365/Copilot**? (i.e. the need can be addressed by a specific Microsoft 365 product, service, or feature).  
3. **Clarity & Feasibility** – Is it **specific, achievable, and clear**? (Avoids vagueness or unrealistic goals. It should be realistic and well-defined enough to guide solution design.)

**Additional Characteristics (at least one is typically present in a valid need):**  
- **User-Centric Pain Point** – Reflects a real user or team problem that Microsoft 365 can solve.  
- **Collaboration Improvement** – Aims to enhance communication or teamwork (a common strength of M365 tools).  
- **Customer Experience** – Targets improving how the business serves or engages customers (via M365 capabilities).  
- **Process Optimization** – Involves streamlining workflows or business processes (which M365 features can support).  
- **Integration** – Involves connecting multiple M365 services or integrating M365 with other systems.  
- **Data Management** – Focuses on better organizing, accessing, or analyzing data (using M365 analytics, databases, etc.).  
- **Mobile/Remote Support** – Addresses needs for remote work or mobile productivity (leveraging M365’s cloud/mobile tools).  
- **Cost/ROI Focus** – Indicates potential for cost savings or high return on investment using M365.  
- **Time-Saving Automation** – Centers on automating tasks or reducing manual effort (a key benefit of many M365/Copilot solutions).

*A Business Goal/Need that meets all core requirements and is aligned with Microsoft 365 capabilities (and ideally touches on one or more additional characteristics) should be marked **Valid**. If it misses any core requirement (e.g., too vague, not tied to M365, etc.), mark it **Invalid**.*

### Examples:

- **Example 1 (Valid):** *“The sales team needs a real-time analytics dashboard (Power BI) to track daily sales and quickly adjust strategies to meet their targets.”*  
  – Meets 1 (specific need: real-time dashboard; outcome: adjust strategies to meet targets), 2 (M365 solution: Power BI), 3 (clear and achievable). Also aligns with Data Management and Time-Saving.  

- **Example 2 (Invalid):** *“Improve productivity with better tools.”*  
  – Fails 1 (no specific tool or outcome mentioned) and 3 (too vague). We don’t know what “better tools” or which outcome. Not actionable for PLG because it’s unclear what to build or measure.  

## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('detailed_few_shot_20', few_shot_prompt, test_results, business_goals_20)

test_results
# Out:
# 0
# Save time and money
# The customer's business imports and sells car parts from Europe to LATAM. Their goal is to implement a collaboration platform to enhance engagement and improve daily operations. {
#   "valid": false,
#   "reasoning": "The entry is too vague and does not specify a clear technical need or business outcome tied to Microsoft 365 solutions. While it mentions a broad goal of implementing a collaboration platform to enhance engagement and improve operations, it does not identify specific tools, capabilities, or outcomes (e.g., 'streamline communication through Teams for faster decision-making' or 'use SharePoint to centralize inventory tracking'). Without such detail, it fails core requirements for clarity, technical need, and actionable M365 capability."
# }
# 1
# After discussing it became clear that the customer aims to enhance efficiency in daily operations by establishing a generic email address connected to a centralized mailbox for their company. This setup would allow multiple users to access the mailbox simultaneously and receive notifications when customers send inquiries, thereby improving communication and enabling faster responses. {
#   "valid": true,
#   "reasoning": "The entry is valid because it specifies a clear technical need (a centralized mailbox connected to a generic email address with multi-user access and notifications) and ties it to the desired business outcome (enhancing efficiency, communication, and response times for customer inquiries). It is actionable with Microsoft 365 solutions, such as a shared mailbox in Exchange Online, which supports simultaneous user access and notification settings. The goal is clear, feasible, and aligned with M365 capabilities."
# }
# 2
# Simplify everyday task
#
# The business needs to utilize Microsoft Office desktop apps like Outlook, Word, and Excel to create detailed project documentation, manage budgets, and track progress efficiently. {
#   "valid": false,
#   "reasoning": "The goal is too general and lacks a specific technical need tied to a measurable business outcome. While it mentions using Microsoft Office desktop apps like Outlook, Word, and Excel for project documentation, budget management, and progress tracking, it doesn't clearly define a specific capability or solution required to simplify these tasks. There is no mention of a new feature, process, or automation, and the desired outcome is vague ('simplify everyday task')."
# }
# 3
# The customer is a tech company offering web and app development services. They use Outlook for communication and MS Access for database management. Their business needs include finding a storage solution that can be used for sharing files efficiently and keep data secure. {
#   "valid": true,
#   "reasoning": "This entry meets all core requirements. It specifies a clear technical need (a storage solution for efficient file sharing and secure data storage) and the desired business outcome (enhanced file sharing efficiency and data security). It is actionable with Microsoft 365, as OneDrive for Business or SharePoint could provide these capabilities. The need is specific, achievable, and clear. Additionally, it aligns with Collaboration Improvement, Data Management, and Process Optimization."
# }
# 4
# Business offers a delightful range of homemade jams and jellies made from fresh, high-quality fruits. they mainly need Word for documents, excel for sales report and PPT for marketing poster   and OneDrive to backup data, they want to automate their order processing, inventory management, and  management  documents, like recipes and marketing posters in Realtime. it will enhance a quick way to handle orders and manage supplies and be able to update recipes and  manage marketing posters. {
#   "valid": false,
#   "reasoning": "While the business need specifies tools like Word, Excel, PowerPoint, and OneDrive for various tasks, and includes a broader aim to automate order processing, inventory management, and real-time management of documents like recipes and marketing posters, the technical need and business outcome are not clearly linked to a specific Microsoft 365 solution. The described goals lack clarity on how M365 would specifically address the automation of order processing and inventory management. The mention of real-time document updates is relevant to M365's capabilities (e.g., OneDrive for synchronization), but the automation aspects need clear technical and actionable details such as using Power Automate or Copilot. The description is currently too vague to be actionable."
# }
# 5
# Connect email with Teams channels for smoother workflows. Enable employees to work from anywhere with synchronized email and Teams. {
#   "valid": true,
#   "reasoning": "The need clearly specifies integrating email with Teams to create smoother workflows, which is actionable using Microsoft 365 features like Teams and Outlook integrations. It ties to the business goal of enabling employees to work from anywhere with synchronized collaboration tools, addressing mobile/remote support and collaboration improvement. The need is achievable, specific, and clearly aligned with M365 capabilities."
# }
# 6
# CX runs a residential facility that provides care for individuals with chronic multiple substance abuse disorders. His main goal is to stay secure as he handles much sensitive data like patients' information. CX need to keep the data secure and protected against any unauthorized access.  {
#   "valid": true,
#   "reasoning": "The Business Need specifies a clear technical need (data security and protection against unauthorized access) and a desired business outcome (keeping sensitive patient information secure). This is actionable with Microsoft 365, as it can leverage features like Microsoft Purview for data loss prevention, encryption, and compliance, as well as Microsoft Defender for threat protection. The need is specific, achievable, and well-aligned with the business goal of protecting sensitive information."
# }
# 7
# This university needs to utilize the Microsoft 365 platform for its students and faculty. By leveraging Microsoft 365, the institution aims to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities. {
#   "valid": false,
#   "reasoning": "The need is too vague and does not specify any particular technical solution or outcome. While it mentions goals like enhancing collaboration, streamlining communication, and providing a digital environment, it does not define specific tools or features within Microsoft 365 that will be leveraged, nor does it outline measurable business outcomes. This makes it unclear and not actionable for Microsoft 365 solutions."
# }
# 8
# he customer's organization focuses on supporting women who have been victims of gender-based violence. Since the customer is a small non-profit business, she is looking to be 100% connected with her customers by updating them about their programs and meetings. Goal captured save time and money. {
#   "valid": false,
#   "reasoning": "While the business goal identifies a focus on connecting with customers and mentions saving time and money, it fails to specify a clear technical need or capability tied to Microsoft 365. The description does not clarify the specific solution (e.g., email automation, scheduling tools, communication platforms) or the actionable result expected from using Microsoft 365 technologies. Additionally, the goal is vague and does not outline measurable outcomes or a precise action plan."
# }
# 9
# Cx has a technology company specialized in manufacturing many types of electrical machines, like food industry machines and medical machines. Cx spends too much time in meetings with clients discussing the status of the orders and discussing the payment for the purchased machines. Cx needs a tool to store the catalogues of machines and share it with clients. {
#   "valid": false,
#   "reasoning": "While the entry specifies a business pain point (too much time spent in meetings with clients) and mentions a need for storing catalogs and sharing them with clients, it does not clearly outline a specific technical solution within Microsoft 365 or tie the need directly to a measurable business outcome. For instance, it is unclear how sharing catalogs will reduce the time spent in meetings or whether tools like SharePoint, Teams, or OneDrive could address the issue. The lack of clarity and actionable connection to M365 solutions makes it invalid."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer, who owns a transport business, requires centralizing the management of network resources, user accounts, and permissions, making it easier to administer and secure the transport business's IT environment. This will ultimately support the business's operations run smoothly {
#   "valid": true,
#   "reasoning": "The business need specifies a technical solution—centralized management of network resources, user accounts, and permissions—which aligns with capabilities of Microsoft 365, such as Azure Active Directory and Microsoft Endpoint Manager. The desired outcome (easier administration and improved security to support smooth business operations) is clearly outlined. The need is actionable with Microsoft 365 and feasible, focusing on a real user pain point (IT environment management)."
# }
# 1
# Customer made me understand that the reason he signed up for the Microsoft 365 was because he needed to save time and money as GoDaddy was charging her al for just email service , and knowing that Microsoft will provider her email service and also provides her other services, emails service and the Microsoft application and a lower cost, this made her to sign up for the Microsoft 365 Business subscription. {
#   "valid": false,
#   "reasoning": "The entry describes the customer's general motivation for choosing Microsoft 365 (time and cost savings as compared to GoDaddy) but does not define a specific **technical need** or a desired **business outcome**. It is too vague and lacks actionable details about what specific capabilities (e.g., an integrated email system, collaboration tools, or productivity features) the customer intends to use to achieve those savings. Therefore, it fails Core Requirements #1 (Technical Need & Outcome) and #3 (Clarity & Feasibility), even though Microsoft 365 could potentially address the underlying pain points."
# }
# 2
# Save time and money. Customer applied for EDU pricing to be able to acquire Office 365 A3 for the users to use Office desktop apps with a discounted price. {
#   "valid": false,
#   "reasoning": "While the goal of saving time and money is implied through accessing Office 365 A3 pricing, the statement does not clearly specify a technical need or desired business outcome other than acquiring the license affordably. The focus is on pricing rather than a specific capability or feature actionable within Microsoft 365. It lacks clarity on what exact business need the Office desktop apps will address or how the tools will be used to achieve a specific business outcome."
# }
# 3
# Customer is a business owner who runs a service of consulting and providing technological  consultation to assist both  small scale and  business and offers different  solutions  business after the assessment of customer business and request needs,  {
#   "valid": false,
#   "reasoning": "The provided entry is too vague and does not specify a clear technical need or actionable outcome tied to Microsoft 365 solutions. While it describes the general nature of the business (consulting and technological consultation for businesses), it does not identify a specific tool, feature, or capability required to achieve a well-defined business goal. To be valid, the entry needs to be more specific about the exact technical need and outcome within the context of Microsoft 365."
# }
# 4
# Customer wants to save time and cut costs by using OneDrive for easy file sharing and syncing across devices. This will improve document access and collaboration with clients. {
#   "valid": true,
#   "reasoning": "The Business Goal is well-defined as it specifies a technical need (use OneDrive for file sharing and syncing) tied to a business outcome (saving time, cutting costs, improving document access, and collaboration with clients). It is actionable with Microsoft 365 solutions, as OneDrive is a core tool for file sharing and syncing. The goal is clear, achievable, and aligns with Process Optimization, Collaboration Improvement, and Mobile/Remote Support characteristics."
# }
# 5
# The client operates a Nonprofit charitable trust he aims to setup emails on his phone to engage with clients through the use of a professional email address using his primary domain name. {
#   "valid": true,
#   "reasoning": "The Business Goal specifies a clear technical need: setting up professional email addresses using the client's primary domain for mobile access, which is actionable through Microsoft 365 (e.g., using Exchange Online for domain-based email hosting and mobile email access). The desired business outcome is improved client engagement with professional communication. This is both clear and achievable, aligning with Microsoft 365's capabilities to support mobile productivity and email management."
# }
# 6
# The customer sought assistance from Copilot to create a custom signature in the Exchange Admin Center. However, they did not receive the exact steps for inserting an image correctly on the first attempt. This led the admin to raise a support request for further help. Additionally, Copilot did not mention that the image should be uploaded online first, which added to the confusion. {
#   "valid": false,
#   "reasoning": "The entry describes a specific issue with Copilot's guidance on creating a custom signature in the Exchange Admin Center but fails to outline a clear business goal or technical need tied to a desired business outcome. While it identifies a pain point, it does not specify a solution or improvement that Microsoft 365/Copilot can address, nor does it tie this to a broader business process or result. Therefore, it does not meet the validation criteria."
# }
# 7
# The customer who operates a business leasing ISO tank container, aims to set up 5 additional business emails to enhance communication, streamline operations, and support business growth. {
#   "valid": false,
#   "reasoning": "The need mentions setting up additional business emails, but it lacks clarity on a specific Microsoft 365 solution or technical capability tied to a measurable business outcome. While Microsoft 365 can facilitate email creation via Outlook and Exchange, this description does not define how the emails enhance communication, streamline operations, or support growth in a specific or actionable way. It also does not specify if there is a technical need for integration, automation, or collaboration features that Microsoft 365 uniquely provides."
# }
# 8
# I learned that customer business is daycare, the business needs of the customer is having OneDrive for storage and sharing files and Office Apps to access existing documents to drive existing projects planning execution. {
#   "valid": true,
#   "reasoning": "The business need is specific, actionable, and tied to a clear technical solution. The customer explicitly needs OneDrive for storage and file sharing, and Office Apps for accessing documents, which are actionable capabilities of Microsoft 365. The desired business outcome—driving project planning and execution—is feasible and aligns with the solution. Furthermore, it touches on process optimization and collaboration improvement relevant to the daycare business."
# }
# 9
# The customer explained that the main reason for subscribing to use Microsoft word and excel. They relay on excel primarily for creating and managing invoices, while word is used to create various documents. This combination of tools helps the customer streamline their workflow by organizing important data in a clear and structured way. It ensures they can easily access and manage their information, keeping everything orderly and readily available for a quick reference of further use {
#   "valid": false,
#   "reasoning": "The submission describes a general use case for Microsoft Word and Excel but fails to articulate a specific technical need or business outcome that Microsoft 365 solutions could address. There is no clear actionable goal, technical feature, or capability needed beyond the basic use of Office apps, which does not meet the core criteria for validation."
# }
# 103.49405884742737
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20     0.900000   0.642857  0.750000
# 1  loose_zero_shot_20_no_negative_criteria     0.777778   0.538462  0.636364
# 2                      loose_zero_shot_200     0.900000   0.638298  0.746888
# 3                    detailed_zero_shot_20     0.555556   0.625000  0.588235
# 4                     detailed_few_shot_20     0.400000   0.500000  0.444444

# %% [markdown]
# ### Few Shot V2
#
# This prompt features more positive and negative examples, stricter language, and eliminated redundancy. This prompt has also been optimised by an AI.

# %%
few_shot_prompt_v2 = '''
You are an AI assistant that validates **Business Goals or Needs** by checking if they are well-defined and actionable for Microsoft 365 (including Copilot) solutions. A **Business Goal or Need** should describe a **specific technical need** tied to a business outcome that Microsoft 365 can achieve, rather than a vague goal.

## Validation Criteria:

**1. Core Criteria**

The entry must match all of the following core criteria: 

A: **Technical Need & Outcome** – The entry specifies the **technical solution or capability needed** *and* the **business outcome** desired? (e.g. “need X technical solution to achieve Y result”).  
B: **M365 Actionable** – The entry describes a need, goal or pain point that is *actionable with Microsoft 365 and/or Copilot products**
C: **Clarity & Specificty ** – The entry is **specific and clear**, it does not contain vague business jargon and showcases a concrete job-to-be-done for the customer

**2. Additional Criteria :**  

The entry must match at least one of the following criteria to be valid:

D: - **Collaboration Improvement** – The entry describes a need to enhance communication or teamwork (a common strength of M365 tools).  
E: - **Improving Customer Experience** – The entry describes a need related to better serve customers via M365 capabilities.  
F: - **Process Optimization** –The entry describes a need or goal related to automating business processes, autating tasks and reducing manual effort(which M365 features can support).  
G: - **Integration** – The entry describes a need related to connecting multiple M365 services or integrating M365 with other systems.  
H: - **Data Management** – The entry describes a need or goal related to organizing, accessing, or analyzing data (using M365 analytics, databases, etc.).  
I: - **Mobile/Remote Support** – The entry descrbes needs related to remote work or mobile productivity (leveraging M365’s cloud/mobile tools).  
J: - **Cost/ROI Focus** – Indicates potential for cost savings or high return on investment using M365.  

*An entry that meets all core requirements and is aligned with Microsoft 365 capabilities (and touches on one or more additional characteristics) should be marked **Valid**. If it misses any core requirement (e.g., too vague, not tied to M365, etc.), mark it **Invalid**.*

### Valid Examples:

- "A financial services company wants to reduce manual expense approvals by automating workflows within the next quarter"
    - Meets A, B, C and F

- "An independend consulstant managing client contracts is looking for a way to secure sensitive data and comply with GPDR"
    - Meets A, B, C and H

- “The sales team needs a real-time analytics dashboard to track daily sales and quickly adjust strategies to meet their targets.”
  – Meets A, B, C and F

- "The customer needs a solution that enables efficient project planning and real-time collaboration among team members".
 - Meets A, B, C and D

### Invalid Examples:

- “Improve productivity with better tools.”
  – Fails A and C

- “the customer needs a security suite to secure his business.”
  – Fails C

- "The customer's goal is to reduce costs by 50%, so it recommends cheaper plans like Microsoft Basic." 
 - Fails A and B

## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('detailed_few_shot_20', few_shot_prompt_v2, test_results, business_goals_20)
# Out:
# 0
# Save time and money
# The customer's business imports and sells car parts from Europe to LATAM. Their goal is to implement a collaboration platform to enhance engagement and improve daily operations. {
#   "valid": false,
#   "reasoning": "The entry is too vague and lacks specificity regarding the technical need and business outcome (Criteria A). While it mentions a general goal to implement a collaboration platform, it does not specify what capabilities are required or how Microsoft 365 will address their specific operational challenges. Additionally, 'Save time and money' is overly broad and does not clarify the concrete job-to-be-done (Criteria C)."
# }
# 1
# After discussing it became clear that the customer aims to enhance efficiency in daily operations by establishing a generic email address connected to a centralized mailbox for their company. This setup would allow multiple users to access the mailbox simultaneously and receive notifications when customers send inquiries, thereby improving communication and enabling faster responses. {
#   "valid": true,
#   "reasoning": "The entry specifies a clear technical need (setting up a centralized mailbox with shared access and notifications) tied to a tangible business outcome (improving communication and enabling faster responses to customer inquiries). It is actionable with Microsoft 365 tools like Exchange and shared mailboxes, meeting criteria A, B, and C. Additionally, it aligns with D (Collaboration Improvement) and E (Improving Customer Experience)."
# }
# 2
# Simplify everyday task
#
# The business needs to utilize Microsoft Office desktop apps like Outlook, Word, and Excel to create detailed project documentation, manage budgets, and track progress efficiently. {
#   "valid": true,
#   "reasoning": "The entry is valid because it specifies the technical solution (Microsoft Office desktop apps like Outlook, Word, and Excel) and ties it to the desired business outcomes (create detailed project documentation, manage budgets, and track progress efficiently), meeting criteria A and B. It is clear and specific, fulfilling criterion C. Additionally, it aligns with process optimization (F) as it aims to simplify and organize everyday tasks using M365 tools."
# }
# 3
# The customer is a tech company offering web and app development services. They use Outlook for communication and MS Access for database management. Their business needs include finding a storage solution that can be used for sharing files efficiently and keep data secure. {
#   "valid": true,
#   "reasoning": "The entry specifies a technical need ('a storage solution for sharing files efficiently and keeping data secure') and a desired business outcome (improved file-sharing efficiency and data security). It is actionable with Microsoft 365 through solutions like OneDrive for Business or SharePoint for secure file sharing and storage. The entry is clear and specific, aligning with M365 capabilities, and meets additional criteria F (Process Optimization) and H (Data Management)."
# }
# 4
# Business offers a delightful range of homemade jams and jellies made from fresh, high-quality fruits. they mainly need Word for documents, excel for sales report and PPT for marketing poster   and OneDrive to backup data, they want to automate their order processing, inventory management, and  management  documents, like recipes and marketing posters in Realtime. it will enhance a quick way to handle orders and manage supplies and be able to update recipes and  manage marketing posters. {
#   "valid": true,
#   "reasoning": "The entry outlines specific technical needs related to using Microsoft 365 tools, including Word, Excel, PPT, OneDrive, and automation capabilities, to achieve desired business outcomes such as efficient order processing, inventory management, and document updating in real-time. It is actionable with M365 solutions like Microsoft Power Automate, OneDrive, and document collaboration features to streamline these workflows. Additionally, it is specific and clear (meeting core criteria), aligns with M365 capabilities, and touches on process optimization (F), collaboration improvement (D), and data management (H)."
# }
# 5
# Connect email with Teams channels for smoother workflows. Enable employees to work from anywhere with synchronized email and Teams. {
#   "valid": true,
#   "reasoning": "The entry meets all core criteria. It specifies the technical need to integrate email with Teams channels for streamlined workflows and includes the desired business outcome of enabling employees to work from anywhere by synchronizing email and Teams. It is actionable with Microsoft 365 capabilities, particularly Teams and Outlook integration. Additionally, it matches criteria D (Collaboration Improvement) and I (Mobile/Remote Support)."
# }
# 6
# CX runs a residential facility that provides care for individuals with chronic multiple substance abuse disorders. His main goal is to stay secure as he handles much sensitive data like patients' information. CX need to keep the data secure and protected against any unauthorized access.  {
#   "valid": true,
#   "reasoning": "The entry is valid because it specifies a technical need (secure sensitive patient information and protect against unauthorized access) tied to a business outcome (maintaining security for a residential care facility). It is actionable using Microsoft 365 or Copilot solutions, such as leveraging Microsoft Defender, Azure Information Protection, and data encryption technologies. The entry is clear and specific (meets A, B, C), and aligns with H (Data Management) and potentially G (Integration with security tools)."
# }
# 7
# This university needs to utilize the Microsoft 365 platform for its students and faculty. By leveraging Microsoft 365, the institution aims to enhance collaboration, streamline communication, and provide a robust digital environment for academic and administrative activities. {
#   "valid": false,
#   "reasoning": "The entry fails the 'Technical Need & Outcome' criterion as it lacks specific technical solutions or capabilities needed to achieve the described results. While it mentions leveraging Microsoft 365 to enhance collaboration, communication, and provide a digital environment, it is too vague and does not describe actionable goals or concrete needs tied to Microsoft 365 tools. Additionally, it uses broad business jargon rather than specific, clear requirements."
# }
# 8
# he customer's organization focuses on supporting women who have been victims of gender-based violence. Since the customer is a small non-profit business, she is looking to be 100% connected with her customers by updating them about their programs and meetings. Goal captured save time and money. {
#   "valid": false,
#   "reasoning": "The entry lacks clarity and specificity (Criteria C) since it does not describe a clear, actionable technical need tied to Microsoft 365 capabilities (Criteria B). While the organization desires to connect more effectively with customers, the entry does not specify what technical solution or tool is needed (Criteria A), nor is there a concrete method described for achieving the 'time and money savings' goal. As such, it fails the core requirements."
# }
# 9
# Cx has a technology company specialized in manufacturing many types of electrical machines, like food industry machines and medical machines. Cx spends too much time in meetings with clients discussing the status of the orders and discussing the payment for the purchased machines. Cx needs a tool to store the catalogues of machines and share it with clients. {
#   "valid": true,
#   "reasoning": "This entry specifies a technical need (a tool to store and share machine catalogs) tied to a business outcome (reducing time spent in meetings with clients discussing order statuses and payment). It is actionable with Microsoft 365 solutions, such as SharePoint or OneDrive, which allow for catalog storage and sharing, and it is clear and specific. Additionally, it aligns with Collaboration Improvement (D) and Process Optimization (F), as sharing catalogs with clients reduces repetitive meetings and improves communication."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# The customer, who owns a transport business, requires centralizing the management of network resources, user accounts, and permissions, making it easier to administer and secure the transport business's IT environment. This will ultimately support the business's operations run smoothly {
#   "valid": true,
#   "reasoning": "The entry meets all core criteria. A: It specifies the technical need (centralized management of network resources, user accounts, and permissions) and ties it to a business outcome (smooth operations of the transport business). B: Microsoft 365 technologies like Azure Active Directory, Intune, and Microsoft Entra are capable of addressing this need. C: The entry is clear and specific, describing a concrete requirement. Additionally, it aligns with H (Data Management) and G (Integration) for handling permissions and accounts across IT resources."
# }
# 1
# Customer made me understand that the reason he signed up for the Microsoft 365 was because he needed to save time and money as GoDaddy was charging her al for just email service , and knowing that Microsoft will provider her email service and also provides her other services, emails service and the Microsoft application and a lower cost, this made her to sign up for the Microsoft 365 Business subscription. {
#   "valid": false,
#   "reasoning": "The entry lacks specific technical needs tied to a business outcome. While it mentions saving time and money as a motivation for signing up for Microsoft 365, it does not outline any actionable requirement or goal that can be addressed with Microsoft 365 capabilities. Additionally, it is too vague and does not describe a particular job-to-be-done, failing A, C, and B."
# }
# 2
# Save time and money. Customer applied for EDU pricing to be able to acquire Office 365 A3 for the users to use Office desktop apps with a discounted price. {
#   "valid": false,
#   "reasoning": "The entry fails criteria A (Technical Need & Outcome) because it does not specify a technical solution or capability aligned with a specific business outcome. It also fails criteria B (M365 Actionable) as it does not describe a tangible or actionable need for Microsoft 365 tools beyond acquiring a discounted pricing tier. Additionally, the entry lacks clarity and specificity (criterion C) and is too vague to evaluate its alignment with any Additional Criteria."
# }
# 3
# Customer is a business owner who runs a service of consulting and providing technological  consultation to assist both  small scale and  business and offers different  solutions  business after the assessment of customer business and request needs,  {
#   "valid": false,
#   "reasoning": "The entry lacks specificity and clarity (criteria C) regarding the technical need and desired business outcome (criteria A). It does not describe a concrete or actionable need tied to Microsoft 365 solutions (criteria B). The wording is too vague and does not specify any particular job-to-be-done or M365 capabilities that can assist their business goal."
# }
# 4
# Customer wants to save time and cut costs by using OneDrive for easy file sharing and syncing across devices. This will improve document access and collaboration with clients. {
#   "valid": true,
#   "reasoning": "The entry specifies a technical need (OneDrive for file sharing and syncing across devices) and clearly links it to business outcomes (saving time, cutting costs, improving document access, and enhancing collaboration with clients). It is actionable with Microsoft 365, specifically OneDrive, and aligns with criteria for Collaboration Improvement (D) and Process Optimization (F)."
# }
# 5
# The client operates a Nonprofit charitable trust he aims to setup emails on his phone to engage with clients through the use of a professional email address using his primary domain name. {
#   "valid": true,
#   "reasoning": "The entry meets core criteria A, B, and C. It specifies a technical need (set up professional email on a phone using a primary domain) and ties it to a business outcome (engaging with clients professionally). The goal is actionable with Microsoft 365, particularly with Exchange Online and mobile email integration. Additionally, it meets criterion I as it supports mobile productivity and remote setup needs for communication."
# }
# 6
# The customer sought assistance from Copilot to create a custom signature in the Exchange Admin Center. However, they did not receive the exact steps for inserting an image correctly on the first attempt. This led the admin to raise a support request for further help. Additionally, Copilot did not mention that the image should be uploaded online first, which added to the confusion. {
#   "valid": false,
#   "reasoning": "The entry fails to meet the core criteria. While it describes a specific scenario related to Copilot's usage in the Exchange Admin Center, the entry does not clearly state a specific business goal or technical need tied to a desired business outcome (criterion A). The issue presented primarily points to a support challenge and lacks clarity on how this would utilize Microsoft 365 solutions to achieve a distinct objective. Furthermore, it is more focused on a troubleshooting instance rather than articulating an actionable goal or improvement."
# }
# 7
# The customer who operates a business leasing ISO tank container, aims to set up 5 additional business emails to enhance communication, streamline operations, and support business growth. {
#   "valid": true,
#   "reasoning": "The entry specifies a technical need (setting up 5 additional business emails) and ties it to clear business outcomes (enhancing communication, streamlining operations, and supporting business growth). This is actionable within Microsoft 365, particularly using services like Exchange Online in M365. It meets criteria A, B, C and D as it enhances collaboration and communication within the business."
# }
# 8
# I learned that customer business is daycare, the business needs of the customer is having OneDrive for storage and sharing files and Office Apps to access existing documents to drive existing projects planning execution. {
#   "valid": true,
#   "reasoning": "The entry meets all core criteria: A (Technical Need & Outcome) as it specifies the need for OneDrive for file storage/sharing and Office Apps for accessing documents, both tied to the business outcome of driving project planning and execution; B (M365 Actionable) as OneDrive and Office Apps are Microsoft 365 solutions; and C (Clarity & Specificity) as it clearly specifies the tools and their purpose. Additionally, it aligns with criteria D (Collaboration Improvement) and I (Mobile/Remote Support) as it supports file sharing and access across team members in a cloud-based environment."
# }
# 9
# The customer explained that the main reason for subscribing to use Microsoft word and excel. They relay on excel primarily for creating and managing invoices, while word is used to create various documents. This combination of tools helps the customer streamline their workflow by organizing important data in a clear and structured way. It ensures they can easily access and manage their information, keeping everything orderly and readily available for a quick reference of further use {
#   "valid": false,
#   "reasoning": "While this entry specifies a technical solution (Excel for invoices and Word for document creation) and suggests a general business outcome (streamlined workflow), it fails to meet the clarity and specificity requirement (C). The goal is too broad and doesn't describe a specific need or actionable improvement tied to Microsoft 365 capabilities. It also does not sufficiently align with any additional criteria, as the functionality described is basic tool usage without detailing a specific enhancement or pain point for improvement."
# }
# 104.88702273368835
# /var/folders/xv/5lp8ff8s7j55zh1lrpr9ddkw0000gn/T/ipykernel_43699/1785463729.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_store = pd.concat([results_store, new_results_row], ignore_index=True)

# %%
test_results
# Out:
#               test_name  sensitivity  precision  f1_score
# 0  detailed_few_shot_20          0.7   0.583333  0.636364

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store, true_positives, true_negatives, false_positives, false_negatives):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                try:
                    llm_res = json.loads(llm_res)
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON: {e}, moving to next case")  # Log the error
                    next
                    
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
# print test results store
