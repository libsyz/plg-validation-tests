# %% [markdown]
# # Product Insight Validation Using LLMs: Copilot Insights🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies and prompts for validating Copilot Insights using a Large Language Model (LLM). The goal is to have a sandbox where we can fine-tune prompts using the same cross validation sets.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing business goals for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key

# %% [markdown]
# # 1 - Load Copilot Insights
#
# Let's take a glimpse at the data we have. All these business goals have been validated by human validators during the month of April '25
#
# These datasets will act as makeshift cross-validation sets, that we can use to test the performance of different prompting strategies and approaches.
#
#
# We have two datasets:
#
# - A small set of 20 cases ( 10 valid, 10 invalids ) for quick experimentation
# - A bigger set of 200 cases ( 100 valid, 100 invalids ) for testing and measuring results

# %%
# We load all the data 

copilot_insights_20 = pd.read_csv('./cases/copilot_insights_cv20.csv')
copilot_insights_200 = pd.read_csv('./cases/copilot_insights_cv200.csv')

# Now let's print one of the datasets to see its shape

copilot_insights_20[:5]
# Out:
#       ID       Case Number                                 UPN  \
# 0  28342  2503270010002818  gig_wfh_kuman@microsoftsupport.com
# 1  28799  2504080010002339  gig_wfh_joqui@microsoftsupport.com
# 2  25766       2,50329E+15  gig_wfh_shtal@microsoftsupport.com
# 3  27427  2504060040000137  gig_wfh_naric@microsoftsupport.com
# 4  26643  2504040030001743  gig_wfh_rapan@microsoftsupport.com
#
#             Line Of Business  \
# 0  Business Advisor Reactive
# 1  Business Advisor Reactive
# 2            Business Assist
# 3  Business Advisor Reactive
# 4            Business Assist
#
#                                     Copilot Insights  \
# 0  Based on my conversation it would benefit the ...
# 1  The customer mentioned Copilot for outlook can...
# 2  The customer, an engineering firm specializing...
# 3  He mentioned that likes using Copilot to compa...
# 4  The user highlighted that they are unable to u...
#
#    Copilot Insights Validation  \
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
#
#                             Copilot Insights Comment
# 0                           Validate Copilot Insight
# 1                                              Valid
# 2  Valid, customer experiences regarding the usab...
# 3                              Valid copilot insight
# 4                                   Insight is valid

# %%
# Column explanation
data = [
    ["Copilot Insights", "Raw Copilot Insights captured by the ambassador as they figure in the tracker"],
    ["Copilot Insights Validation", "Validation done by a human validator - 0 is invalid, 1 is valid"],
    ["Copilot Insights comment", "Comment/Explanation provided by a human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                    Column Name  \
# 0             Copilot Insights
# 1  Copilot Insights Validation
# 2     Copilot Insights comment
#
#                                                                      Explanation
# 0  Raw Copilot Insights captured by the ambassador as they figure in the tracker
# 1                Validation done by a human validator - 0 is invalid, 1 is valid
# 2                              Comment/Explanation provided by a human validator

# %% [markdown]
# ## 1.1 Defining Performance
#
# These 2 datasets have already been evaluated by human validators.
#
# This means we can use the previous labels to calculate Sensitivity, Recall and F1 for this dataset, which will give us performance metrics we can analyse and optimise. We will be looking at the following metrics.
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$

# %% [markdown]
# We will create a dataframe where we will store the results of our tests as we run them.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])


test_results
# Out:
# Empty DataFrame
# Columns: [test_name, sensitivity, precision, f1_score]
# Index: []

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "The feedback highlights a usability issue—the app's menu is convoluted, crowded with icons, and hard to read. This directly impacts the ease of use and navigability of the application."
# }
# ```

# %% [markdown]
# The model is giving us back a JSON wrapped in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "The feedback highlights a usability issue—the app's menu is convoluted, crowded with icons, and hard to read. This directly impacts the ease of use and navigability of the application."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through the rows of one of our datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the entry
#     - 2. Evaluate if the LLM did a good job or not
#           - LLM => Valid, Human => Valid, then *true positive*
#           - LLM => Invalid, Human => Invalid, then *true negative*
#           - LLM => Valid, Human => Invalid, then *false positive*
#           - LLM => Invalid, Human => Valid, then *false negative*
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store, dataset):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for index, row in dataset.iterrows():
        # avoid token limit if needed every 10 rows 
        print(row_counter)
        if row_counter >= 10:
            print(f"Rate limit is close, continuing in {60} seconds...")
            time.sleep(61)
            row_counter = 0
                
        llm_res = send_prompt(prompt, row['Copilot Insights'])
        llm_res = clean_llm_response(llm_res)
        row_counter += 1
        print(row['Copilot Insights'],llm_res)

        try:
            llm_res = json.loads(llm_res)
        except json.JSONDecodeError as e:
            print(f"[WARN] Failed to parse LLM response as JSON: {e}")
            continue

        human_validation = row['Copilot Insights Validation']
        if llm_res['valid'] == True and human_validation == 1:
            tp += 1
        elif llm_res['valid'] == False and human_validation == 0:
            tn += 1
        elif llm_res['valid'] == True and human_validation == 0:
            fp += 1
        elif llm_res['valid'] == False and human_validation == 1:
            fn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Loose Zero Shot Prompt
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe high level criteria that is frequently mentioned by human validators to mark insights as valid or invalid. These are drawn from analysing the reasons as to why validators mark insights as valid or invalid.

# %%
loose_zero_shot_prompt = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Set 1: Valid Business Goals Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Copilot Relevance: The feedback must clearly relate to the Copilot product—its performance, features, or experience.

    - B) Specificity: The entry should include specific and concrete observations, experiences, or suggestions related to Copilot.

    - C) Actionability: The feedback should be useful for improving Copilot, such as identifying enhancement opportunities, accuracy issues, pricing concerns, or deployment barriers.

## Set 2: Invalid Business Goal Criteria

Meeting any of the criteria below is enough for the entry to be considered invalid Copilot feedback.

    - D) No Copilot Experience: The customer has not used Copilot or is unaware of it.

    - E) Vague or Generic Feedback: The feedback lacks detail or does not describe specific aspects of Copilot.

    - F) Ambassador-Originated: The feedback comes from an ambassador, not the customer themselves.

    - G) Not Actionable: The entry does not provide enough information to derive improvements or insights.

    - H) No Real Feedback: The entry does not include any actual feedback, feature request, or deployment blocker.

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
# Test Loose Zero Shot Prompt here (test_name, prompt, results_store, dataset)
test_results = analyse_test_prompt('loose_zero_shot_20', loose_zero_shot_prompt, test_results, copilot_insights_20)
# Out:
# 0
# Based on my conversation it would benefit the customer if copilot comes free of usage for the first week of a new account to get users hooked on using AI with their work flow. {
#   "valid": true,
#   "reasoning": "The entry is valid because it clearly relates to the Copilot product (A: Copilot Relevance), provides a specific suggestion—introducing a free usage trial for a week (B: Specificity), and the suggestion is actionable as it identifies an enhancement opportunity aimed at improving adoption and user engagement (C: Actionability)."
# }
# 1
# The customer mentioned Copilot for outlook can have a feature for end users where they can have text to image so the emails can be personalized with the ideas of the moment {
#   "valid": true,
#   "reasoning": "The entry meets all of the valid business goals criteria. It is clearly related to Copilot (Criteria A), specifically identifies a feature suggestion related to email personalization (Criteria B), and provides actionable feedback by suggesting text-to-image functionality for Copilot in Outlook (Criteria C)."
# }
# 2
# The customer, an engineering firm specializing in human-machine interfaces, uses Copilot AI to streamline email drafting and enhance efficiency. They are curious about the sources of information Copilot relies on, aiming to ensure the reliability and accuracy of its content. With Copilot automating tasks like drafting emails, creating presentations, and managing schedules, the customer benefits from improved productivity, secure workflows, and seamless communication {
#   "valid": false,
#   "reasoning": "The entry does not provide specific feedback, issues, or suggestions regarding Copilot. It is descriptive but lacks concrete observations or actionable insights (criteria B and C). Additionally, the inquiry about Copilot's sources of information is curiosity-based rather than directly addressing a feature, experience, or actionable improvement opportunity (criteria G)."
# }
# 3
# He mentioned that likes using Copilot to compare two product specifications. For example, dimension and prices. He also uses Copilot for Office applications and used it to write a letter. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria under Set 1: Valid Business Goals Criteria. It is relevant to Copilot (Criterion A), provides specific use cases of comparing product specifications and using Copilot for Office applications (Criterion B), and suggests areas of strength that can be enhanced further, like improving those experiences (Criterion C)."
# }
# 4
# The user highlighted that they are unable to upload images with the free version of Copilot chat and suggested that it would be beneficial if Microsoft could consider a solution for this, as it would significantly enhance their business productivity by enabling better visual communication and documentation. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for Valid Business Goals Criteria. It is clearly related to Copilot's features (A: Copilot Relevance), provides specific details about the inability to upload images in the free version (B: Specificity), and suggests an actionable enhancement opportunity to improve business productivity by enabling image uploads (C: Actionability)."
# }
# 5
# The customer shared that while some users are ready to use Copilot, she is hesitant due to previous experiences with inaccurate responses and unsatisfactory AI learning. She hopes for improvements and plans to reconsider using Copilot in the future. {
#   "valid": true,
#   "reasoning": "This entry is valid based on Set 1 criteria. It clearly relates to Copilot and its experience (Criterion A: Copilot Relevance). The feedback is specific, mentioning inaccuracies and unsatisfactory AI learning (Criterion B: Specificity). Moreover, it is actionable as it highlights areas—accuracy and AI learning—that need improvement (Criterion C: Actionability)."
# }
# 6
# Customer mentioned he has tried copilot in teams meeting to create comprehensive meeting notes, it would be beneficial if Copilot could provide more customizable summary options to cater to different meeting formats and preferences. {
#   "valid": true,
#   "reasoning": "The entry meets the Valid Business Goals Criteria. It mentions specific use of Copilot in Teams meetings, making the feedback related to Copilot's performance and features (criteria A). The suggestion for more customizable summary options is specific and concrete (criteria B). Additionally, this feedback is actionable as it identifies a potential enhancement to improve Copilot (criteria C)."
# }
# 7
#  Cx finds Copilot quite easy to use and straightforward with an interactive user interface and accurate insights. {
#   "valid": false,
#   "reasoning": "The feedback mentions that Copilot is easy to use and straightforward with an interactive interface and accurate insights, but it lacks specificity (Criterion B) and actionability (Criterion C). There are no concrete observations, experiences, or suggestions provided that could be used to improve Copilot. This makes the feedback vague or generic (Criterion E)."
# }
# 8
# The customer mentioned that Copilot's ability to suggest Power Automate workflows is limited. Enhancing Copilot to create baseline workflows based on user descriptions, such as "send email," "attach files to email," and "look through a list of clients," would improve its usability. {
#   "valid": true,
#   "reasoning": "The entry is valid according to the criteria under Set 1 for Valid Business Goals. It meets criteria A (Copilot Relevance) by discussing Copilot's ability to suggest Power Automate workflows. It fulfills criteria B (Specificity) by providing concrete feedback and examples such as 'send email,' 'attach files to email,' and 'look through a list of clients.' Lastly, it satisfies criterion C (Actionability) as it identifies enhancement opportunities and suggests ways to improve Copilot's functionality."
# }
# 9
# During our conversation, the customer mentioned that Copilot's feature of creating PowerPoint presentations from files will be very useful for his business, as it saves time on creating presentations. He is also interested in exploring other potential benefits of Copilot to enhance his business operations. This feedback highlights the value of Copilot's time-saving features for startups. {
#   "valid": false,
#   "reasoning": "The feedback lacks specificity and actionable suggestions about Copilot. While the customer acknowledges the potential usefulness of Copilot in creating PowerPoint presentations, it does not include concrete observations or specific experiences related to using the feature. Additionally, the mention of exploring other benefits is too vague for actionable insights, violating criteria B (Specificity) and C (Actionability)."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Customer mentioned that he never used Copilot before. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it meets the 'No Copilot Experience' criterion (D). The customer has not used Copilot and therefore cannot provide actionable feedback or observations related to the product."
# }
# 1
# Copilot Feedback:
#
# Cst shared the below Feedback about MS365 Copilot:
#
# Copilot's advanced analytics capabilities, such as predictive modeling and trend analysis, will provide us with deeper insights into our data, which will help us a lot in our daily work.   {
#   "valid": false,
#   "reasoning": "The feedback appears positive but lacks specificity (Criteria E). While it mentions potential benefits like predictive modeling and trend analysis, it does not offer specific observations, experiences, or suggestions about Copilot's actual performance, features, or experience (Criteria B). Additionally, there is no actionability as it does not suggest improvements or identify issues (Criteria G)."
# }
# 2
# Informed the customer about Copilot, explaining its uses and benefits. Highlighted how Copilot can assist with various tasks, including productivity, support, and information synthesis. Emphasized Copilot's ability to streamline processes, improve efficiency, and provide timely support. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it does not include actual feedback from the customer about their experience with Copilot (criterion D). It appears to be an ambassador's description or promotional effort rather than the customer's specific observations or actionable feedback (criterion F)."
# }
# 3
# Customer is planning to get it with new fiscal year {
#   "valid": false,
#   "reasoning": "The entry is invalid because it meets criterion D (No Copilot Experience). The customer has not used Copilot yet and is merely planning to get it in the future, which does not provide actionable or specific feedback about the product."
# }
# 4
# The customer mentioned Copilot in Outlook will impact their customers workflow and improve overall performance due to emails are being created by an AI on a daily basis and with this he can focus on other tasks  {
#   "valid": true,
#   "reasoning": "The entry is valid as it meets all the criteria under Set 1: Valid Business Goals Criteria. It clearly relates to the Copilot product's performance and experience (A - Copilot Relevance), provides specific observations about the use of Copilot in Outlook for improving workflows and creating emails daily (B - Specificity), and highlights actionable insights about how Copilot enables users to focus on other tasks (C - Actionability)."
# }
# 5
# As per the customer manual processes provide a sense of control, and some users prefer traditional methods over automation. {
#   "valid": false,
#   "reasoning": "The entry fails Set 1 criteria as it does not specifically relate to Copilot's performance, features, or experience (A). Moreover, it lacks specificity and does not include actionable feedback regarding Copilot (B and C). It meets Invalid Business Goal Criteria E and G because the feedback is vague, generic, and not actionable about improving Copilot."
# }
# 6
# Customer mentioned that he have a commercial department team, that includes two people, and they are currently using shared mailbox to communicate with customer as that helps save money, the customer is wondering if Microsoft can make possible to assign the license to that shared mailbox or group, so the entire team can leverage on it. {
#   "valid": false,
#   "reasoning": "The feedback does not clearly relate to Copilot's performance, features, or experience, failing Copilot Relevance (Criteria A). It is more focused on licensing and shared mailbox usage rather than specific observations or suggestions about Copilot. Therefore, it does not meet Set 1 requirements and falls under Invalid Criteria G as it is not actionable in terms of improving Copilot."
# }
# 7
# Customer was unaware of Copilot and after some Demo he realized that he has access to Microsoft 365 Copilot and that it is similar to Chat GPT. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it meets criteria D (No Copilot Experience). The customer was unaware of Copilot prior to the demo and no specific feedback related to Copilot's performance, features, or experience is provided."
# }
# 8
# The user doesn't know Copilot and never user it. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it meets Criterion D (No Copilot Experience) from the Invalid Business Goal Criteria. The user has not used Copilot or is unaware of it."
# }
# 9
# Deepseek offer multiple possible solutions and explanation where Copilot dont offer that which is a big challenge for users who do research {
#   "valid": true,
#   "reasoning": "The feedback is valid because it meets all Set 1 criteria: A) it clearly relates to Copilot's product features, specifically its inability to offer multiple solutions and explanations; B) it provides specific and concrete observations about what Copilot lacks; and C) it is actionable, as it identifies an enhancement opportunity for improving the Copilot user experience by addressing this challenge."
# }
# 98.57699298858643

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          0.7   0.777778  0.736842
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.750000  0.818182

# %% [markdown]
# Ha dado como resultado:
#
# sensitivity: 0.8
# precision: 0.888889
# f1_score: 0.842105

# %%
loose_zero_shot_no_negative_criteria = '''

You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Valid Copilot Insights Criteria

Meeting any of the criteria below is enough for the entry to be considered invalid Copilot feedback.

    - A) No Copilot Experience: The customer has not used Copilot or is unaware of it.

    - B) Vague or Generic Feedback: The feedback lacks detail or does not describe specific aspects of Copilot.

    - C) Ambassador-Originated: The feedback comes from an ambassador, not the customer themselves.

    - D) Not Actionable: The entry does not provide enough information to derive improvements or insights.

    - E) No Real Feedback: The entry does not include any actual feedback, feature request, or deployment blocker.

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('loose_zero_shot_20_no_negative_criteria', loose_zero_shot_no_negative_criteria, test_results, copilot_insights_20)
# Out:
# 0
# Based on my conversation it would benefit the customer if copilot comes free of usage for the first week of a new account to get users hooked on using AI with their work flow. {
#   "valid": true,
#   "reasoning": "The entry includes a specific feature request related to Copilot—making it free for the first week of a new account which could benefit user adoption. This provides actionable feedback relevant to Copilot insights."
# }
# 1
# The customer mentioned Copilot for outlook can have a feature for end users where they can have text to image so the emails can be personalized with the ideas of the moment {
#   "valid": true,
#   "reasoning": "The entry includes a specific feature request (text-to-image functionality) that could improve Copilot for Outlook by enabling personalized emails. It provides actionable feedback and is specific enough to offer insights for improvement."
# }
# 2
# The customer, an engineering firm specializing in human-machine interfaces, uses Copilot AI to streamline email drafting and enhance efficiency. They are curious about the sources of information Copilot relies on, aiming to ensure the reliability and accuracy of its content. With Copilot automating tasks like drafting emails, creating presentations, and managing schedules, the customer benefits from improved productivity, secure workflows, and seamless communication {
#   "valid": true,
#   "reasoning": "The entry describes the customer's specific usage of Copilot AI—such as streamlining email drafting, automating presentations, and managing schedules. Additionally, their curiosity about the sources of information Copilot uses reflects actionable feedback or insights that could help improve the product's transparency and accuracy, ensuring it aligns with customer trust and reliability concerns. Thus, the entry contains detailed and actionable feedback."
# }
# 3
# He mentioned that likes using Copilot to compare two product specifications. For example, dimension and prices. He also uses Copilot for Office applications and used it to write a letter. {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback on how the customer uses Copilot to compare product specifications and in Office applications, including writing a letter. This feedback is detailed and actionable."
# }
# 4
# The user highlighted that they are unable to upload images with the free version of Copilot chat and suggested that it would be beneficial if Microsoft could consider a solution for this, as it would significantly enhance their business productivity by enabling better visual communication and documentation. {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback about a limitation in the free version of Copilot chat (inability to upload images) and includes actionable insights (a suggestion for Microsoft to address this issue to enhance business productivity). Therefore, it meets the criteria for valid Copilot feedback."
# }
# 5
# The customer shared that while some users are ready to use Copilot, she is hesitant due to previous experiences with inaccurate responses and unsatisfactory AI learning. She hopes for improvements and plans to reconsider using Copilot in the future. {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback regarding the customer's hesitance in using Copilot due to previous experiences with inaccurate responses and unsatisfactory AI learning. This makes it detailed and actionable as it reveals areas for improvement and the customer's eventual willingness to reconsider using Copilot."
# }
# 6
# Customer mentioned he has tried copilot in teams meeting to create comprehensive meeting notes, it would be beneficial if Copilot could provide more customizable summary options to cater to different meeting formats and preferences. {
#   "valid": true,
#   "reasoning": "The entry is valid because the customer has used Copilot in Teams meetings, described a specific use case (creating comprehensive meeting notes), and provided actionable feedback by requesting more customizable summary options to cater to different meeting formats and preferences."
# }
# 7
#  Cx finds Copilot quite easy to use and straightforward with an interactive user interface and accurate insights. {
#   "valid": false,
#   "reasoning": "The entry is invalid as it falls under the 'Vague or Generic Feedback' (Criterion B). While the customer mentions that Copilot is easy to use and provides accurate insights, the feedback lacks specific details or actionable insights to improve the product."
# }
# 8
# The customer mentioned that Copilot's ability to suggest Power Automate workflows is limited. Enhancing Copilot to create baseline workflows based on user descriptions, such as "send email," "attach files to email," and "look through a list of clients," would improve its usability. {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback about Copilot's limitations in suggesting Power Automate workflows and includes actionable suggestions to improve the functionality by creating baseline workflows based on user descriptions."
# }
# 9
# During our conversation, the customer mentioned that Copilot's feature of creating PowerPoint presentations from files will be very useful for his business, as it saves time on creating presentations. He is also interested in exploring other potential benefits of Copilot to enhance his business operations. This feedback highlights the value of Copilot's time-saving features for startups. {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback about Copilot's feature of creating PowerPoint presentations from files and its time-saving benefits for the customer's business, which makes it actionable and detailed. It does not fall under any of the invalid Copilot Insights criteria."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Customer mentioned that he never used Copilot before. {
#   "valid": false,
#   "reasoning": "The entry is invalid as it meets criterion A: No Copilot Experience. The customer has not used Copilot or is unaware of it."
# }
# 1
# Copilot Feedback:
#
# Cst shared the below Feedback about MS365 Copilot:
#
# Copilot's advanced analytics capabilities, such as predictive modeling and trend analysis, will provide us with deeper insights into our data, which will help us a lot in our daily work.   {
#   "valid": true,
#   "reasoning": "The feedback is specific and actionable, describing particular aspects of Copilot's functionality (predictive modeling and trend analysis) and how they can be beneficial (providing deeper insights into data to improve daily work). This makes the entry valid according to the criteria."
# }
# 2
# Informed the customer about Copilot, explaining its uses and benefits. Highlighted how Copilot can assist with various tasks, including productivity, support, and information synthesis. Emphasized Copilot's ability to streamline processes, improve efficiency, and provide timely support. {
#   "valid": false,
#   "reasoning": "The entry is invalid as it falls under criterion A) No Copilot Experience. The customer has not provided feedback or demonstrated experience with Copilot. The entry only describes the ambassador's explanation of Copilot, not actionable insights or actual feedback."
# }
# 3
# Customer is planning to get it with new fiscal year {
#   "valid": false,
#   "reasoning": "The entry is invalid because it falls under criteria A: No Copilot Experience. The customer has not used Copilot yet and is only planning to get it in the future. Therefore, no actual feedback has been provided."
# }
# 4
# The customer mentioned Copilot in Outlook will impact their customers workflow and improve overall performance due to emails are being created by an AI on a daily basis and with this he can focus on other tasks  {
#   "valid": true,
#   "reasoning": "The entry describes specific aspects of Copilot in Outlook, including its impact on workflow, performance, and the automatic generation of emails allowing for task prioritization. It is actionable and detailed feedback."
# }
# 5
# As per the customer manual processes provide a sense of control, and some users prefer traditional methods over automation. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it does not provide real feedback specific to Copilot (Criteria E). It discusses a general preference for manual processes and traditional methods, but there is no actionable or Copilot-specific feedback mentioned."
# }
# 6
# Customer mentioned that he have a commercial department team, that includes two people, and they are currently using shared mailbox to communicate with customer as that helps save money, the customer is wondering if Microsoft can make possible to assign the license to that shared mailbox or group, so the entire team can leverage on it. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it does not include any actual feedback, deployment blocker, or feature request related to Copilot specifically. Hence, it falls under criterion E (No Real Feedback)."
# }
# 7
# Customer was unaware of Copilot and after some Demo he realized that he has access to Microsoft 365 Copilot and that it is similar to Chat GPT. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it falls under criteria A (No Copilot Experience). The customer was unaware of Copilot and therefore did not provide feedback based on actual usage or experience."
# }
# 8
# The user doesn't know Copilot and never user it. {
#   "valid": false,
#   "reasoning": "The entry falls under Criterion A (No Copilot Experience) because the user has not used Copilot or is unaware of it."
# }
# 9
# Deepseek offer multiple possible solutions and explanation where Copilot dont offer that which is a big challenge for users who do research {
#   "valid": true,
#   "reasoning": "The entry provides specific feedback comparing Copilot to Deepseek, noting a challenge in Copilot's functionality (not offering multiple solutions and explanations). This is actionable and gives insight into a potential improvement for Copilot."
# }
# 96.89806008338928

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          0.8   0.888889  0.842105
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.750000  0.818182

# %% [markdown]
# Ha dado como resultado:
#
# sensitivity: 0.9
# precision: 0.75
# f1_score: 0.818182

# %% [markdown]
# ### 3.2 Detailed Zero Shot Prompt
#
# In the prompt below, we provide a detailed list of criteria based on the latest version of the insights framework available at GigPlus. This has a detailed set of tiered criteria.

# %%
detailed_zero_shot_prompt = '''
You're an AI assistant that reviews Microsoft 365 Copilot Product Feedback to ensure it provides actionable insights for product improvement. Valid feedback should be specific, relevant to Copilot, and help Microsoft refine the product based on real user experience.
 
What Makes Strong Copilot Feedback?
✅ Mentions a specific Copilot feature or aspect - Feedback should focus on a particular functionality, not general comments. ✅ Explains how the feature impacts business goals - How does it support or fail to meet customer needs? ✅ Describes user experience or workflow impact - Does it affect productivity, efficiency, or satisfaction? ✅ Provides actionable details - Can the product team investigate or improve based on this feedback?
 
When is Feedback Invalid?
❌ Customer hasn't used Copilot or is unaware of it - Feedback should come from real experience. ❌ Too generic or vague - It doesn't specify Copilot features or effects. ❌ Ambassador recommendation, not customer feedback - Feedback should come from users, not internal suggestions. ❌ Lack of actionable details - If it doesn't help Microsoft refine Copilot, it's invalid. ❌ No actual feedback or request - Entries must provide a real issue, feature request, or usability concern.

## Response ##

You will respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('detailed_zero_shot', detailed_zero_shot_prompt, test_results, copilot_insights_20)
# Out:
# 0
# Based on my conversation it would benefit the customer if copilot comes free of usage for the first week of a new account to get users hooked on using AI with their work flow. {
#   "valid": false,
#   "reasoning": "This feedback does not come from a real user experience or actual usage of Copilot. Instead, it is a recommendation about pricing strategy or onboarding incentives, which falls outside of actionable feedback related to refining specific features in Copilot. Additionally, it lacks details about functional aspects, impact on workflows, or productivity."
# }
# 1
# The customer mentioned Copilot for outlook can have a feature for end users where they can have text to image so the emails can be personalized with the ideas of the moment {
#   "valid": true,
#   "reasoning": "The feedback is specific and mentions a Copilot feature for Outlook, suggesting a text-to-image capability to enhance email personalization. It identifies a potential improvement that can be implemented and relates to user experience and creativity, making the feedback actionable for the product team."
# }
# 2
# The customer, an engineering firm specializing in human-machine interfaces, uses Copilot AI to streamline email drafting and enhance efficiency. They are curious about the sources of information Copilot relies on, aiming to ensure the reliability and accuracy of its content. With Copilot automating tasks like drafting emails, creating presentations, and managing schedules, the customer benefits from improved productivity, secure workflows, and seamless communication {
#   "valid": false,
#   "reasoning": "The feedback describes how the customer uses Copilot and the benefits they derive from it, but it does not articulate any specific feature, usability concern, or actionable feedback tied to Copilot's functionality. While their curiosity about sources of information is relevant, it does not provide enough actionable detail to refine or improve Copilot."
# }
# 3
# He mentioned that likes using Copilot to compare two product specifications. For example, dimension and prices. He also uses Copilot for Office applications and used it to write a letter. {
#   "valid": true,
#   "reasoning": "The feedback is valid because it mentions specific Copilot features, such as comparing product specifications and writing a letter within Office applications. This provides actionable insights into how the features are used and can help the product team understand practical use cases to improve functionality or user experience."
# }
# 4
# The user highlighted that they are unable to upload images with the free version of Copilot chat and suggested that it would be beneficial if Microsoft could consider a solution for this, as it would significantly enhance their business productivity by enabling better visual communication and documentation. {
#   "valid": true,
#   "reasoning": "The feedback is valid because it mentions a specific Copilot feature limitation (inability to upload images in the free version of Copilot chat). It explains how addressing this limitation would impact business goals by enhancing visual communication and documentation, which could improve productivity. The suggestion provides actionable details that the product team could investigate or address."
# }
# 5
# The customer shared that while some users are ready to use Copilot, she is hesitant due to previous experiences with inaccurate responses and unsatisfactory AI learning. She hopes for improvements and plans to reconsider using Copilot in the future. {
#   "valid": false,
#   "reasoning": "The feedback does not come from actual use of Copilot. The customer mentions hesitation to use the product based on previous experiences with AI in general, rather than specific experiences with Copilot. The feedback lacks actionable details about specific Copilot features or their impact on workflows."
# }
# 6
# Customer mentioned he has tried copilot in teams meeting to create comprehensive meeting notes, it would be beneficial if Copilot could provide more customizable summary options to cater to different meeting formats and preferences. {
#   "valid": true,
#   "reasoning": "The feedback directly references a specific Copilot feature (creating meeting notes in Teams) and includes actionable details about a desired improvement (customizable summary options to cater to different meeting formats and preferences). It also provides insight into how this enhancement could impact user workflow and satisfaction, making it relevant for refining the product."
# }
# 7
#  Cx finds Copilot quite easy to use and straightforward with an interactive user interface and accurate insights. {
#   "valid": false,
#   "reasoning": "The feedback is too generic and lacks actionable details. While it mentions that Copilot is easy to use and provides accurate insights, it does not specify a particular feature or workflow, nor does it describe how it impacts business goals or user experience in a meaningful way. Therefore, it does not help Microsoft refine the product."
# }
# 8
# The customer mentioned that Copilot's ability to suggest Power Automate workflows is limited. Enhancing Copilot to create baseline workflows based on user descriptions, such as "send email," "attach files to email," and "look through a list of clients," would improve its usability. {
#   "valid": true,
#   "reasoning": "The feedback mentions a specific Copilot feature—its ability to suggest Power Automate workflows—and highlights its limitation. It includes actionable insights by proposing enhancements for Copilot to create baseline workflows based on user descriptions. This feedback explains how improving this feature could increase usability and aligns with the goal of refining the product."
# }
# 9
# During our conversation, the customer mentioned that Copilot's feature of creating PowerPoint presentations from files will be very useful for his business, as it saves time on creating presentations. He is also interested in exploring other potential benefits of Copilot to enhance his business operations. This feedback highlights the value of Copilot's time-saving features for startups. {
#   "valid": false,
#   "reasoning": "The feedback mentions a potential use case for Copilot's PowerPoint creation feature and expresses general interest in exploring its benefits. However, it doesn't provide actionable details based on real user experience, specific pain points, or suggestions for improvement. Additionally, the customer appears to be discussing hypothetical value rather than actual usage of Copilot."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Customer mentioned that he never used Copilot before. {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the customer has not used Copilot before. Feedback should come from real experience to ensure it provides actionable insights for product improvement."
# }
# 1
# Copilot Feedback:
#
# Cst shared the below Feedback about MS365 Copilot:
#
# Copilot's advanced analytics capabilities, such as predictive modeling and trend analysis, will provide us with deeper insights into our data, which will help us a lot in our daily work.   {
#   "valid": false,
#   "reasoning": "The feedback is generic and future-oriented, mentioning how Copilot's capabilities 'will provide' benefits rather than describing actual user experience or workflow impact. It lacks actionable details about specific Copilot features or how they have already affected business goals or productivity. This suggests the customer may not have used Copilot yet."
# }
# 2
# Informed the customer about Copilot, explaining its uses and benefits. Highlighted how Copilot can assist with various tasks, including productivity, support, and information synthesis. Emphasized Copilot's ability to streamline processes, improve efficiency, and provide timely support. {
#   "valid": false,
#   "reasoning": "The entry does not constitute valid feedback because it does not originate from the experience of a user utilizing Copilot. It is a description or recommendation by an ambassador, explaining Copilot's benefits rather than providing actionable insights from real usage. No specific features, user experiences, or workflow impacts are mentioned for improvement."
# }
# 3
# Customer is planning to get it with new fiscal year {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the customer has not yet used Copilot and is only planning to obtain it in the future. Valid feedback must come from actual experience with the product."
# }
# 4
# The customer mentioned Copilot in Outlook will impact their customers workflow and improve overall performance due to emails are being created by an AI on a daily basis and with this he can focus on other tasks  {
#   "valid": true,
#   "reasoning": "The feedback specifically mentions Copilot in Outlook, focusing on the feature of AI-generated emails. It explains how this functionality positively impacts the user's workflow by improving performance and freeing up time to focus on other tasks. This is actionable feedback as it highlights a significant benefit of the feature and is tied to user experience and productivity."
# }
# 5
# As per the customer manual processes provide a sense of control, and some users prefer traditional methods over automation. {
#   "valid": false,
#   "reasoning": "The feedback does not mention a specific Copilot feature or functionality. It is a general comment about preference for manual processes over automation and does not provide actionable insights or describe how Copilot impacts user workflows or business goals."
# }
# 6
# Customer mentioned that he have a commercial department team, that includes two people, and they are currently using shared mailbox to communicate with customer as that helps save money, the customer is wondering if Microsoft can make possible to assign the license to that shared mailbox or group, so the entire team can leverage on it. {
#   "valid": false,
#   "reasoning": "The feedback does not pertain specifically to Microsoft 365 Copilot or its features, nor does it reflect real user experience or workflow impact with Copilot. The request is about licensing for shared mailboxes or groups, which relates to general Microsoft 365 functionality rather than Copilot performance or improvement. It provides no actionable insights for refining Copilot."
# }
# 7
# Customer was unaware of Copilot and after some Demo he realized that he has access to Microsoft 365 Copilot and that it is similar to Chat GPT. {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the customer was unaware of Copilot and has not provided any specific feedback based on real usage or experience. The statement does not mention any Copilot feature, impact on business goals, or actionable details that could help improve the product."
# }
# 8
# The user doesn't know Copilot and never user it. {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the user has not used Copilot and is unaware of it. Feedback must come from real user experience with Copilot to be considered actionable."
# }
# 9
# Deepseek offer multiple possible solutions and explanation where Copilot dont offer that which is a big challenge for users who do research {
#   "valid": false,
#   "reasoning": "The feedback is too vague and general. It does mention a limitation of Copilot related to research but does not refer to a specific Copilot feature or functionality. Additionally, it does not describe the user experience or workflow impact in detail or provide actionable insights to improve Copilot based on real usage."
# }
# 93.33685302734375
# /var/folders/xv/5lp8ff8s7j55zh1lrpr9ddkw0000gn/T/ipykernel_53985/2193324611.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_store = pd.concat([results_store, new_results_row], ignore_index=True)

# %%
test_results
# Out:
#             test_name  sensitivity  precision  f1_score
# 0  detailed_zero_shot          0.5   0.833333     0.625

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''

You are an AI assistant that validates Microsoft 365 Copilot product feedback (suggestions, bug reports, usability challenges, etc.) based on four criteria:
 
(1) Specificity - Identifies a specific feature or aspect of Copilot
(2) Alignment With Objectives - Explains how that feature supports or fails the customer's business goals
(3) Impact on Workflows or Satisfaction - Describes the effect on the user's experience or processes
(4) Actionability - Offers enough detail for the product team to investigate or make improvements

If the feedback meets these criteria, respond:
{
  "CopilotPFvalid": "Valid",
  "CopilotPFcomment": ""
}
Otherwise, respond:
{
  "CopilotPFvalid": "Invalid",
  "CopilotPFcomment": ""
}
 
### Examples:
 
• Example 1 (Valid)
“Copilot's 'Summarize Document' feature doesn't handle spreadsheets well. Our finance team needs accurate summaries for weekly budget reports. Because the data can't be summarized, we have to do it manually, wasting hours. We need Copilot to parse tables in Excel files more accurately.”
- Specific feature named.
- States the business objective (weekly budget reports).
- Describes workflow impact (manual process).
- Actionable improvement (parse Excel tables better).
 
Valid Output:
{
  "valid": true,
  "CopilotPFcomment": "Valid — Identifies feature, aligns with business needs, describes the problem's impact and calls for a fix. This is actionable."
}
 
• Example 2 (Invalid)
“Our team hates Copilot. It's just too annoying.”
- No specific feature.
- No tie to any business objective.
- Not actionable.
 
Invalid Output:
{
  "valid": false,
  "CopilotPFcomment": "Invalid — Vague feedback. Lacks specifics on what's annoying or how it hinders business goals. Not actionable from a PLG perspective; needs more detail."
}
 
## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true or false
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('detailed_few_shot_20', few_shot_prompt, test_results, copilot_insights_20)
# Out:
# 0
# Based on my conversation it would benefit the customer if copilot comes free of usage for the first week of a new account to get users hooked on using AI with their work flow. {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback suggests a promotional idea (free trial for a week) and hints at enhancing user adoption, it does not identify a specific feature or aspect of Copilot, tie the suggestion explicitly to a business objective, describe the impact on workflows or satisfaction, nor offer enough detail to make it actionable for the product team. It requires clearer alignment with product functionality and objectives."
# }
# 1
# The customer mentioned Copilot for outlook can have a feature for end users where they can have text to image so the emails can be personalized with the ideas of the moment {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback suggests a potential feature (text-to-image for personalized emails), it does not identify a specific existing feature or problem with Copilot. It also lacks alignment with business objectives, does not describe the impact on workflows or satisfaction, and is not actionable as it provides insufficient detail about the need or implementation requirements."
# }
# 2
# The customer, an engineering firm specializing in human-machine interfaces, uses Copilot AI to streamline email drafting and enhance efficiency. They are curious about the sources of information Copilot relies on, aiming to ensure the reliability and accuracy of its content. With Copilot automating tasks like drafting emails, creating presentations, and managing schedules, the customer benefits from improved productivity, secure workflows, and seamless communication {
#   "valid": false,
#   "reasoning": "Invalid — The feedback lacks specificity regarding any particular feature or aspect of Copilot. While it describes the firm's broader use of Copilot and outlines general business goals (efficiency, productivity, secure workflows), it does not identify a feature that is problematic or provides actionable suggestions. More detail is needed about how source accuracy impacts specific workflows or user satisfaction."
# }
# 3
# He mentioned that likes using Copilot to compare two product specifications. For example, dimension and prices. He also uses Copilot for Office applications and used it to write a letter. {
#   "valid": false,
#   "reasoning": "Invalid — While this feedback mentions liking Copilot for comparing specifications and writing a letter, it lacks specificity about any feature, no clear alignment with business objectives, no described impact on workflows or satisfaction, and no actionable details. More detail is needed to make this feedback useful."
# }
# 4
# The user highlighted that they are unable to upload images with the free version of Copilot chat and suggested that it would be beneficial if Microsoft could consider a solution for this, as it would significantly enhance their business productivity by enabling better visual communication and documentation. {
#   "valid": true,
#   "reasoning": "Valid — The feedback specifies a feature limitation (unable to upload images in the free version of Copilot chat), aligns with the objective of improving business productivity through visual communication, describes the impact on workflows (enhancing documentation), and suggests a potential course of action (introducing this capability)."
# }
# 5
# The customer shared that while some users are ready to use Copilot, she is hesitant due to previous experiences with inaccurate responses and unsatisfactory AI learning. She hopes for improvements and plans to reconsider using Copilot in the future. {
#   "valid": false,
#   "reasoning": "Invalid — The feedback is too general and lacks specificity. While it mentions a hesitation related to previous issues with inaccurate responses and unsatisfactory AI learning, it does not identify a specific feature or functionality, nor does it clearly tie these concerns to business objectives. The feedback is not directly actionable since no specific area for improvement is detailed."
# }
# 6
# Customer mentioned he has tried copilot in teams meeting to create comprehensive meeting notes, it would be beneficial if Copilot could provide more customizable summary options to cater to different meeting formats and preferences. {
#   "valid": true,
#   "reasoning": "Valid — The feedback is specific (Copilot in Teams meeting notes and request for customizable summary options). It aligns with business objectives (enhancing meeting productivity). It describes the impact (addresses different meeting formats and preferences to improve usefulness). The request is actionable as it calls for more flexibility in generating summaries."
# }
# 7
#  Cx finds Copilot quite easy to use and straightforward with an interactive user interface and accurate insights. {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback is positive, it lacks specificity about any particular feature or area of Copilot, provides no business objectives or workflows impacted, and does not suggest any specific action for improvement. More detail is needed to make this actionable."
# }
# 8
# The customer mentioned that Copilot's ability to suggest Power Automate workflows is limited. Enhancing Copilot to create baseline workflows based on user descriptions, such as "send email," "attach files to email," and "look through a list of clients," would improve its usability. {
#   "valid": true,
#   "reasoning": "Valid — The feedback identifies the specific feature of Copilot (suggesting Power Automate workflows). It explains how expanding functionality to create baseline workflows would align with the objective of improving usability. The impact on workflows is clear—enhanced workflow automation would save users time and improve satisfaction. Finally, it provides actionable detail by suggesting examples of baseline workflows Copilot could support."
# }
# 9
# During our conversation, the customer mentioned that Copilot's feature of creating PowerPoint presentations from files will be very useful for his business, as it saves time on creating presentations. He is also interested in exploring other potential benefits of Copilot to enhance his business operations. This feedback highlights the value of Copilot's time-saving features for startups. {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback appreciates the time-saving benefits of Copilot's PowerPoint creation feature, it lacks specificity about any challenges or areas needing improvement in the feature. Additionally, it does not describe any direct workflow impact or provide actionable suggestions for Copilot enhancements."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Customer mentioned that he never used Copilot before. {
#   "valid": false,
#   "reasoning": "Invalid — The feedback does not identify a specific feature, business objective, workflow impact, or offer actionable insights. It is observational rather than feedback that can guide product improvements."
# }
# 1
# Copilot Feedback:
#
# Cst shared the below Feedback about MS365 Copilot:
#
# Copilot's advanced analytics capabilities, such as predictive modeling and trend analysis, will provide us with deeper insights into our data, which will help us a lot in our daily work.   {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback mentions advanced analytics capabilities like predictive modeling and trend analysis, it does not identify a specific feature of Copilot, explain alignment with business objectives, describe workflow impact, or provide actionable detail for improvement. The comment is more appreciation than feedback."
# }
# 2
# Informed the customer about Copilot, explaining its uses and benefits. Highlighted how Copilot can assist with various tasks, including productivity, support, and information synthesis. Emphasized Copilot's ability to streamline processes, improve efficiency, and provide timely support. {
#   "valid": false,
#   "reasoning": "Invalid — This feedback is generic and doesn't identify a specific feature or aspect of Copilot. It does not explain how Copilot supports or fails the customer's business goals, nor does it describe any impact on workflows or satisfaction. It is not actionable because it lacks detail about any particular issue or suggestion."
# }
# 3
# Customer is planning to get it with new fiscal year {
#   "valid": false,
#   "reasoning": "Invalid — This feedback does not specify any feature or aspect of Copilot, does not tie to business objectives, does not explain any impact on workflows or satisfaction, and offers no actionable detail. It simply states a decision about acquiring Copilot without providing any feedback about the product itself."
# }
# 4
# The customer mentioned Copilot in Outlook will impact their customers workflow and improve overall performance due to emails are being created by an AI on a daily basis and with this he can focus on other tasks  {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback does mention Copilot in Outlook and potential workflow improvement, it lacks specificity regarding a particular feature or functionality of Copilot. Additionally, it does not outline what specific tasks or objectives are being streamlined or impacted, nor does it describe any challenges or issues requiring action. The feedback is too general to be actionable."
# }
# 5
# As per the customer manual processes provide a sense of control, and some users prefer traditional methods over automation. {
#   "valid": false,
#   "reasoning": "Invalid — This feedback is too general and does not specify any particular feature or aspect of Copilot. It does not tie to a business objective, describe a specific impact on workflows, or provide actionable detail for improvement. More specifics are needed to understand the user's preference for manual processes and whether it relates to Copilot's functionality."
# }
# 6
# Customer mentioned that he have a commercial department team, that includes two people, and they are currently using shared mailbox to communicate with customer as that helps save money, the customer is wondering if Microsoft can make possible to assign the license to that shared mailbox or group, so the entire team can leverage on it. {
#   "valid": false,
#   "reasoning": "Invalid — While the feedback discusses a shared mailbox and licensing concerns, it doesn't reference a specific Microsoft 365 Copilot feature. It also lacks a clear alignment with business objectives or explanation of how this issue impacts workflows or satisfaction with Copilot. The suggested improvement isn't actionable for the Copilot product team, as licensing is outside Copilot's scope."
# }
# 7
# Customer was unaware of Copilot and after some Demo he realized that he has access to Microsoft 365 Copilot and that it is similar to Chat GPT. {
#   "valid": false,
#   "reasoning": "Invalid — The feedback doesn't identify any specific feature or aspect of Copilot, doesn't explain alignment with business objectives, doesn't describe the impact on workflows or satisfaction, and lacks actionable detail for improvement. It is more of an observation than product feedback."
# }
# 8
# The user doesn't know Copilot and never user it. {
#   "valid": false,
#   "reasoning": "Invalid — The user has not provided any feedback related to Copilot's features, functionality, or user experience. No specifics, alignment with objectives, impact on workflows, or actionable insights can be assessed."
# }
# 9
# Deepseek offer multiple possible solutions and explanation where Copilot dont offer that which is a big challenge for users who do research {
#   "valid": false,
#   "reasoning": "Invalid — The feedback lacks specificity about which Copilot feature or aspect is underperforming, does not clearly state which business objective is impacted, provides no detail on workflow or user satisfaction challenges, and does not offer actionable suggestions for improvement. More detail is needed to make this feedback constructive."
# }
# 95.28036618232727

# %%
test_results
# Out:
#               test_name  sensitivity  precision  f1_score
# 0    detailed_zero_shot          0.5   0.833333  0.625000
# 1  detailed_few_shot_20          0.3   1.000000  0.461538

# %%
detailed_few_shot_v2_cot = '''
You are an AI assistant that reviews **Microsoft 365 Copilot Product Feedback** to ensure it provides actionable insights for product improvement. Valid feedback should reflect real customer experience with Copilot and help Microsoft refine the product based on specific issues, needs, or limitations.

---

## ✅ What Makes Valid Copilot Feedback?

A **Valid** entry should include:
1. **Specificity:** Clearly mentions a **specific Copilot feature or functionality** (not just “Copilot in general”).
2. **Business Relevance:** Explains how the Copilot feature supports or fails to support the **customer’s business goals or use case**.
3. **Impact:** Describes how it affects productivity, satisfaction, workflow, or decision-making.
4. **Actionability:** Gives Microsoft product teams something they could **investigate, improve, or build upon**.

---

## When Is Feedback Invalid?

Mark the entry as **Invalid** if:
- The entry says that the customer hasn’t used Copilot or isn’t aware of it
- The feedback is **generic**, vague, or lacks any specific feature
- It’s a **suggestion from an internal ambassador**, not customer feedback
- It’s missing real insight (e.g., no issue, request, or pain point)
- It lacks **actionable detail**

---

## Valid Examples

- Customer mentioned they struggle with generating high-quality email drafts using Copilot in Outlook and would like more control over tone and formality.
- Customer requested Copilot in Teams to summarize long chat threads more accurately, as sometimes key action points are missing.
- Customer reported that Copilot in Word does not always align with their company’s writing style guide when generating proposals.
- Customer asked if Copilot in PowerPoint could provide more creative slide layouts instead of just reformatting existing content to improve quality of produced content.

---

## Invalid Examples

- Copilot is an amazing tool that simplifies tasks across all Office apps
- A small business owner expressed interest in AI tools but provided vague suggestions.Copilot should be able to browse the web in real-time and fetch live news updates automatically.
- "ChatGPT provides better responses than Copilot, which feels less human-like.

---

## 🧠 Chain of Thought (How to Think Before Deciding)

- Is the feedback clearly tied to a **specific part** of Copilot?
- Does it describe the **customer's experience**, not just general praise or confusion?
- Does it show **impact** on the user’s workflow or goals?
- Could a Microsoft engineer or PM reasonably take action based on this?

If the answer is mostly “yes,” mark as **valid**. If mostly “no,” mark as **invalid**.

---

## 📦 Output Format

Do not include any of the reasoning in your response. Respond in **JSON only**, with the following fields:

```json
{
  "valid": true,
  "reasoning": "A short explanation of your reasoning."
}

'''

# %%
detailed_few_shot_v2_cot = '''
You are an AI assistant that reviews **Microsoft 365 Copilot Product Feedback** to ensure it provides actionable insights for product improvement. Valid feedback should reflect real customer experience with Copilot and help Microsoft refine the product based on specific issues, needs, or limitations.

---

## ✅ What Makes Valid Copilot Feedback?

A **Valid** entry should include:
1. **Specificity:** Clearly mentions a **specific Copilot feature or functionality** (not just “Copilot in general”).
2. **Business Relevance:** Explains how the Copilot feature supports or fails to support the **customer’s business goals or use case**.
3. **Impact:** Describes how it affects productivity, satisfaction, workflow, or decision-making.
4. **Actionability:** Gives Microsoft product teams something they could **investigate, improve, or build upon**.

---

## When Is Feedback Invalid?

Mark the entry as **Invalid** if:
- The entry says that the customer hasn’t used Copilot or isn’t aware of it
- The feedback is **generic**, vague, or lacks any specific feature
- It’s a **suggestion from an internal ambassador**, not customer feedback
- It’s missing real insight (e.g., no issue, request, or pain point)
- It lacks **actionable detail**

---

## Valid Examples

- Customer mentioned they struggle with generating high-quality email drafts using Copilot in Outlook and would like more control over tone and formality.
- Customer requested Copilot in Teams to summarize long chat threads more accurately, as sometimes key action points are missing.
- Customer reported that Copilot in Word does not always align with their company’s writing style guide when generating proposals.
- Customer asked if Copilot in PowerPoint could provide more creative slide layouts instead of just reformatting existing content to improve quality of produced content.

---

## Invalid Examples

- Copilot is an amazing tool that simplifies tasks across all Office apps
- A small business owner expressed interest in AI tools but provided vague suggestions.Copilot should be able to browse the web in real-time and fetch live news updates automatically.
- "ChatGPT provides better responses than Copilot, which feels less human-like.

---

## 🧠 Chain of Thought (How to Think Before Deciding)

- Is the feedback clearly tied to a **specific part** of Copilot?
- Does it describe the **customer's experience**, not just general praise or confusion?
- Does it show **impact** on the user’s workflow or goals?
- Could a Microsoft engineer or PM reasonably take action based on this?

If the answer is mostly “yes,” mark as **valid**. If mostly “no,” mark as **invalid**.

---

## 📦 Output Format

Do not include any of the reasoning in your response. Respond in **JSON only**, with the following fields:

```json
{
  "valid": true,
  "reasoning": "A short explanation of your reasoning."
}

'''

# %%
test_results = analyse_test_prompt('detailed_few_shot_v2_cot_20', detailed_few_shot_v2_cot , test_results, copilot_insights_20)
# Out:
# 0
# Based on my conversation it would benefit the customer if copilot comes free of usage for the first week of a new account to get users hooked on using AI with their work flow. {
#   "valid": false,
#   "reasoning": "This feedback is a suggestion regarding pricing or onboarding strategy rather than a specific issue or feature related to Copilot functionality or experience."
# }
# 1
# The customer mentioned Copilot for outlook can have a feature for end users where they can have text to image so the emails can be personalized with the ideas of the moment {
#   "valid": true,
#   "reasoning": "The feedback suggests a specific enhancement for Copilot in Outlook, proposing text-to-image capabilities to improve email personalization. This is actionable and tied to a particular business use case."
# }
# 2
# The customer, an engineering firm specializing in human-machine interfaces, uses Copilot AI to streamline email drafting and enhance efficiency. They are curious about the sources of information Copilot relies on, aiming to ensure the reliability and accuracy of its content. With Copilot automating tasks like drafting emails, creating presentations, and managing schedules, the customer benefits from improved productivity, secure workflows, and seamless communication {
#   "valid": false,
#   "reasoning": "The feedback lacks specificity about any particular Copilot feature or functionality and does not highlight a specific issue, pain point, or actionable insight for product improvement. It primarily describes general curiosity and benefits, which are not directly actionable."
# }
# 3
# He mentioned that likes using Copilot to compare two product specifications. For example, dimension and prices. He also uses Copilot for Office applications and used it to write a letter. {
#   "valid": false,
#   "reasoning": "The feedback is vague and does not describe any specific issues, limitations, or opportunities for improvement. It merely outlines general use cases without actionable insights or impact."
# }
# 4
# The user highlighted that they are unable to upload images with the free version of Copilot chat and suggested that it would be beneficial if Microsoft could consider a solution for this, as it would significantly enhance their business productivity by enabling better visual communication and documentation. {
#   "valid": true,
#   "reasoning": "The feedback is specific to the inability to upload images in Copilot chat, explains its impact on business productivity, and provides actionable insight by suggesting a solution to enhance visual communication and documentation."
# }
# 5
# The customer shared that while some users are ready to use Copilot, she is hesitant due to previous experiences with inaccurate responses and unsatisfactory AI learning. She hopes for improvements and plans to reconsider using Copilot in the future. {
#   "valid": false,
#   "reasoning": "The feedback is generic and reflects hesitation about using Copilot but does not include any specific feature, functionality, or actionable insight based on actual usage."
# }
# 6
# Customer mentioned he has tried copilot in teams meeting to create comprehensive meeting notes, it would be beneficial if Copilot could provide more customizable summary options to cater to different meeting formats and preferences. {
#   "valid": true,
#   "reasoning": "The feedback is specific to Copilot in Teams meeting notes, highlights a need for customizable summary options for different formats and preferences, and is actionable for improving the feature."
# }
# 7
#  Cx finds Copilot quite easy to use and straightforward with an interactive user interface and accurate insights. {
#   "valid": false,
#   "reasoning": "The feedback is too generic and lacks specificity about any particular Copilot feature or functionality. It does not provide actionable insights or details about the customer’s experience with Copilot."
# }
# 8
# The customer mentioned that Copilot's ability to suggest Power Automate workflows is limited. Enhancing Copilot to create baseline workflows based on user descriptions, such as "send email," "attach files to email," and "look through a list of clients," would improve its usability. {
#   "valid": true,
#   "reasoning": "The feedback is specific to Copilot's ability in Power Automate and suggests a clear enhancement related to generating workflows from user descriptions. It offers actionable insights to improve usability for structured tasks."
# }
# 9
# During our conversation, the customer mentioned that Copilot's feature of creating PowerPoint presentations from files will be very useful for his business, as it saves time on creating presentations. He is also interested in exploring other potential benefits of Copilot to enhance his business operations. This feedback highlights the value of Copilot's time-saving features for startups. {
#   "valid": false,
#   "reasoning": "The feedback is generic and lacks specificity regarding any issues, limitations, or actionable insights. It does not provide detailed information about how the presentation creation feature impacts the workflow or what specific improvements could be made."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# Customer mentioned that he never used Copilot before. {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the customer has not used Copilot, and there is no actionable insight or specific feature mentioned."
# }
# 1
# Copilot Feedback:
#
# Cst shared the below Feedback about MS365 Copilot:
#
# Copilot's advanced analytics capabilities, such as predictive modeling and trend analysis, will provide us with deeper insights into our data, which will help us a lot in our daily work.   {
#   "valid": false,
#   "reasoning": "The feedback is generic and does not mention a specific issue, request, or limitation related to Copilot's analytics functionalities. It lacks actionable detail for improvement."
# }
# 2
# Informed the customer about Copilot, explaining its uses and benefits. Highlighted how Copilot can assist with various tasks, including productivity, support, and information synthesis. Emphasized Copilot's ability to streamline processes, improve efficiency, and provide timely support. {
#   "valid": false,
#   "reasoning": "This entry does not provide any specific feedback or actionable insights on Copilot's functionality or the user's experience. It simply describes how Copilot was introduced to the customer."
# }
# 3
# Customer is planning to get it with new fiscal year {
#   "valid": false,
#   "reasoning": "The feedback does not provide any specific information about Copilot features, user experience, or actionable insights."
# }
# 4
# The customer mentioned Copilot in Outlook will impact their customers workflow and improve overall performance due to emails are being created by an AI on a daily basis and with this he can focus on other tasks  {
#   "valid": false,
#   "reasoning": "The feedback lacks specificity regarding Copilot's functionality or any detailed experience with its use in Outlook. It does not include actionable insights or describe specific issues, limitations, or requests for improvement."
# }
# 5
# As per the customer manual processes provide a sense of control, and some users prefer traditional methods over automation. {
#   "valid": false,
#   "reasoning": "The feedback lacks specificity and does not provide actionable insight about a specific Copilot feature or functionality. It is a general preference rather than a critique or request related to Copilot."
# }
# 6
# Customer mentioned that he have a commercial department team, that includes two people, and they are currently using shared mailbox to communicate with customer as that helps save money, the customer is wondering if Microsoft can make possible to assign the license to that shared mailbox or group, so the entire team can leverage on it. {
#   "valid": false,
#   "reasoning": "The feedback is not specific to a Copilot feature or functionality and instead requests a general licensing change unrelated to Copilot."
# }
# 7
# Customer was unaware of Copilot and after some Demo he realized that he has access to Microsoft 365 Copilot and that it is similar to Chat GPT. {
#   "valid": false,
#   "reasoning": "The feedback does not provide specific insights, issues, or requests regarding Copilot features or functionality but instead highlights the customer's initial awareness and general comparison to ChatGPT."
# }
# 8
# The user doesn't know Copilot and never user it. {
#   "valid": false,
#   "reasoning": "The feedback is invalid because the user has not used Copilot or provided any actionable insight about the tool."
# }
# 9
# Deepseek offer multiple possible solutions and explanation where Copilot dont offer that which is a big challenge for users who do research {
#   "valid": false,
#   "reasoning": "The feedback compares Copilot to another product, Deepseek, but does not provide specific details about Copilot's features or shortcomings. It is too generic and lacks actionable insights for improvement."
# }
# 91.75161695480347

# %%
test_results
# Out:
#                      test_name  sensitivity  precision  f1_score
# 0           detailed_zero_shot          0.5   0.833333  0.625000
# 1         detailed_few_shot_20          0.3   1.000000  0.461538
# 2  detailed_few_shot_v2_cot_20          0.4   1.000000  0.571429

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store, true_positives, true_negatives, false_positives, false_negatives):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                try:
                    llm_res = json.loads(llm_res)
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON: {e}, moving to next case")  # Log the error
                    next
                    
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
# print test results store

# %%
# Out:
# 4
# 5
