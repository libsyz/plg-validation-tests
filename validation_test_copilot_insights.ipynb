# %% [markdown]
# # Copilot Insight Validation Using LLMs 🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies for validating Copilot Product Insights using a Large Language Model (LLM). The goal is to determine the most effective prompting approach for distinguishing between valid and invalid insights based on predefined criteria.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing copilot insights for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key

# %% [markdown]
# # 1 - Load Copilot Insights
#
# Let's take a glimpse at the data we have. All this data has been validated with an LLM with a custom prompt and then reviewed by human validators. This explains why we have true and false positives and negatives.
#
# This data will act as a makeshift cross-validation set. We can test different approaches on it, and then see which one performs best

# %%
# We load all the data 

true_positives = pd.read_csv('copilot_insights/cp_true_positives.csv')
true_negatives = pd.read_csv('copilot_insights/cp_true_negatives.csv')
false_positives = pd.read_csv('copilot_insights/cp_false_positives.csv')
false_negatives = pd.read_csv('copilot_insights/cp_false_negatives.csv')

# Now let's print one of the datasets to see its shape

true_positives[:5]
# Out:
#                                       CopilotInsight  \
# 0   In our conversation the company representativ...
# 1  The visualizations generated by Copilot are no...
# 2  INSTITUT-RICHEMONT is an educational center sp...
# 3  Customer concerned with Copilot's Data Privacy...
# 4  Customer is satisfied with Copilot's meeting s...
#
#    Copilot Insights validation_status  \
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
#
#                             Copilot Insights comment  \
# 0  The entry is valid as it provides specific fee...
# 1  The insight is specific, actionable, and custo...
# 2  The insight is valid as it is specific, action...
# 3  The insight is valid as it highlights a specif...
# 4  The insight is valid as it is specific, action...
#
#   Copilot Insights_human_review
# 0                         Agree
# 1                         Agree
# 2                         Agree
# 3                         Agree
# 4                         Agree

# %%
# Column explanation
data = [
    ["CopilotInsight", "Raw feedback notes captured by the agent and stored on Gigplus Trackers"],
    ["Copilot Insights validation_status", "Validation done by the LLM - 0 is invalid, 1 is valid"],
    ["Copilot Insights comment", "Explanation provided by the LLM"],
    ["Copilot Insights_human_review", "Human review, agreeing or disagreeing with the model"],
    ["Copilot Insights_human_comment", "Comment left by the human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                           Column Name  \
# 0                      CopilotInsight
# 1  Copilot Insights validation_status
# 2            Copilot Insights comment
# 3       Copilot Insights_human_review
# 4      Copilot Insights_human_comment
#
#                                                                Explanation
# 0  Raw feedback notes captured by the agent and stored on Gigplus Trackers
# 1                    Validation done by the LLM - 0 is invalid, 1 is valid
# 2                                          Explanation provided by the LLM
# 3                     Human review, agreeing or disagreeing with the model
# 4                                      Comment left by the human validator

# %% [markdown]
# ## 1.1 Baselining Performance
#
# These 4 datasets have already been evaluated by an LLM as well as been reviewed by a human.
#
# This means we can calculate Sensitivity, Recall and F1 for this dataset, which will give us target performance metrics to iterate on. Let's refresh on how these are calculated
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$
#
#
# With that, let's calculate sensitivity, precision and F1 score for our current dataset

# %%
tp = true_positives.shape[0]  
tn = true_negatives.shape[0]
fp = false_positives.shape[0]
fn = false_negatives.shape[0]

sensitivity = tp / ( tp + fn )
precision = tp / ( tp + fp )
f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )

baseline_eval_metrics = pd.DataFrame([
    ["Sensitivity", sensitivity],
    ["Precision", precision],
    ["F1_Score", f_1]
    ],
    columns=["Metric", "Value"]
)

baseline_eval_metrics
# Out:
#         Metric  Value
# 0  Sensitivity    0.5
# 1    Precision    0.5
# 2     F1_Score    0.5

# %% [markdown]
# The metrics are very low and in principle "easy to beat", but this is only because we have the exact same number of TN, TP, FN and FP in the sample.
#
# In reality, the previous model performed better than this - nevertheless, this gives us a compass for our exercise.
#
# **New prompts/prompt strategies should be able to have a better ability to catch false positives and false negatives while maintaining accuracy with true positives and negatives**
#
# We'll store the result of all our tests into a dataframe table. This will allow us to contrast and compare approaches and make a final selection.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])

test_results = pd.concat([test_results, pd.DataFrame({"test_name": ["original"] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })], ignore_index=True)

test_results
# Out:
# /var/folders/xv/5lp8ff8s7j55zh1lrpr9ddkw0000gn/T/ipykernel_36058/125464560.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   test_results = pd.concat([test_results, pd.DataFrame({"test_name": ["original"] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })], ignore_index=True)
#   test_name  sensitivity  precision  f1_score
# 0  original          0.5        0.5       0.5

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue, mentioning that the menu was convoluted and crowded with icons, making it hard to use the app effectively."
# }
# ```

# %% [markdown]
# The model is giving us back a string formatted in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue, mentioning that the menu was convoluted and crowded with icons, making it hard to use the app effectively."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through our TP, TN, FP, FN datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the product feedback entry
#     - 2. Evaluate if the LLM did a good job or not
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # cooldown logic to prevent exceeding token limit every 10 rows 
            print(row_counter)
            if row_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                row_counter = 0
                
                
            llm_res = send_prompt(prompt, row['CopilotInsight'])
            llm_res = clean_llm_response(llm_res)
            row_counter += 1
            print(llm_res)
            
            llm_res = json.loads(llm_res)
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

test_prompt = "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }"

# test_results = analyse_test_prompt('testy test', test_prompt, test_results)

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Zero Shot Prompt
#
# ![Alt Text](zero_shot.png)
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe 2 sets of criteria, one for Product Feedback and Limitations, and another one for Deployment Blockers. We instruct the model to validate the entries when 1 of the criteria sets are met.

# %%
zero_shot_prompt = '''
You are an AI assistant that classifies Copilot feedback as valid or invalid based on strict criteria

Valid Insights
A valid insight must be specific and actionable and highlight a product limitation

## Specific & Actionable Feedback (Required for general insights)
- Identifies a specific Copilot feature, use case, or scenario
- Provides enough detail for improvements or decision-making

## Product Limitations (Any of these make feedback valid)
- Feature request: A customer explicitly requests a missing capability
- Functionality gap: Copilot cannot do something the customer needs
- Competitor preference: Customer chose a competitor’s product for specific reasons
- Usability issue: Copilot is difficult or frustrating to use
- Pricing concern: The cost of Copilot is a barrier to adoption or not seen as justified

## Invalid Insights
- General recommendations (e.g., “Copilot should have more customization”).
- Positive feedback without detail (e.g., “Copilot is great”).
- Vague statements (e.g., “Copilot is interesting”).
- Non-customer feedback (e.g., “I explained Copilot to the customer, who will review it”).

You will respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('zero shot', zero_shot_prompt, test_results)
# Out:
# 0
# {
#   "valid": true,
#   "reasoning": "The feedback highlights a functionality gap where Copilot's text generation and summarization capabilities are not meeting the company's core requirements for managing consistent, targeted internal communication across their global organization. This represents a valid product limitation, as the company has emphasized their reliance on established systems for communication and project workflows, suggesting Copilot is not directly relevant to their specific needs."
# }
# 1
# {
#   "valid": true,
#   "reasoning": "This feedback identifies a specific product limitation in Copilot's functionality. It highlights that the visualizations generated by Copilot are not accurate and require manual intervention, which implies a usability issue. Additionally, it points out that the created datasets do not align with customer preferences or needs, signifying a functionality gap. Thus, the feedback is both specific and actionable, meeting the criteria for validity."
# }
# 2
# {
#   "valid": true,
#   "reasoning": "The feedback qualifies as valid because it highlights a specific product limitation related to pricing concerns. The customer expressed that the cost of adopting Copilot is a barrier to their intent to employ the tool across a large number of staff. This is actionable and points to a clear limitation in affordability for educational institutions like INSTITUT-RICHEMONT."
# }
# 3
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a specific concern about data privacy and transparency—a critical usability issue. The customer explicitly mentions uncertainty about what personal data Copilot collects and its usage, which is actionable as it pinpoints a limitation in the product's metadata or documentation that could be addressed."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "The feedback is valid because the customer explicitly requests a missing capability: an action item generator that detects tasks from meetings and creates reminders or to-do lists. This is a specific and actionable feature request that highlights a functionality gap in Copilot's current meeting summary capabilities."
# }
# 5
# {
#   "valid": true,
#   "reasoning": "The feedback identifies a specific feature request: the ability to automate data entry from customer forms into rental agreements in Word using Copilot. This highlights a product limitation and provides actionable insight for improving Copilot's functionality."
# }
# 6
# {
#   "valid": true,
#   "reasoning": "The feedback is valid because the user explicitly requests a new feature for Copilot in Teams that would allow creating a meeting using voice commands. This is actionable, specific, and highlights a product limitation as the feature is currently missing."
# }
# 7
# {
#   "valid": false,
#   "reasoning": "The feedback is too vague and does not highlight a specific limitation, feature request, or actionable insight. It simply states a general use case ('help write code and develop software'), which does not satisfy the criteria for specific and actionable feedback."
# }
# 8
# {
#   "valid": true,
#   "reasoning": "The feedback highlights a usability issue with Copilot for Web, specifically the customer's frustration with needing to open another tab to access Copilot. This is actionable as it suggests a product improvement to enhance user experience by keeping Copilot accessible within the same tab."
# }
# 9
# {
#   "valid": true,
#   "reasoning": "This feedback is valid because it identifies specific and actionable limitations in Copilot's functionality: its inability to search across all documents simultaneously, analyze data from multiple Excel files, and work within PDFs. Additionally, the requirement to analyze documents across SharePoint, OneDrive, and emails using keywords is another clear functionality gap. The customer's dissatisfaction with the yearly commitment and reliance on a free trial highlights a pricing concern. These insights provide concrete areas for improvement or consideration in product development."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": false,
#   "reasoning": "The feedback primarily focuses on the client's interest in learning more about Copilot and exploring cost and integration options, but it lacks specificity or actionable detail regarding a product limitation, functionality gap, or usability issue. Additionally, it does not include any specific feature requests or highlight challenges with Copilot. The entry is informative but does not meet the criteria for valid insights about Copilot."
# }
# 1
# {
#   "valid": false,
#   "reasoning": "The feedback does not identify a specific product limitation, feature request, functionality gap, usability issue, or pricing concern. It recounts a general conversation about Copilot's capabilities and the customer's interest in it but lacks actionable details or evidence of any issues encountered by the customer."
# }
# 2
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not highlight a specific limitation, functionality gap, or usability issue with Copilot. While the customer expressed interest, this is non-customer feedback since the action involves introducing Copilot rather than identifying a clear product limitation or actionable insight for improvement."
# }
# 3
# {
#   "valid": false,
#   "reasoning": "The feedback does not highlight any specific product limitations, feature requests, usability issues, or pricing concerns. While the customer expressed interest in Copilot for Microsoft 365, their feedback is not specific or actionable with detailed insights tied to Copilot's limitations or areas for improvement. This is essentially a summary of a positive conversation without actionable detail."
# }
# 4
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not identify a specific Copilot feature, use case, or scenario that needs improvement or is a limitation. The customer’s interest and decision to evaluate Copilot does not provide actionable feedback or highlight a product limitation. It is also non-customer feedback, as it reflects a summary of the discussion rather than insights from the customer's experience."
# }
# 5
# {
#   "valid": false,
#   "reasoning": "The feedback lacks specific and actionable insights about Copilot. It is a general description of its capabilities and does not highlight a product limitation, functionality gap, feature request, usability issue, pricing concern, or competitor preference. It is more aligned with describing potential use cases rather than addressing a problem or customer need."
# }
# 6
# {
#   "valid": false,
#   "reasoning": "The feedback does not identify any specific Copilot feature, use case, or scenario, nor does it highlight a product limitation. It contains positive feedback about the customer’s interest in exploring Copilot further but lacks actionable detail or mentions of functionality gaps, usability issues, or other limitations."
# }
# 7
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not highlight a specific product limitation, such as a missing feature, functionality gap, usability issue, pricing concern, or competitor preference. While it mentions the customer’s interest in implementing Copilot and its potential benefits, it lacks actionable detail or a concrete issue requiring improvement."
# }
# 8
# {
#   "valid": false,
#   "reasoning": "The feedback does not highlight a specific product limitation, usability issue, feature request, pricing concern, or functionality gap. It simply outlines the customer's intention to try Copilot and does not provide actionable insights or details about potential limitations or problems in their workflow."
# }
# 9
# {
#   "valid": false,
#   "reasoning": "The feedback does not identify a specific product limitation, feature request, functionality gap, pricing concern, or usability issue. The freelancer's lack of interest in keeping the subscription is mentioned, but there is no actionable or detailed explanation regarding why Copilot did not meet her needs or if any limitations influenced her decision."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not identify a specific limitation or issue with Copilot. While the customer has expressed interest in using Copilot and sees its potential benefits, the feedback does not highlight any product gaps, feature requests, usability issues, or other limitations. This is general positive feedback about their interest in the tool, but it lacks actionable or specific insights."
# }
# 1
# {
#   "valid": false,
#   "reasoning": "The feedback is vague and does not identify a specific Copilot feature, use case, or limitation. It mainly consists of general recommendations and does not highlight any actionable product limitation or customer request. There is no mention of any usability issue, pricing concern, direct competitor preference, or specific missing functionality."
# }
# 2
# {
#   "valid": false,
#   "reasoning": "The feedback does not highlight a specific product limitation, functionality gap, or actionable feature request. Instead, it describes general observations about demonstrating Copilot's features and perceived improvements without specifying any usability issues, missing capabilities, or limitations. The entry lacks actionable details for improvement and does not meet the criteria for valid feedback."
# }
# 3
# {
#   "valid": false,
#   "reasoning": "The feedback is primarily positive and generalized, highlighting that Copilot is helpful for saving time and improving productivity. However, it does not identify a specific limitation, usability issue, or actionable element for improvement. The feedback lacks any mention of missing features, functionality gaps, or pricing concerns as defined by the criteria."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "The feedback identifies a specific product limitation related to the lack of a trial or monthly subscription option. This is actionable and highlights a clear barrier to adoption, as it prevents potential customers from trying the service before committing. It falls under the category of a pricing concern, making it valid feedback."
# }
# 5
# {
#   "valid": false,
#   "reasoning": "The feedback identifies a general issue with Copilot providing outdated or irrelevant responses, but it does not detail a specific feature, scenario, or limitation. While the recommendation to refine prompts and update data sources is constructive, it lacks the specificity and actionable insights required to improve the product. The feedback does not explicitly highlight a missing capability, functionality gap, usability issue, or other criteria for valid insights."
# }
# 6
# {
#   "valid": false,
#   "reasoning": "The feedback highlights a positive outcome of using Copilot 365, but it lacks specific, actionable details regarding product limitations, a missing capability, or a functionality gap. It does not identify any usability issue, pricing concern, or competitor preference either. As a result, it does not meet the criteria for valid insights."
# }
# 7
# {
#   "valid": false,
#   "reasoning": "The feedback is predominantly positive, highlighting potential benefits of Copilot without providing specific or actionable insights related to limitations or areas for improvement. It does not identify a feature request, functionality gap, usability issue, pricing concern, or competitor preference. The statements are general and lack critical details needed for decision-making or improvement."
# }
# 8
# {
#   "valid": false,
#   "reasoning": "The feedback is positive, but it lacks specificity and does not highlight a product limitation or actionable insight. It only broadly praises Copilot's ability to save time, without referencing specific features, use cases, or limitations."
# }
# 9
# {
#   "valid": false,
#   "reasoning": "The feedback is positive but lacks specific and actionable details describing a product limitation or necessary improvement. It does not identify a specific feature, scenario, or limitation but instead provides general praise about drafting financial and legal documents in Word."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a pricing concern, which is a product limitation based on the customer's perception of cost versus value. Specifically, the customer mentions that Copilot is too expensive and expects it to be integrated into existing subscriptions rather than requiring an additional cost. This is actionable for pricing and packaging considerations."
# }
# 1
# {
#   "valid": true,
#   "reasoning": "This feedback is valid because it highlights two specific product limitations: (1) Copilot's response time is slower compared to a competitor (ChatGPT), which qualifies as a functionality gap and a competitor preference. (2) The browser session freezing issue leading to forced restarts and retyping queries indicates a usability issue. Both insights are actionable and detailed enough for improvement considerations."
# }
# 2
# {
#   "valid": true,
#   "reasoning": "This feedback is valid because it highlights a pricing concern, specifically the lack of flexibility in commitment options. The customer's preference for monthly options is a specific and actionable insight related to a product limitation, as it points to a barrier to adoption."
# }
# 3
# {
#   "valid": true,
#   "reasoning": "The feedback highlights a specific limitation in the free version of Copilot, indicating it provides shallow and repetitive answers. This is a functionality gap and could be actionable for improving the product. Additionally, it identifies a usability concern related to the quality of content generated by Copilot in its free version."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a specific product limitation where Copilot struggles with understanding the nuanced and context-specific requirements of a particular use case (wedding planning). This indicates a functionality gap that could impact the accuracy of suggestions, making the feedback specific and actionable."
# }
# 5
# {
#   "valid": true,
#   "reasoning": "The feedback identifies a functionality gap (Copilot's response speed and comprehension issues) which could impact usability. These are specific and actionable concerns that highlight limitations and can inform improvements."
# }
# 6
# {
#   "valid": true,
#   "reasoning": "This feedback is valid because it identifies a specific Copilot feature, the M365 Chat Bing web experience, and highlights a usability issue. The customer mentions that it requires multiple prompts to get the right responses and that the responses are not always accurate. This constitutes a functionality gap and provides actionable feedback for improvement."
# }
# 7
# {
#   "valid": true,
#   "reasoning": "The feedback highlights two specific product limitations. The first is a functionality gap in image generation, where certain use cases (e.g., generating an image of a police officer holding a radar gun) are restricted due to censorship. The second is a usability issue where the Copilot takes too long to load (3 seconds) in the browser, which impacts the user experience. Both points are actionable and specific, making this valid feedback."
# }
# 8
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a pricing concern, specifically suggesting reduced costs for small businesses already using Microsoft subscriptions. It is actionable and identifies a potential barrier to adoption, making it a valid insight."
# }
# 9
# {
#   "valid": true,
#   "reasoning": "The feedback is valid because it identifies a specific product limitation: Copilot lacks the capability to edit or modify existing images that users upload. This constitutes a functionality gap and is actionable for potential improvement."
# }
# 261.36283802986145

# %%
print(test_results)
# Out:
#    test_name  sensitivity  precision  f1_score
# 0   original         0.50       0.50      0.50
# 1  zero shot         0.95       0.95      0.95

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# ![Alt Text](few_shot.png)
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''

You are an AI assistant that classifies Copilot feedback as valid or invalid based on strict criteria.

# Validation Criteria
A valid insight must be specific and actionable or highlight a product limitation.

## Valid Insight Conditions
Specific & Actionable Feedback (Required for general insights)
- Identifies a specific Copilot feature, use case, or scenario.
- Provides enough detail for improvements or decision-making.


## Product Limitation (At least one of the following must apply):
- Feature request: A customer explicitly requests a missing capability.
- Functionality gap: Copilot cannot do something the customer needs.
- Competitor preference: Customer chose a competitor’s product for specific reasons.
- Usability issue: Copilot is difficult or frustrating to use.
- Pricing concern: The cost of Copilot is a barrier to adoption or not seen as justified.

## Valid Insights Examples
- The customer would like Copilot to generate automatic meeting invites after a conversation finishes ( Specific, Actionable, Feature request ) 
- Copilot cannot summarize multiple email threads at once—it only works on a single thread at a time ( Specific, Actionable, Functionality gap ) 
- Customer prefers ChatGPT over Copilot because ChatGPT is better at solving complex coding problems ( Specific, Actionable, Competitor preference )
- Customer finds Copilot’s interface confusing and difficult to navigate, especially when trying to switch between different Microsoft 365 apps ( Specific, Actionable, Usability issue )
- Customer finds Copilot’s pricing too high for small teams and would prefer a tiered pricing model that offers a lower-cost option ( Specific, Actionable, Pricing concern )

- The customer signed up for copilot365 to enable him test out the product and demonstrate copilot to his clients.  
- The customer expressed that he loves Copilot365's ability to pull information within his company and work on it. He also appreciated the Copilot in Teams for meeting recaps and the Copilot in Word for drafting proposals.  
- "Integration with Loop helps teams collaborate more effectively." 
- "Python in Excel automates data analysis, reducing manual effort." 
- "Copilot in Outlook prioritizes important emails, improving productivity." 

## Invalid Insights
 - General recommendations 
 - Positive feedback without detail 
 - Vague statements 
 - Non-customer feedback 
 
## Invalid Insights Examples
- The customer signed up for copilot365 to enable him test out the product and demonstrate copilot to his clients.  
- The customer expressed that he loves Copilot365's ability to pull information within his company and work on it. He also appreciated the Copilot in Teams for meeting recaps and the Copilot in Word for drafting proposals.  
- Copilot integration with Loop helps teams collaborate more effectively
- I recommended the customer to use Copilot for drafting emails and automating tasks
- Customer said Copilot and AI can revolutionise their industry and is the future of work

You will respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_test_prompt('few shot', few_shot_prompt, test_results)

print(test_results)
# Out:
# 0
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a functionality gap. The customer stated that Copilot's text generation and summarization capabilities do not meet their core needs for managing internal communications and ensuring consistent and targeted messaging across a global workforce. This insight provides actionable information about a specific limitation in Copilot's applicability to their organization's requirements."
# }
# 1
# {
#   "valid": true,
#   "reasoning": "The feedback is valid because it highlights a specific product limitation: the generated visualizations are not reliable and require human intervention for accuracy, and the created datasets do not meet customer preferences or needs. This represents a functionality gap and a usability issue, both of which are actionable insights for improvement."
# }
# 2
# {
#   "valid": true,
#   "reasoning": "The insight highlights a specific pricing concern raised by the customer related to deploying Copilot for a large number of staff. Pricing concerns are valid based on the criteria, as they can act as a barrier to adoption. The additional details about the customer's appreciation for integration capabilities provide context but do not affect the validity of the insight regarding pricing concerns."
# }
# 3
# {
#   "valid": true,
#   "reasoning": "The feedback is valid as it highlights a usability issue related to data privacy concerns, which is a critical aspect of product adoption. The lack of clarity around what personal data Copilot collects and how it is used can hinder customer trust and satisfaction, making this actionable for improvement."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "The entry is valid because it includes a feature request for an 'action item generator' that detects tasks from meetings and generates reminders or to-do lists. This meets the criteria of being specific and actionable, as it identifies a clear functionality gap in Copilot's meeting summary feature in Teams and provides detailed improvement suggestions."
# }
# 5
# {
#   "valid": true,
#   "reasoning": "This is valid feedback because it identifies a specific Copilot feature (Copilot in Word) and a desired feature request: the ability to automate data entry from customer forms directly into rental agreements. This is actionable feedback that highlights a functionality gap."
# }
# 6
# {
#   "valid": true,
#   "reasoning": "This is valid feedback because it explicitly requests a missing capability (feature request) for Copilot in Teams: the ability to create a meeting using voice commands. The feedback identifies a specific use case and provides actionable information for potential improvements."
# }
# 7
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a specific customer feature request for using Copilot to assist in writing code and developing software/applications. It identifies a potential use case and a functionality gap, making this insight actionable."
# }
# 8
# {
#   "valid": true,
#   "reasoning": "This insight highlights a usability issue where the customer finds it annoying to open another tab while trying to navigate Copilot on the web. It is actionable in providing a specific improvement suggestion to allow users to stay on the same tab, making it valid feedback under the usability issue category."
# }
# 9
# {
#   "valid": true,
#   "reasoning": "This feedback is valid as it highlights specific limitations in Copilot's functionality and an additional pricing concern. The inability of Copilot to search all documents simultaneously, analyze data across multiple Excel files, or work within PDFs are clear functionality gaps. Additionally, the customer requested advanced capabilities, such as analyzing related documents across SharePoint, OneDrive, and emails, and providing consolidated reports—constituting feature requests. Lastly, the concern about the yearly commitment acts as a pricing concern, making it actionable feedback."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": false,
#   "reasoning": "The feedback provided is a general recommendation on using M365 apps and includes the client's interest in Copilot, but it does not specify any actionable insights, feature requests, functionality gaps, or limitations. There is no clear identification of a specific Copilot feature, use case, or scenario."
# }
# 1
# {
#   "valid": false,
#   "reasoning": "The feedback focuses on a recommendation made to the customer about Copilot's capabilities in Teams and Outlook, rather than specific feedback or insights provided by the customer. It does not meet the criteria for actionable feedback or highlight a product limitation. Additionally, while the customer expressed interest, there is no specific detail or request provided that can be acted upon."
# }
# 2
# {
#   "valid": false,
#   "reasoning": "This feedback is invalid because it does not highlight a specific or actionable insight about Copilot. It is primarily a description of the conversation where the customer was informed about Copilot's features, but it does not indicate any specific requests, limitations, or issues with the product."
# }
# 3
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it primarily describes the customer's workflow and the recommendation of Copilot for Microsoft 365. While the customer expressed interest in Copilot, the feedback lacks specific detail about a particular feature, use case, or limitation that meets the validation criteria. There is no actionable information or mention of any product limitation."
# }
# 4
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not identify any specific actionable insight or product limitation. It simply describes a general interaction in which features were highlighted and the customer expressed interest. There is no specific feature request, usability issue, competitor preference, or detailed concern mentioned."
# }
# 5
# {
#   "valid": false,
#   "reasoning": "The feedback is invalid because it does not highlight a specific or actionable insight regarding Copilot. It is a general statement about how Copilot can assist with emails and scheduling tasks, without identifying specific features, limitations, or customer needs. Additionally, it does not address any product gaps, usability issues, or pricing concerns."
# }
# 6
# {
#   "valid": false,
#   "reasoning": "The feedback lacks specific and actionable details about Copilot's features, usability, or limitations. The customer's interest in exploring Copilot further and general satisfaction are positive, but they are too vague to provide actionable insights for improvement or decision-making."
# }
# 7
# {
#   "valid": false,
#   "reasoning": "The feedback does not include specific or actionable insights about Copilot's features, use cases, or limitations. It primarily describes the customer's interest in learning more and using Copilot for general productivity improvements, which is vague and lacks enough detail for decision-making."
# }
# 8
# {
#   "valid": false,
#   "reasoning": "The feedback mainly consists of a general recommendation for using Copilot and the customer's intent to try the product. It lacks specific and actionable insights about Copilot features, use cases, or limitations. No detailed feedback on the functionality or any mention of product limitations such as usability issues, feature requests, or pricing concerns."
# }
# 9
# {
#   "valid": false,
#   "reasoning": "The feedback lacks specificity and actionable insights. The statement describes the customer's situation and her lack of interest in continuing the subscription, but it does not highlight a specific feature, functionality gap, usability issue, or explicit request for improvement. It also does not mention any pricing concern or preference for competitors, which might have made it actionable."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": false,
#   "reasoning": "The feedback primarily describes the introduction of Copilot to the customer and their interest in its potential use. While it mentions how the customer plans to use Copilot on Teams for session note-taking and summarization, it does not identify any actionable suggestion or highlight a specific product limitation. The feedback lacks sufficient detail for improvement or decision-making."
# }
# 1
# {
#   "valid": false,
#   "reasoning": "The feedback primarily contains a recommendation for using Copilot in OneDrive and general positive interest from the customer. It does not provide specific or actionable insights about Copilot's features, use cases, or limitations. Additionally, there is no detailed information that highlights a product limitation or specific area for improvement."
# }
# 2
# {
#   "valid": false,
#   "reasoning": "The feedback is primarily a description of the functionality of Microsoft Copilot in Outlook and its potential benefits, but it lacks specific, actionable insights or mention of product limitations. It does not identify a particular problem, feature request, functionality gap, usability issue, or pricing concern."
# }
# 3
# {
#   "valid": false,
#   "reasoning": "The feedback is general and lacks specificity about functionality gaps, feature requests, or usability issues. While it highlights positive aspects of Copilot, such as time-saving in Outlook, it does not provide actionable or detailed insights for improvement. It does not meet the criteria for specific and actionable feedback or outline a product limitation."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "The feedback identifies a pricing concern and provides a feature request. The customer explicitly mentions the lack of a trial or monthly subscription option as a drawback, which is actionable and highlights a product limitation. This satisfies the criteria for valid feedback under pricing concerns and feature requests."
# }
# 5
# {
#   "valid": false,
#   "reasoning": "The insight lacks specific and actionable details about the challenges. While it mentions outdated or irrelevant responses, it does not provide specifics about the queries, scenarios, or how Copilot failed. Additionally, the recommendations provided (refining prompts, updating data sources, customizing settings) are general suggestions rather than feedback on specific functionality gaps or limitations."
# }
# 6
# {
#   "valid": false,
#   "reasoning": "The feedback is positive but lacks specificity. It does not mention any specific Copilot feature, use case, or scenario, nor does it provide actionable details or highlight a product limitation. General statements about improved productivity are insufficient for evaluation based on the validation criteria."
# }
# 7
# {
#   "valid": false,
#   "reasoning": "The feedback is a general positive statement about Copilot's potential use cases, but it lacks specificity or actionable insights. It does not indicate a specific feature, limitation, or detailed request for improvement. Instead, it broadly describes how the customer plans to use Copilot."
# }
# 8
# {
#   "valid": false,
#   "reasoning": "The feedback is positive but lacks specific details about a Copilot feature, use case, or scenario that can be improved upon. It is a general statement about the benefits of automation and is not actionable. Thus, it does not meet the validation criteria for specific and actionable feedback or highlighting a product limitation."
# }
# 9
# {
#   "valid": false,
#   "reasoning": "The feedback is positive but lacks specific and actionable details regarding Copilot's functionality or any product limitation. It only mentions that Copilot is found useful for drafting complex financial and legal documents, but does not identify a specific feature, use case, limitation, or recommendation."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a pricing concern. The customer finds Copilot's cost to be a barrier to adoption and expresses dissatisfaction with Copilot being priced as an additional subscription rather than being integrated into existing Microsoft 365 subscriptions. This meets the criteria for a specific and actionable insight related to pricing."
# }
# 1
# {
#   "valid": true,
#   "reasoning": "This is valid feedback because it highlights a specific product limitation: Copilot takes too long to respond compared to ChatGPT (Competitor preference) and there is a usability issue with the browser session freezing and requiring a retype of the query after restarting the tab (Usability issue). These insights are actionable for improving the product experience and addressing performance and reliability concerns."
# }
# 2
# {
#   "valid": true,
#   "reasoning": "This is valid feedback as it highlights a pricing concern, specifically that the customer prefers more flexible monthly options rather than an annual commitment. This detail is actionable for evaluating pricing models and addressing barriers to adoption."
# }
# 3
# {
#   "valid": true,
#   "reasoning": "This feedback highlights a product limitation: the free version of Copilot sometimes provides shallow and repetitive answers, which points to a potential functionality gap. It contains enough detail to understand the issue and implies that the product could be improved to better meet customer needs."
# }
# 4
# {
#   "valid": true,
#   "reasoning": "The insight highlights a functionality gap, as it indicates that Copilot struggles with understanding the specific context and nuances of wedding planning. This is a specific limitation in its ability to generate accurate suggestions and assistance for a particular use case. Such feedback could guide product improvement aimed at better contextual understanding in niche scenarios."
# }
# 5
# {
#   "valid": true,
#   "reasoning": "The feedback highlights two specific product limitations: slow response times and difficulties in understanding user questions. These are usability issues that could impact the overall user experience and warrant improvement."
# }
# 6
# {
#   "valid": true,
#   "reasoning": "This is a valid insight because it highlights a usability issue with the M365 Chat Bing web experience. Specifically, the customer finds it takes multiple prompts to get accurate responses, and the tool sometimes gives incorrect answers. This feedback is actionable and identifies a functionality gap or potential improvement area."
# }
# 7
# {
#   "valid": true,
#   "reasoning": "The feedback highlights specific product limitations. The first issue identifies a functionality gap in Copilot's image generation capabilities due to censorship or restrictions. The second issue points out a usability issue concerning loading time in the browser, which impacts user experience. Both points are actionable and meet the validation criteria."
# }
# 8
# {
#   "valid": true,
#   "reasoning": "The customer explicitly highlights a pricing concern related to affordability, especially for small businesses. They suggest a reduction in cost for customers already using Microsoft subscriptions to make Copilot more accessible. This aligns with the 'Pricing concern' criteria under product limitations, offering specific and actionable feedback."
# }
# 9
# {
#   "valid": true,
#   "reasoning": "This feedback is valid because it highlights a specific product limitation: the inability of Copilot to edit or modify existing images uploaded by users. This represents a clear functionality gap, as the customer is identifying a missing capability that would enhance Copilot's utility."
# }
# 267.2362537384033
#    test_name  sensitivity  precision  f1_score
# 0   original         0.50   0.500000   0.50000
# 1  zero shot         0.95   0.950000   0.95000
# 2   few shot         1.00   0.952381   0.97561

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                llm_res = json.loads(llm_res)
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %%
product_prompt = '''

You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following set of criteria.

## Product Feedback and Limitations Criteria

Meeting criteria A) and B) is a must have for the entry to be considered valid

    - A) Actionability: the entry mentions product feedback, limitations that are specific, actionable and valuable for a product team.

    - B) Specificity: The entry should clearly refer to a specific product feature or a product limitation
    
Meeting at least one of the following criteria C), D) and E) is enough to check the entry as valid

    - C) Support of Objectives: The entry should explain how the feedback aligns customer business objectives or business case, regardless of whether the feedback is positive or negative. 

    - D) Impact on Customer Experience: The entry must explain how it impacts customer workflows, satisfaction, or any stage of the customer's experience
    
    - E) Positive Feedback: The entry provides positive feedback about a feature or aspect of the product

##Criteria End##

## Examples of valid Entries ## 

    - “The Product seems very hard to use, doing basic actions like managing the calendar requires many clicks and it's confusing.” – [ Valid, Meets Criteria A), B) and D) ]

    - “The Product is not able to perform scheduled updates, forcing the customer to do manual work and waste time” – [ Valid, Meets Criteria A), B) and C) ]

    - “The customer mentioned how happy he was with the new data visualization suite and the FabricView feature. It has really helped his team make better decisions” – [ Valid, Meets Criteria A), B) and E) ]

    - “The customer was frustrated because the product is unstable when running alongside another application” – [ Valid - Meets criteria A) and B) and D) ]

## Examples of valid Entries end ##

## Examples of invalid Entries## 

    - “The Product seems slow sometimes.” – [ Invalid - Does not meet criteria A) and B) ]

    - “The customer does not like the product, he prefers the older version. Also thinks the competition is better” – [ Invalid - Does not meet criteria A) and B) ]

    - “We heard from another company that they had issues with the product.” – [ Invalid, Does not meet criteria A) and B) ]  

    - “We really love the product, the new functionalities are really cool and helps us make more money which is what we want” – [ Invalid, Does not meet criteria A) and B) even though meets C) and E) ] 

    - “We need time to adjust to new workflows.” - [ Invalid, Does not meet criteria A) and B) ]

    - "Product is a bit expensive, should rethink the price point" - [ Invalid, Does not meet criteria A) and B) ]

## Examples of invalid Entries for Set 1 end ##

## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above
'''

# %%
deployment_blocker_prompt = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following set of criteria.

##Valid Deployment Blockers Criteria## 

Meeting any of the following criteria is enough to check the entry as valid

    - Technical Barriers: The entry contains concrete obstacles that prevents or limits the successful implementation, adoption, or performance of a technology, system or product.  

    - Organizational Readiness: The entry refers to a shortage of trained personnel or expertise to adopt, implement or maintain a the product.

    - Compatibility:  The entry explains clearly how the product cannot be adopted or used due to lack of compatibility, outdated systems, or proprietary formats 

    - Support and Documentation: The entry explains how poor documentation prevents the deployment, adoption or use of the product 

    - Security and Compliance: The entry explains risks related to data protection, cybersecurity threats, or compliance with privacy laws that prevent deployment, adoption or use of the product.

## Valid Deployment Blockers Criteria end ## 

## Examples of valid Entries for Set 2 ## 

    - “The customer raised a concern about the lack of multi-tenancy support. They need a way to manage multiple teams and departments separately within the product.” – [ Valid, Technical Barrier ]

    - “The customer said that while they see the value in our solution, they can't deploy because their team would need extensive training to use it effectively.” – [ Valid, Organizational Readiness ]

    - “he customer mentioned that they were excited to deploy the product, but they discovered it's not compatible with their existing infrastructure. Their systems run on Linux, while the software only supports Windows, making it impossible for them to implement” – [ Valid, Compatibility ]

    - “The customer said that when they encountered an issue, they couldn’t find sufficient troubleshooting guides or FAQs to resolve it on their own, making them overly reliant on support.” – [ Valid, Support and Documentation ]

    - "The product only provides US-based data hosting but the customer requires GDPR, so legally they cannot use it." - [Valid, Security and Compliance]

## Examples of valid Entries for Set 2 end ##

## Examples of invalid Entries for Set 2 ## 

    - “Our office is moving next month, so we can’t focus on deployment right now.” – [ Invalid, Does not meet any of the criteria ]

    - “The system doesn't seem to work as expected in our environment.” – [ Invalid, Does not meet any of the criteria ]

    - “The customer mentioned that they are facing some challenges with the new system.” – [ Invalid, Does not meet any of the criteria ]

    - “The customer said that they are not sure how to proceed with the migration.” – [ Invalid, Does not meet any of the criteria ]

    - "They have concerns about security that need to be cleared before they proceed with the deployment" - [Invalid, Does not meet any of the criteria]

## Examples of valid Entries for Set 2 end ##

## Response ##

You will always respond in JSON format with only the following fields and no more:

* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
test_results = analyse_multipass_prompt('multipass', product_prompt, deployment_blocker_prompt, test_results)

test_results

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
test_results
# Out:
#    test_name  sensitivity  precision  f1_score
# 0   original         0.50   0.500000   0.50000
# 1  zero shot         0.95   0.950000   0.95000
# 2   few shot         1.00   0.952381   0.97561
