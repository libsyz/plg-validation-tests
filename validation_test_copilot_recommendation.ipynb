# %% [markdown]
# # Product Insight Validation Using LLMs: Copilot Recommendations🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies and prompts for validating Copilot Recommendations using a Large Language Model (LLM). The goal is to have a sandbox where we can fine-tune prompts using the same cross validation sets.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing business goals for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key
# Out:
# /Users/martaibanez/Desktop/plg-validation-tests/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # 1 - Load Business Goals
#
# Let's take a glimpse at the data we have. All these business goals have been validated by human validators during the month of April '25
#
# These datasets will act as makeshift cross-validation sets, that we can use to test the performance of different prompting strategies and approaches.
#
#
# We have two datasets:
#
# - A small set of 20 cases ( 10 valid, 10 invalids ) for quick experimentation
# - A bigger set of 200 cases ( 100 valid, 100 invalids ) for testing and measuring results

# %%
# We load all the data 

copilot_recommendation_20 = pd.read_csv('./cases/copilot_recommendation_cv20.csv')
copilot_recommendation_200 = pd.read_csv('./cases/copilot_recommendation_cv200.csv')

# Now let's print one of the datasets to see its shape

copilot_recommendation_20[:5]
# Out:
#       ID       Case Number                                 UPN  \
# 0  28155  2503310040000583  gig_wfh_micsi@microsoftsupport.com
# 1  27414  2504041420002774  gig_wfh_abelr@microsoftsupport.com
# 2  26653  2504031420003187  gig_wfh_hotab@microsoftsupport.com
# 3  27703  2504040030008181  gig_wfh_feasu@office365support.com
# 4  26036  2503280040006869  gig_wfh_maond@microsoftsupport.com
#
#             Line Of Business  \
# 0  Business Advisor Reactive
# 1  Business Advisor Reactive
# 2  Trials Nurturing Reactive
# 3            Business Assist
# 4            Business Assist
#
#                               Recommendation Details  \
# 0   \nInformed customer that Copilot is integrate...
# 1   \n- Given the administrator's objective of ut...
# 2   \nCopilot in Outlook assists with email manag...
# 3   \n To save time I recommended summarizing ema...
# 4  Copilot recommendation details: \nThe customer...
#
#    Recommendation Details Validation  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
#
#                       Recommendation Details Comment
# 0  Relevant in customer's key areas of usage in M365
# 1                                              Valid
# 2                               Valid recommendation
# 3  Copilot Outlook to summarize email thread was ...
# 4                                              Valid

# %%
# Column explanation
data = [
    ["Recommendation Details", "Raw Copilot Recommendation Details captured by the ambassador as they figure in the tracker"],
    ["Recommendation Details Validation", "Validation done by a human validator - 0 is invalid, 1 is valid"],
    ["Recommendation Details Comment", "Comment/Explanation provided by a human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                          Column Name  \
# 0             Recommendation Details
# 1  Recommendation Details Validation
# 2     Recommendation Details Comment
#
#                                                                                    Explanation
# 0  Raw Copilot Recommendation Details captured by the ambassador as they figure in the tracker
# 1                              Validation done by a human validator - 0 is invalid, 1 is valid
# 2                                            Comment/Explanation provided by a human validator

# %% [markdown]
# ## 1.1 Defining Performance
#
# These 2 datasets have already been evaluated by human validators.
#
# This means we can use the previous labels to calculate Sensitivity, Recall and F1 for this dataset, which will give us performance metrics we can analyse and optimise. We will be looking at the following metrics.
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$

# %% [markdown]
# We will create a dataframe where we will store the results of our tests as we run them.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])


test_results
# Out:
# Empty DataFrame
# Columns: [test_name, sensitivity, precision, f1_score]
# Index: []

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue related to the app's menu being convoluted and crowded, which directly impacts the user's ability to use the product."
# }
# ```

# %% [markdown]
# The model is giving us back a JSON wrapped in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "The feedback addresses a usability issue related to the app's menu being convoluted and crowded, which directly impacts the user's ability to use the product."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through the rows of one of our datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the entry
#     - 2. Evaluate if the LLM did a good job or not
#           - LLM => Valid, Human => Valid, then *true positive*
#           - LLM => Invalid, Human => Invalid, then *true negative*
#           - LLM => Valid, Human => Invalid, then *false positive*
#           - LLM => Invalid, Human => Valid, then *false negative*
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store, dataset):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for index, row in dataset.iterrows():
        # avoid token limit if needed every 10 rows 
        print(row_counter)
        if row_counter >= 10:
            print(f"Rate limit is close, continuing in {60} seconds...")
            time.sleep(61)
            row_counter = 0
                
        llm_res = send_prompt(prompt, row['Recommendation Details'])
        llm_res = clean_llm_response(llm_res)
        row_counter += 1
        print(row['Recommendation Details'],llm_res)

        try:
            llm_res = json.loads(llm_res)
        except json.JSONDecodeError as e:
            print(f"[WARN] Failed to parse LLM response as JSON: {e}")
            continue

        human_validation = row['Recommendation Details Validation']
        if llm_res['valid'] == True and human_validation == 1:
            tp += 1
        elif llm_res['valid'] == False and human_validation == 0:
            tn += 1
        elif llm_res['valid'] == True and human_validation == 0:
            fp += 1
        elif llm_res['valid'] == False and human_validation == 1:
            fn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Loose Zero Shot Prompt
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe high level criteria that is frequently mentioned by human validators to mark insights as valid or invalid. These are drawn from analysing the reasons as to why validators mark insights as valid or invalid.

# %%
loose_zero_shot_prompt_Test1 = '''
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Set 1: Valid Copilot Recommendation Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Relevance: The recommendation is clearly aligned with the customer's specific needs or how they use Microsoft 365

    - B) Copilot Focus: The recommendation includes specific mention of Copilot and its features

    - C) Demonstrated Benefit: The recommendation explicitly outlines the benefits or expected impact for the customer

    - D) Workflow Impact: The recommendation includes details about Microsoft 365 features and how they will improve the customer's workflow

    - E) Specificity: The recommendation targets a specific Microsoft 365 application (e.g., Outlook, Teams, Excel, etc.)

## Set 2: Invalid Copilot Recommendation Criteria

Meeting any of the criteria below is enough for the entry to be considered invalid.

    - F) Generic/Vague: The recommendation lacks specific detail about Copilot features or their benefits

    - G) Misaligned: The recommendation does not align with any known customer need or business goal

    - H) No Copilot Mention: The recommendation does not mention any specific Copilot functionality

    - I) Template-based: The recommendation appears copy/pasted or overly generic, lacking personalization

    - J) No Demonstrated Benefit: The recommendation does not explain how it would help the customer or impact their workflow


## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above

'''

# %%
# Test Loose Zero Shot Prompt here 
test_results = analyse_test_prompt('loose_zero_shot_20_Test1', loose_zero_shot_prompt_Test1, test_results, copilot_recommendation_20)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#   "valid": false,
#   "reasoning": "The entry lacks specificity and does not provide detailed information about Copilot features and their benefits. While Copilot is mentioned, the recommendation is generic and fails to demonstrate a clear alignment with specific customer needs (criterion F). It also lacks any demonstrated impact on workflow (criterion J). Furthermore, the use of multiple applications without specific needs or workflow improvements makes the recommendation appear overly template-based and vague (criterion I)."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#   "valid": true,
#   "reasoning": "The recommendation meets all criteria for Set 1. It is relevant as it targets the administrator's objective of utilizing Microsoft Teams (A). It explicitly mentions Copilot functionality within Microsoft Teams chat and channels (B). The demonstrated benefits, such as enhanced meeting productivity, efficient summarization, and prompt responses, are clearly outlined (C). Specific details about workflow improvements through Microsoft Teams features are provided (D). Lastly, it is specific to the Microsoft Teams application (E)."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria in Set 1, making it valid. It is relevant as it provides recommendations aligned with typical Microsoft 365 usage such as email management, virtual meetings, and presentation creation. It focuses on Copilot features explicitly and demonstrates their benefits, including organizing workflows, enhancing meeting productivity, and improving presentation design. It has specificity by targeting particular applications: Outlook, Teams, and PowerPoint."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#   "valid": true,
#   "reasoning": "The entry meets all criteria in Set 1 for a valid recommendation. It is relevant (A) as summarizing email threads aligns with saving the customer time in Outlook use. It focuses on Copilot (B) by mentioning Copilot explicitly for summarization functionality. There is a demonstrated benefit (C) outlined, which is saving time. Workflow impact (D) is included as it improves email management efficiency within Outlook. Lastly, the recommendation is specific (E) as it targets Outlook directly."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#   "valid": true,
#   "reasoning": "The recommendation meets all criteria under Set 1. It is clearly aligned with the customer's need for forecasting capabilities in asset management (A: Relevance). Copilot is explicitly mentioned as the solution (B: Copilot Focus), and the benefits such as efficient asset tracking, better decision-making, and productivity improvements are clearly outlined (C: Demonstrated Benefit). The workflow impact is explained through Copilot's role in enhancing data analysis and visualization in Excel (D: Workflow Impact), and the recommendation specifically focuses on the Microsoft 365 application, Excel (E: Specificity)."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#   "valid": true,
#   "reasoning": "The recommendation meets all criteria from Set 1. It is relevant (aligned with the customer's need for staying organized and saving time), explicitly mentions Copilot and its features (summarizing meetings, scheduling appointments, and extracting key notes), demonstrates benefits (staying organized and time-saving), impacts workflow (enhances meeting management within Teams), and is specific to a Microsoft 365 application (Teams)."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#   "valid": false,
#   "reasoning": "The recommendation is invalid because it does not meet several of the Valid Copilot Recommendation Criteria. While it does mention Copilot and a specific feature in PowerPoint, it fails to demonstrate clear alignment with the customer's specific need (Set 1 - Criteria A). The customer's objective is to start a new small organization, but the recommendation about creating presentations does not explicitly address how this ties into their workflow or business goals. Additionally, the recommendation lacks a detailed explanation of the workflow impact (Set 1 - Criteria D) and expected benefits (Set 1 - Criteria C). This results in a lack of specificity regarding the practicality or improvement to the customer's situation. As such, it meets Set 2 - Criteria G (Misaligned) and fails Set 1 - Criteria A, C, and D."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria from Set 1 for Valid Copilot Recommendation. It is relevant (Criteria A) as it aligns with automating routine email and scheduling tasks, explicitly focuses on Copilot and its features (Criteria B) such as auto-drafting emails and scheduling meetings, demonstrates clear benefits (Criteria C) like improving communication efficiency and organizing timely meetings, discusses workflow impact (Criteria D) by automating routine tasks, and specifies Outlook as the application (Criteria E)."
# }
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  {
#   "valid": true,
#   "reasoning": "The recommendation fulfills all criteria in Set 1 for a valid Copilot recommendation. It is relevant to the specific need of improving presentation creation efficiency (A), focuses on Copilot's specific features like design suggestions and point summarization (B), outlines the benefits such as saving time, enhancing creativity, and producing impactful presentations (C), links directly to workflow improvements in PowerPoint (D), and specifically targets PowerPoint as the Microsoft 365 application (E)."
# }
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   {
#   "valid": true,
#   "reasoning": "The entry meets all criteria under Set 1 for a valid Copilot recommendation. A) Relevance: It aligns with centralized file storage, a customer-specific need. B) Copilot Focus: It specifically mentions Copilot functionalities like drafting, summarizing, and reply suggestions. C) Demonstrated Benefit: It outlines how Copilot enhances email management and supports file retrieval, improving workflows. D) Workflow Impact: Integration with SharePoint and OneDrive for file retrieval and leveraging data insights enhances productivity. E) Specificity: The recommendation is focused on Copilot in Outlook."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#   "valid": false,
#   "reasoning": "The entry fails to meet Set 1 criteria for validity. While Copilot is mentioned, the entry lacks sufficient specificity (criterion E), as it does not detail specific Microsoft 365 features or applications beyond generic mentions like Outlook, Teams, and PowerPoint. Additionally, the entry fails to demonstrate explicit benefits or impacts for the customer (criterion C), making it invalid. It also falls under Set 2 criteria F (Generic/Vague) due to the lack of detail about Copilot features or their benefits."
# }
# 1
#
# Drafting emails in Outlook {
#   "valid": false,
#   "reasoning": "The entry 'Drafting emails in Outlook' is invalid because it is vague and lacks specific details about Copilot features or their benefits (Criterion F). Additionally, it does not mention any specific Copilot functionalities (Criterion H) nor does it demonstrate how it would impact workflow or outline the benefits (Criterion J)."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#   "valid": false,
#   "reasoning": "The recommendation mentions Copilot in Teams, but it does not explicitly outline demonstrated benefits (criterion C) or explain how specific Microsoft 365 features impact the customer's workflow (criterion D). Additionally, the recommendation lacks specificity beyond general mentions of communication and collaboration, making it somewhat generic/vague (criterion F)."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#   "valid": false,
#   "reasoning": "The entry is invalid because it does not fulfill multiple criteria in Set 1. Specifically, there is no mention of specific Copilot features (violating Criterion B), no explicit demonstration of benefits or impact for the customer (Criterion C), no discussion of workflow improvement using Microsoft 365 features (Criterion D), and no specificity targeting a Microsoft 365 application (Criterion E). Additionally, it seems generic and lacks personalization, violating Criterion F."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#   "valid": false,
#   "reasoning": "The entry is invalid because it fails to meet all criteria under Set 1. While it mentions Copilot and a proposed feature (criteria B), it does not demonstrate how this feature aligns with the customer's needs (criteria A), nor does it explicitly outline the impact on their workflow or provide specificity regarding Microsoft 365 features (criteria D and E). Additionally, the benefit of the proposed feature is somewhat vague (criteria J)."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#   "valid": false,
#   "reasoning": "The entry fails to meet Valid Copilot Recommendation criteria due to lack of demonstrated benefit (criterion C). While it mentions Copilot and its features (criterion B and criterion E), it does not explicitly outline the specific benefits or the expected impact on the customer's workflow (criterion D), nor does it seem aligned to a specific customer need or business goal (criterion A). This entry is also somewhat generic, potentially aligning with criterion F under the Invalid Copilot Recommendation criteria."
# }
# 6
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The entry 'Guided and Provided Documentation and link' is invalid because it does not mention Copilot functionality (criterion H), lacks specific details about its features or benefits (criterion F), does not target a specific need or workflow of the customer (criterion G), and does not demonstrate benefits or impact for the customer (criterion J). Additionally, it offers no specificity regarding a Microsoft 365 application (criterion E)."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#   "valid": true,
#   "reasoning": "The entry meets all criteria for Valid Copilot Recommendation. It demonstrates relevance (A) by addressing the customer's real estate industry needs for streamlining processes and email management. It explicitly mentions Copilot (B) and its capabilities. The benefits (C) are outlined as simplifying email organization and improving workflow efficiency. Workflow impact (D) is detailed in terms of streamlining email processes, and specificity (E) is targeted at email management within Microsoft 365."
# }
# 8
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The entry is invalid because it lacks specific detail about Copilot features, does not mention any Copilot functionality (criterion H), and fails to outline demonstrated benefits or workflow impacts (criteria J and D). Additionally, it appears generic and template-based (criterion F and I)."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#   "valid": false,
#   "reasoning": "The entry lacks specificity about a particular Microsoft 365 application (violates criterion E) and does not outline how Copilot Chat and Bing will improve the customer's workflow (violates criterion D). Additionally, while there is mention of Copilot, the recommendation does not provide clear, demonstrated benefits or align specifically to customer needs (violates criteria C and A)."
# }
# 111.18037700653076
# /var/folders/l5/mgfyqzvn1b91vhsqpws_8vyh0000gn/T/ipykernel_44478/1299775133.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_store = pd.concat([results_store, new_results_row], ignore_index=True)

# %%
test_results
# Out:
#                   test_name  sensitivity  precision  f1_score
# 0  loose_zero_shot_20_Test1          0.8   0.888889  0.842105

# %%
loose_zero_shot_prompt_Test2 = '''
What You Do
You check Copilot Value-Add recommendations to see if they really help customers—not just solve a small problem, but make their work faster, easier, or more successful.

Good Recommendations ✅
    - Fits the customer's needs → It helps with how they already use Microsoft 365.

    - Mentions Copilot features → It's clearly about Copilot, not just general advice.

    - Explains the benefits → Shows why it's useful.

    - Gives details on features & workflow impact → How does it make work better?

    - Talks about specific apps (Outlook, Teams, Excel, etc.) → Targeted tips are better.

Bad Recommendations ❌
    - Too vague → Doesn't really say how Copilot helps.

    - Not related to customer needs or business goals → Doesn't fit their actual work.

    - No mention of Copilot features → Must be about Copilot, not just Microsoft 365.

    - Copy-paste or template responses → Needs to be personal and useful.

    - Doesn't explain impact → Just saying something is good isn't enough—how does it help?

AI Output Format:
    json
    {
        "valid": make it true if the entry is considered valid, false if invalid,
        "reasoning": add your reasoning based on the criteria set above
    }
'''

# %%
# Test Loose Zero Shot Prompt here 
test_results = analyse_test_prompt('loose_zero_shot_20_Test2', loose_zero_shot_prompt_Test2, test_results, copilot_recommendation_20)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#     "valid": false,
#     "reasoning": "While the recommendation mentions some Copilot features related to different apps, it remains too vague and generic. It does not go into detail about specific workflows or scenarios where Copilot can uniquely help the customer. For example, how exactly does Copilot draft emails in Outlook, analyze data in Excel, or automate tasks? There is no explanation of the impact or benefits tailored to the customer's needs, and the advice seems copy-pasted or templated rather than personalized. Additionally, while providing an article might be helpful, it’s unclear if it addresses the specific Copilot features or customer goals."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#     "valid": true,
#     "reasoning": "The recommendation is valid because it clearly fits the customer's needs by addressing their objective to utilize Microsoft Teams. It explicitly mentions Copilot features (using Copilot within Teams chat and channels) and explains the benefits (enhancing meeting productivity, efficient summarization, and facilitating prompt responses). Additionally, the recommendation is targeted to a specific app (Teams), making it relevant and impactful."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#     "valid": true,
#     "reasoning": "This recommendation is valid because it directly mentions Copilot features across multiple apps (Outlook, Teams, and PowerPoint) and explains how they impact workflows, helping users manage emails, meetings, and presentations more efficiently. It provides specific details on the features (e.g., highlighting key messages, offering response suggestions, arranging appointments, live captions, summarizing meeting notes, suggesting layouts, automating slide design, integrating multimedia content) and clearly outlines their benefits for customer work."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#     "valid": true,
#     "reasoning": "This recommendation is valid because it directly addresses a common need for customers—saving time by summarizing email threads—and ties it to a specific Copilot feature in Outlook. Summarizing email threads with Copilot can streamline work, especially when dealing with lengthy or complex chains of communication. It also explicitly explains the benefit (saving time), which aligns with the customer's goal of increasing efficiency in email management tasks."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#     "valid": true,
#     "reasoning": "This recommendation directly addresses the customer's need for forecasting capabilities in asset management and integrates Copilot features specific to Excel. It highlights how Copilot will enable predictive analysis, improve visualization, and reduce human error—all valuable impacts tied to the customer's business goals. Additionally, it explains the benefits of using Copilot, like increased efficiency and productivity, with specific detail on its application in asset tracking and decision-making processes."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#     "valid": true,
#     "reasoning": "The recommendation fits the customer's needs by highlighting features of Copilot in Teams that help with organization and time management. It specifically explains the benefits (saving time and staying organized) and mentions Copilot features like meeting summaries, scheduling appointments, and extracting keynotes from meetings. The connection to workflow impact is clear, as it demonstrates how Copilot can make work faster and easier for the customer."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#     "valid": false,
#     "reasoning": "The recommendation is invalid because it does not align with the customer's specific needs or goals, which involve deleting a tenant and starting a new organization. Suggesting Copilot features in PowerPoint for creating presentations from a file is unrelated to these objectives. Additionally, no reasoning is provided on how this feature makes their work faster, easier, or more successful in the context of their tenant or organization setup needs."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. {
#     "valid": true,
#     "reasoning": "The recommendation is valid because it specifically mentions Copilot features in Outlook, such as auto-drafting emails and scheduling meetings. These features are clearly tied to customer needs (streamlining communication and organizing meetings), explain the benefits (automating routine tasks for efficiency), and demonstrate workflow impact (saving time and improving organization). The suggestion is targeted and provides clear use cases for how Copilot can enhance work within Outlook."
# }
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  {
#     "valid": true,
#     "reasoning": "The recommendation clearly aligns with the customer's needs by addressing how Copilot in PowerPoint can help them create presentations faster and with less effort, which fits the way they likely use Microsoft 365. It mentions specific Copilot features, such as suggesting design improvements and summarizing key points automatically. The benefits are explained well, highlighting time savings, enhanced creativity, and better impact. It provides details on how Copilot can make work better, specifically mentioning applications such as PowerPoint and professional workflows like branding proposals, marketing pitches, and client presentations."
# }
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   {
#     "valid": true,
#     "reasoning": "This recommendation is valid because it directly mentions Copilot features in Outlook, such as drafting messages, summarizing conversations, and reply suggestions. It explains the benefits, including improved email management and efficiency. Additionally, it highlights how Copilot supports organizational goals like centralized file storage through effortless file retrieval from SharePoint and OneDrive using natural language queries. The mention of data-driven insights adds specific workflow impact, making this recommendation useful and relevant to the customer's needs."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#     "valid": false,
#     "reasoning": "While educating the customer about Copilot's capabilities is useful, this recommendation is too vague and lacks specific details about how Copilot can help in their workflow or address their needs. It doesn't mention particular features, provide examples, or explain the benefits or impact on their work. To be valid, the recommendation needs to go beyond a general overview and focus on the application's impact in specific scenarios or workflows."
# }
# 1
#
# Drafting emails in Outlook {
#     "valid": false,
#     "reasoning": "The recommendation is too vague and does not mention how Copilot specifically helps with drafting emails in Outlook. It also fails to explain the benefits, provide feature details, or describe workflow impacts. To be a valid recommendation, it should mention Copilot features like AI-generated templates, automated responses, or refinement suggestions, and explain how these improve email drafting efficiency."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#     "valid": false,
#     "reasoning": "The recommendation is too vague and doesn't specifically highlight any Copilot features. While it generally discusses Teams' functionality, it doesn't explain how Copilot adds value or improves workflows. There is no mention of specific Copilot capabilities (e.g., automating tasks, summarizing conversations, creating action items, etc.) or how it addresses the customer's needs. Additionally, it doesn't provide details on workflow impact or benefits."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#     "valid": false,
#     "reasoning": "The recommendation does not meet the criteria as it is too vague and fails to explain how Copilot can address the customer's needs or improve their work. There is no mention of specific Copilot features, benefits, or impact on their workflow. Additionally, sharing general details and insisting on using the free version does not provide actionable value, targeted tips, or relevance to the customer’s current use of Microsoft 365."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#     "valid": false,
#     "reasoning": "The suggestion does not align with the customer's needs for how they typically use Microsoft 365 or Copilot. Copilot for Outlook is primarily focused on improving productivity in email workflows, such as drafting, summarizing, and replying to emails. A text-to-image feature is not connected to the existing Copilot functionality or the core purpose of Outlook, so this recommendation feels out of scope. Additionally, Copilot features were not clearly mentioned, and the impact on work is unexplained, making it overly vague."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#     "valid": true,
#     "reasoning": "The recommendation is valid because it clearly mentions Copilot features, including specific examples such as summarizing email threads, drafting documents, analyzing data, automating tasks, and generating creative ideas. It also highlights how Copilot integrates seamlessly into Microsoft 365 apps like Outlook, Word, Excel, and Teams, addressing customer needs and explaining workflow improvements effectively. Additionally, it informs the customer about tangible benefits, making the suggestion targeted and useful."
# }
# 6
#
# Guided and Provided Documentation and link {
#     "valid": false,
#     "reasoning": "The recommendation is too vague and does not mention specific Copilot features or explain the benefits. It also lacks details about how Copilot fits the customer's needs, and it does not explain the impact on their workflow or reference specific Microsoft 365 apps. Simply mentioning 'guided and provided documentation and link' doesn't clarify how it helps the customer or relates to Copilot's value-add."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#     "valid": true,
#     "reasoning": "This recommendation meets the criteria for a good Copilot Value-Add recommendation. It fits the customer's need (streamlining processes and email management), mentions Copilot features (simplifying email organization and improving workflow efficiency), and provides a clear explanation of benefits tailored to the customer's real estate business. The suggestion is targeted and specific, addressing their email management issues effectively."
# }
# 8
#
# Guided and Provided Documentation and link {
#     "valid": false,
#     "reasoning": "The statement 'Guided and Provided Documentation and link' is too vague and does not explain how Copilot helps the customer. It doesn't mention any specific Copilot features, how it fits the customer's needs, or the benefits it provides. Additionally, there is no explanation of the impact on workflow or detailed information about specific Microsoft 365 apps Copilot could enhance. This appears to be a generic and unhelpful response."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#     "valid": false,
#     "reasoning": "The recommendation lacks sufficient detail and does not directly explain how Copilot fits into the customer’s specific needs or workflows. While it mentions the search feature, it does not provide specific Copilot features, how they improve the customer's work, or the particular benefits of its integration within Microsoft 365 apps. Additionally, the recommendation is vague and does not explain the specific impact on productivity or how Copilot's Bing capabilities are more than generic search. To be valid, it should highlight the distinct role of Copilot Chat and Bing in delivering actionable information, tailored to the customer's tasks."
# }
# 107.91223692893982

# %%
test_results
# Out:
#                   test_name  sensitivity  precision  f1_score
# 0  loose_zero_shot_20_Test1          0.8   0.888889  0.842105
# 1  loose_zero_shot_20_Test2          0.8   0.800000  0.800000

# %%
loose_zero_shot_no_negative_criteria_Test1 = """
You are an AI assistant that validates entries based on specific criteria. 

Your job is to mark any entries given to you as valid or invalid. An input will be valid whenever it conforms to any of the following sets of criteria.

## Valid Copilot Recommendation Criteria

Meeting all criteria below is a must have for the entry to be considered valid, otherwise it will be invalid

    - A) Relevance: The recommendation is clearly aligned with the customer's specific needs or how they use Microsoft 365

    - B) Copilot Focus: The recommendation includes specific mention of Copilot and its features

    - C) Demonstrated Benefit: The recommendation explicitly outlines the benefits or expected impact for the customer

    - D) Workflow Impact: The recommendation includes details about Microsoft 365 features and how they will improve the customer's workflow

    - E) Specificity: The recommendation targets a specific Microsoft 365 application (e.g., Outlook, Teams, Excel, etc.)

## Response ##

You will always respond in JSON format with the following fields:
* valid - make it true if the entry is considered valid, false if invalid
* reasoning - add your reasoning based on the criteria set above
"""

# %%
test_results = analyse_test_prompt('loose_zero_shot_20_no_negative_criteria_Test1', loose_zero_shot_no_negative_criteria_Test1, test_results, copilot_recommendation_20)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#   "valid": false,
#   "reasoning": "The entry does not meet all the required criteria. While it mentions Copilot and outlines its integration into various Microsoft 365 apps, it lacks specificity about how the recommendations align with the customer's specific needs (Criteria A). The benefits and workflow impacts mentioned are generic and do not provide enough detail about how Copilot improves workflows for the customer (Criteria C, D). Furthermore, while Microsoft 365 applications are named, there is insufficient specificity around the unique features or applications of Copilot within each mentioned app (Criteria E)."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for a valid Copilot recommendation. (A) It is relevant as it aligns with the customer's objective of utilizing Microsoft Teams. (B) Copilot and its features are specifically mentioned as part of the recommendation. (C) The benefits, such as enhancing meeting productivity, providing summarization, and facilitating prompt responses, are explicitly outlined. (D) Workflow improvements within Microsoft Teams chat and channels are highlighted. (E) The recommendation specifically targets Microsoft Teams."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#   "valid": true,
#   "reasoning": "The entry satisfies all the valid recommendation criteria. It is relevant to customer needs (email management, virtual meetings, and presentation creation) and focuses on specific Copilot features in Outlook, Teams, and PowerPoint, demonstrating their benefits like improved email handling, meeting organization, and effective presentation creation. It details how Microsoft 365 features, including Copilot, enhance workflows and targets specific applications (Outlook, Teams, and PowerPoint)."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#   "valid": true,
#   "reasoning": "The entry meets all the required criteria for a valid Copilot recommendation: (A) Relevance: It addresses saving time, which aligns with the customer's need for efficiency in email management; (B) Copilot Focus: Specific mention of Copilot for summarizing email threads; (C) Demonstrated Benefit: Explicitly outlines the time-saving benefit; (D) Workflow Impact: Details how Copilot in Outlook will improve the workflow by summarizing email threads; (E) Specificity: Targets the Outlook application."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#   "valid": true,
#   "reasoning": "The recommendation meets all the valid criteria: (A) Relevance - it aligns with the customer's need for forecasting capabilities in asset management; (B) Copilot Focus - it specifically mentions Copilot for Excel and its features; (C) Demonstrated Benefit - it outlines the benefits, such as enhanced data analysis, reduced human error, and improved productivity; (D) Workflow Impact - it mentions how Copilot for Excel will improve asset tracking and decision-making; (E) Specificity - the recommendation targets Excel as the specific Microsoft 365 application."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for a valid Copilot recommendation: (A) Relevance: It aligns with the customer's needs for staying organized and saving time. (B) Copilot Focus: It explicitly mentions Copilot and its features in Teams. (C) Demonstrated Benefit: It outlines benefits such as summarizing meetings, scheduling appointments, and highlighting key notes to save time for other important tasks. (D) Workflow Impact: It describes how these features improve the workflow by enhancing organization and efficiency. (E) Specificity: It specifically targets Microsoft Teams as the application."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#   "valid": false,
#   "reasoning": "The recommendation mentions Copilot features in PowerPoint, satisfying the Copilot Focus (B) and Specificity (E) criteria. However, it does not clearly align with the customer's specific needs or use of Microsoft 365 (A), as the customer aims to delete a tenant and start a new organization, which is unrelated to creating presentations. Additionally, the recommendation lacks information on the benefit or expected impact for the customer (C) and does not detail how PowerPoint Copilot improves the customer's workflow regarding this context (D)."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. {
#   "valid": true,
#   "reasoning": "The entry meets all Valid Copilot Recommendation Criteria. It is relevant to the customer's needs (automation of routine tasks), focuses on Copilot and its features (auto-drafting emails and scheduling meetings), outlines the expected benefits (efficient communication and timely meetings), details workflow impact (automation for routine tasks using Outlook), and specifies a specific Microsoft 365 application (Outlook)."
# }
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  {
#   "valid": true,
#   "reasoning": "The entry meets all the criteria for a valid Copilot recommendation. It is relevant to the customer's need for creating presentations faster with less effort (A: Relevance). Copilot and its specific features, such as design improvements and summarizing key points, are explicitly mentioned (B: Copilot Focus). The benefits, including saving time, enhancing creativity, and ensuring impactful presentations, are clearly outlined (C: Demonstrated Benefit). The workflow impact is detailed as it explains how Copilot improves the presentation creation process within PowerPoint (D: Workflow Impact). Lastly, the entry targets the specific Microsoft 365 application, PowerPoint (E: Specificity)."
# }
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   {
#   "valid": true,
#   "reasoning": "The entry meets all criteria: (A) Relevance, as the recommendation aligns with the need for efficient email management and centralized file storage; (B) Copilot Focus, since it mentions Copilot's features such as drafting, summarizing, and reply suggestions; (C) Demonstrated Benefit, by outlining the impact of streamlined workflows and effortless file retrieval; (D) Workflow Impact, as the entry describes features improving email and file management workflows; (E) Specificity, targeting Outlook as the specific Microsoft 365 application."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#   "valid": false,
#   "reasoning": "The entry lacks several key criteria to be considered valid. While it mentions Copilot and its integration into Microsoft 365 apps, it fails to explicitly outline the benefits or expected impact for the customer (criteria C). Additionally, it does not include details on how Microsoft 365 features specifically improve the customer's workflow (criteria D). There is also a lack of specific demonstrated workflow impacts for each mentioned application (criteria E)."
# }
# 1
#
# Drafting emails in Outlook {
#   "valid": false,
#   "reasoning": "The entry lacks several of the required criteria for validity. It does not mention specific Copilot features (criterion B), does not explicitly outline the benefits or expected impact (criterion C), lacks details about how Microsoft 365 features improve the workflow (criterion D), and does not provide specificity beyond the mention of Outlook (criterion E)."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#   "valid": false,
#   "reasoning": "The recommendation mentions Copilot in Teams and its features, but it does not clearly outline the specific benefits or expected impact for the customer, nor does it explicitly detail how it improves the customer's workflow. Additionally, while Teams is mentioned, there is a lack of demonstrated alignment with the customer's specific needs. Therefore, it fails to fulfill all the necessary criteria."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#   "valid": false,
#   "reasoning": "The entry does not meet the required criteria. While it mentions explaining Copilot to the customer, it does not explicitly align with the customer's specific needs (Relevance), it does not outline benefits or workflow improvements (Demonstrated Benefit, Workflow Impact), and it does not reference specific Microsoft 365 applications (Specificity)."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#   "valid": false,
#   "reasoning": "The entry fails to meet the Valid Copilot Recommendation Criteria. While the suggestion aligns with Copilot (Criteria B), it does not clearly outline any workflow impact or describe how Microsoft 365 features would improve the customer's workflow (Criteria D). Furthermore, it lacks explicit mention of demonstrated benefits or expected impact for the customer (Criteria C). Additionally, the recommendation does not directly address a specific Microsoft 365 application (Criteria E) in terms of functionality improvements. The concept is also more generic rather than specific to a customer's use case (Criteria A)."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#   "valid": false,
#   "reasoning": "The entry does mention Copilot and its features (criterion B) and identifies specific Microsoft 365 applications (criterion E). However, it falls short of explicitly aligning the recommendation with the customer's specific needs (criterion A), does not clearly outline the benefits or expected impact for the customer (criterion C), and does not detail how the features will improve the customer's workflow (criterion D). Thus, it does not meet all the required criteria."
# }
# 6
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The entry does not meet the criteria. It does not mention Copilot or its features (Criterion B), fails to outline benefits or impact (Criterion C), does not specify details about Microsoft 365 features or workflow improvements (Criterion D), and does not target a specific Microsoft 365 application (Criterion E)."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#   "valid": false,
#   "reasoning": "The entry lacks specificity in outlining which Microsoft 365 application is being targeted, violating the 'Specificity' criterion. While it mentions Copilot and implies benefits to the workflow (email organization and workflow efficiency), it does not include sufficient detail about the specific features of Copilot or Microsoft 365 that will directly improve the customer's workflow, failing the 'Workflow Impact' criterion."
# }
# 8
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The entry does not meet the criteria. It lacks relevance (A) and Copilot focus (B); there is no mention of Copilot features or alignment with customer needs. Additionally, there is no explicit demonstration of benefits (C), workflow impact (D), or specificity targeting a particular Microsoft 365 application (E). The phrase 'Guided and Provided Documentation and link' is too vague and does not adhere to the criteria."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#   "valid": false,
#   "reasoning": "The recommendation mentions Copilot Chat and Bing Experience and highlights the feature of driving productivity with accurate information via search. However, it does not sufficiently meet all the valid Copilot Recommendation Criteria. Specifically:
#
# - A) Relevance: The recommendation does not clarify how it aligns with the customer's specific needs or usage of Microsoft 365.
# - C) Demonstrated Benefit: While productivity is mentioned, the explicit and detailed benefits or expected impact for the customer are not clearly outlined.
# - D) Workflow Impact: There is no detail about Microsoft 365 features or how they specifically improve the customer's workflow.
# - E) Specificity: Bing Experience is mentioned, but it does not target a specific Microsoft 365 application.
#
# Thus, the entry fails to meet multiple required criteria."
# }
# [WARN] Failed to parse LLM response as JSON: Invalid control character at: line 3 column 267 (char 286)
# 114.30041980743408

# %%
test_results
# Out:
#                                        test_name  sensitivity  precision  \
# 0                       loose_zero_shot_20_Test1          0.8   0.888889
# 1                       loose_zero_shot_20_Test2          0.8   0.800000
# 2  loose_zero_shot_20_no_negative_criteria_Test1          0.8   1.000000
#
#    f1_score
# 0  0.842105
# 1  0.800000
# 2  0.888889

# %%
loose_zero_shot_no_negative_criteria_Test2 = '''
What You Do
You check Copilot Value-Add recommendations to see if they really help customers—not just solve a small problem, but make their work faster, easier, or more successful.

Good Recommendations ✅
    - Fits the customer's needs → It helps with how they already use Microsoft 365.

    - Mentions Copilot features → It's clearly about Copilot, not just general advice.

    - Explains the benefits → Shows why it's useful.

    - Gives details on features & workflow impact → How does it make work better?

    - Talks about specific apps (Outlook, Teams, Excel, etc.) → Targeted tips are better.

AI Output Format:
    json
    {
        "valid": make it true if the entry is considered valid, false if invalid,
        "reasoning": add your reasoning based on the criteria set above
    }
'''

# %%
test_results = analyse_test_prompt('loose_zero_shot_20_no_negative_criteria_Test2', loose_zero_shot_no_negative_criteria_Test2, test_results, copilot_recommendation_20)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#     "valid": true,
#     "reasoning": "This recommendation clearly outlines Copilot features integrated within specific Microsoft 365 apps (Outlook, Word, Excel, Teams, etc.). It explains how Copilot helps users save time, enhance productivity, and make smarter decisions while highlighting specific workflows like drafting emails, editing documents, analyzing data, collaborating in Teams, and automating tasks. The inclusion of a helpful article further supports the recommendation with detailed information. This meets the criteria of being beneficial, targeted, and Copilot-centric."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#     "valid": true,
#     "reasoning": "The recommendation fits the administrator's objective of utilizing Microsoft Teams, a specific app in Microsoft 365. It mentions Copilot features such as enhancing meeting productivity, providing summarizations, and facilitating prompt responses. Additionally, it explains the benefits and details how Copilot can make work faster and more efficient for the customer’s needs."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#     "valid": true,
#     "reasoning": "This recommendation meets the criteria for a good suggestion. It fits the customer's needs by focusing on common tasks in Microsoft 365 apps such as Outlook, Teams, and PowerPoint. It specifically mentions Copilot features, including email management, live captions, meeting notes summarization, and slide design automation. The benefits are clearly stated, such as improved efficiency in managing emails, meetings, and presentations. Additionally, it describes the impact on workflows, such as enhancing presentation creation and helping with scheduling and meetings."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#     "valid": true,
#     "reasoning": "The recommendation fits the customer's needs by addressing a common task—reviewing lengthy email threads. It mentions Copilot features explicitly, as summarizing is a key Copilot capability in Outlook. The benefit is clear: saving time while reviewing emails. Additionally, the mention of Copilot's summarization functionality is specific to Outlook, showing targeted value to the customer. This aligns well with the criteria set above."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#     "valid": true,
#     "reasoning": "This recommendation fits the customer's needs as it addresses their desire for forecasting capabilities in asset management, aligning with how they might already use Microsoft 365 tools. It clearly mentions Copilot features for Excel, highlighting its advantages in data analysis, visualization, and error reduction. The benefits are explained, including improved asset tracking, decision-making, and productivity, giving specific workflow impact details. Furthermore, it is targeted at Excel, making it app-specific and more relevant."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#     "valid": true,
#     "reasoning": "The recommendation is valid because it fits the customer's need to save time and stay organized, which aligns with how they already use Microsoft 365. It specifically mentions Copilot features in Teams, such as summarizing meetings, scheduling appointments, and highlighting key points. It also explains the benefits, focusing on time savings and improved organization. Finally, it targets a specific app, Teams, making it a relevant and targeted tip."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#     "valid": false,
#     "reasoning": "The recommendation does not fit the customer's immediate need of deleting a tenant and starting a new organization. It also fails to explain how Copilot features in PowerPoint would directly help the customer achieve their goal. The advice is too general and lacks a clear link to the customer's specific situation."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. {
#     "valid": true,
#     "reasoning": "This recommendation is valid because it clearly mentions Copilot features in Outlook, such as automating email drafting and scheduling meetings. It aligns with the customer's needs by simplifying routine communication and organizational tasks. Furthermore, it explains the benefits by emphasizing efficiency and timeliness, and targets a specific app (Outlook) with actionable tips that improve workflow impact."
# }
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  {
#     "valid": true,
#     "reasoning": "The recommendation is valid because it aligns with the customer's needs by highlighting how Copilot in PowerPoint can make creating presentations faster and less effortful. It clearly mentions specific Copilot features like design suggestions and automatic summarization. The benefits are well-explained, emphasizing time savings, creativity enhancement, and impactful presentations. Additionally, the recommendation effectively focuses on PowerPoint, a specific Microsoft 365 app, and details its workflow impact for use cases like branding proposals, marketing pitches, and client presentations."
# }
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   {
#     "valid": true,
#     "reasoning": "This recommendation is valid because it directly highlights Copilot features and explains the benefits in a clear way. It mentions how Copilot in Outlook can streamline work by helping with drafting messages, summarizing conversations, and suggesting replies—specific features that improve workflow efficiency. It also details how Copilot can retrieve files from SharePoint or OneDrive with natural language queries, supporting centralized storage efforts, along with generating insights from emails. The recommendation aligns with customer needs and explicitly connects to Copilot features in Outlook."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#     "valid": false,
#     "reasoning": "The recommendation mentions Copilot's integration into Office apps and gives a general overview of its capabilities, but it doesn't offer specific benefits, features, or details on how Copilot can improve workflows in those apps. To meet the criteria, there needs to be clear explanations of how Copilot makes work faster, easier, or more successful in specific Office apps."
# }
# 1
#
# Drafting emails in Outlook {
#     "valid": true,
#     "reasoning": "The recommendation addresses a specific Copilot feature related to drafting emails in Outlook, which is clearly about Copilot's functionality. It fits the customer's needs as drafting emails is a common task in Outlook, and this feature could make their work faster, easier, or more successful. Additionally, it mentions a specific app (Outlook) and the targeted use case of email drafting, demonstrating workflow impact."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#     "valid": false,
#     "reasoning": "The recommendation mentions general benefits of using Teams, such as centralizing communication, sharing files, and collaborating in real-time. However, it does not explicitly mention Copilot features or how Copilot specifically adds value to this workflow. It lacks details on Copilot capabilities and benefits within the context of Teams, such as summarizing conversations, generating meeting agendas, or automating tasks."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#     "valid": false,
#     "reasoning": "The recommendation does not mention how Copilot fits the customer's specific needs or how it aligns with their usage of Microsoft 365. It also does not mention specific Copilot features, explain benefits, or detail how Copilot can make the customer's work faster, easier, or more successful. Additionally, encouraging the customer to start using Copilot is too general without discussing specific apps, workflows, or targeted tips."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#     "valid": false,
#     "reasoning": "The suggestion for a text-to-image feature in Copilot for Outlook does not fit the customer's needs based on how they already use Microsoft 365. Outlook is primarily an email tool, and while enhancing communication is valuable, text-to-image generation is not directly relevant for efficient or professional email communication. Additionally, the recommendation does not explicitly mention Copilot features or explain specific benefits/workflow impacts in the context of Outlook. It lacks targeted advice on how Copilot's existing capabilities could simplify or improve the customer's work directly."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#     "valid": true,
#     "reasoning": "This recommendation meets all the criteria for a good Copilot Value-Add recommendation. It fits the customer's needs by showing how Copilot integrates into their existing Microsoft 365 workflow. It mentions specific apps (Outlook, Word, Excel, Teams, etc.) and explains how Copilot features can assist. The benefits are clear—summarizing emails, drafting documents, analyzing data, automating tasks, and generating ideas—all of which make work faster, easier, or more successful. Additionally, the recommendation provides specific examples of features and their impact on workflows."
# }
# 6
#
# Guided and Provided Documentation and link {
#     "valid": false,
#     "reasoning": "The recommendation is too vague and does not specifically mention Copilot features, benefits, or how it improves Microsoft 365 workflows. It also lacks details about features, workflow impacts, and the targeted apps it may enhance. Simply providing documentation or links is not inherently Copilot-specific guidance or advice."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#     "valid": false,
#     "reasoning": "The recommendation mentions simplifying email organization and improving workflow efficiency, which aligns with the customer's need for email management. However, it does not clearly reference specific Copilot features or demonstrate how those features will make work faster, easier, or more successful. While the recommendation fits the customer’s general needs, it lacks details about Copilot-specific capabilities and their impact on workflows, as well as targeted mentions of apps like Outlook. To meet the criteria, it should explicitly tie the solution to Copilot features and explain the specific benefits and workflow improvements enabled within Microsoft 365 applications."
# }
# 8
#
# Guided and Provided Documentation and link {
#     "valid": false,
#     "reasoning": "The recommendation 'Guided and Provided Documentation and link' lacks information about how it fits the customer's needs, what Copilot features it utilizes, and the specific benefits it provides. It does not show how Copilot improves workflows or targets particular Microsoft 365 apps, so it fails to meet the criteria for a good recommendation."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#     "valid": false,
#     "reasoning": "While the recommendation mentions using the Bing Experience for search and productivity, it doesn't clarify how Microsoft 365 Copilot's specific capabilities or features fit the customer's needs. The recommendation lacks detail on Copilot features, workflows, or how those tools directly enhance productivity within Microsoft 365 apps like Outlook, Teams, or Excel. It also does not explain specific benefits of Copilot over general tools or workflows."
# }
# 108.11747217178345

# %%
test_results
# Out:
#                                        test_name  sensitivity  precision  \
# 0                       loose_zero_shot_20_Test1          0.8   0.888889
# 1                       loose_zero_shot_20_Test2          0.8   0.800000
# 2  loose_zero_shot_20_no_negative_criteria_Test1          0.8   1.000000
# 3  loose_zero_shot_20_no_negative_criteria_Test2          0.9   0.818182
#
#    f1_score
# 0  0.842105
# 1  0.800000
# 2  0.888889
# 3  0.857143

# %% [markdown]
# ### 3.2 Detailed Zero Shot Prompt
#
# In the prompt below, we provide a detailed list of criteria based on the latest version of the insights framework available at GigPlus. This has a detailed set of tiered criteria.

# %%
loose_detailed_zero_shot_prompt = '''
You are an AI assistant that validates **Copilot Value Add** recommendations in customer support conversations. These recommendations highlight how **Microsoft 365 Copilot** (the AI assistant integrated into apps like Teams, Outlook, Word, etc.) can provide **additional value** beyond solving the customer's immediate issue. A Copilot Value Add is essentially a **personalized suggestion** that goes the extra mile – it's tailored to the customer's unique situation and shows how Copilot can help them achieve their broader goals or improve an aspect of their work.

**What does a great Copilot Value Add look like?**  
It's **customer-centric**: The ambassador (support agent) clearly links a Copilot feature to a **specific business benefit** for that customer. It demonstrates how using Copilot will contribute to the customer's business or personal objectives (e.g., saving time, improving accuracy, boosting team collaboration). It also usually involves **showing Copilot in action** (like giving a quick demo or guiding the customer through using Copilot right there, so they experience its value first-hand). Throughout, it's **tailored to the customer's use case**: it addresses the customer's own pain points and workflows, with context about their environment, rather than being a generic pitch. In short, a valid value-add recommendation feels like helpful coaching or insight, not a sales script.

If an ambassador is an external consultant working on behalf of the customer, or if the recommendation is part of a promotional campaign, it's still crucial that they **define a relevant use case** so the customer can see the practical value. (For example, instead of just saying “Try Copilot's new feature X!”, they should say something like “Since you often have to do Y, Copilot's feature X could save you Z hours by...”). 

## Validation Criteria:

To mark the entry **Valid**, ensure the conversation's recommendation meets most of the following:

  - **Aligns with Needs/Goals:** It clearly connects a Copilot feature or capability with the customer's stated **business needs or goals**. (e.g., “Using Copilot in Excel will help you analyze these sales figures faster so you can meet your deadline.”)

  - **Provides Value-Add Insight:** It goes beyond the original support issue to offer something extra that contributes to the customer’s success. The ambassador demonstrates an understanding of the customer's context and gives a relevant, helpful suggestion.

  - **Hands-On or Clearly Described:** A strong recommendation either demonstrates the Copilot feature or clearly describes how it works and what benefit it brings to the customer. A live demo is ideal, but not required if the explanation is vivid and practical.

  - **Tailored to Use Case (Flexible):** The suggestion should ideally reference the customer’s specific scenario or pain point. However, clear and helpful recommendations that are relevant to common Microsoft 365 usage scenarios may still be considered valid.

  - **Copilot Mention (Flexible):** If the recommendation clearly describes a capability associated with Copilot (e.g. summarizing emails, drafting responses, generating insights), it can be valid even if the word "Copilot" is not mentioned—provided the feature is accurately described.

  - **Context and Impact:** The recommendation should help the customer understand when and why they might use the feature. Mentioning expected benefits (e.g. saving time, improving accuracy, reducing effort) is sufficient — precise metrics are not required.

If the recommendation is vague, generic, not aligned with a business goal or customer need, fails to explain the benefit of the feature, or sounds like a template without personalization — it should be marked **Invalid**.

**Output Format:**

Respond in JSON with:
```json
{
  "valid": true or false,
  "reasoning": "your explanation based on the validation criteria"
}
'''

# %%
test_results = analyse_test_prompt('loose_detailed_zero_shot_20', loose_detailed_zero_shot_prompt, test_results, copilot_recommendation_20)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#   "valid": false,
#   "reasoning": "The recommendation is generic and does not connect specific Copilot features to the customer's unique business goals or pain points. While it lists various capabilities of Copilot—such as drafting emails, editing documents, analyzing data, and automating tasks—it does not demonstrate how these features would specifically benefit the customer based on their needs or workflows. Additionally, there is no example or detailed explanation of how Copilot works, nor a tailored use case that would make the suggestions impactful. Simply providing a helpful article does not suffice as a personalized value-add recommendation."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#   "valid": false,
#   "reasoning": "The recommendation is too generic and lacks connection to the customer's specific business needs or goals. While it mentions using Copilot to enhance meeting productivity, summarize efficiently, and facilitate prompt responses, the ambassador does not provide a tailored suggestion or demonstrate how these features would benefit the administrator's stated objective of utilizing Microsoft Teams. A valid recommendation would need to clearly describe how Copilot's features (e.g., meeting summarization or drafting responses) directly align with the administrator's specific use case or workflows. Additionally, there is no hands-on demonstration or vivid explanation of how Copilot works in Microsoft Teams chat and channels."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#   "valid": false,
#   "reasoning": "The recommendation is generic and lacks personalization. While it describes Copilot capabilities across Outlook, Teams, and PowerPoint, it does not align these features with specific customer needs or goals. Additionally, there is no context provided about the customer's use case, pain points, or workflows, and no clear explanation of how these features would deliver value to the customer in their unique scenario. The suggestion reads more like a feature list rather than a tailored recommendation that provides value-add insights."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#   "valid": false,
#   "reasoning": "The recommendation mentions using Copilot for summarizing email threads as a time-saving feature, but it lacks any context regarding the customer's specific business goals, needs, or pain points. There is no explanation of the practical value or how it aligns with the customer's workflow. For the recommendation to be valid, the ambassador should explicitly connect this capability to a more tailored use case, such as a scenario where the customer deals with extensive email volumes or needs to prioritize actionable insights from long threads."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#   "valid": true,
#   "reasoning": "The recommendation aligns with the customer's stated desire for forecasting capabilities in asset management. It clearly connects Copilot for Excel with the specific goal of predictive analysis, explaining how the tool enhances data analysis, visualization, and reduces human error. The suggestion offers substantial value-add insight by emphasizing benefits such as efficient asset tracking, improved decision-making, and increased productivity—all directly relevant to the customer's context. While it doesn't describe a hands-on demo, the recommendation is vivid and practical, making it a valid Copilot Value Add."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#   "valid": true,
#   "reasoning": "The recommendation aligns with the customer's potential business goals of staying organized and saving time. It connects specific Copilot features in Teams, such as summarizing meetings, scheduling appointments, and highlighting key points, with the broader benefit of freeing up time for other important tasks. The explanation is clear and provides insight into how these capabilities can improve productivity, addressing common pain points related to managing meetings and follow-up tasks. While the exact demonstration of Copilot's functionality is not included, the description is vivid and practical, making the recommendation valid."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#   "valid": false,
#   "reasoning": "The recommendation to use Copilot in PowerPoint to create presentations from a file is disconnected from the customer's immediate need or broader goal, which is focused on setting up a new small organization after deleting a tenant. There is no clear link between the suggested Copilot feature and the customer's objectives, pain points, or workflows in this case. Additionally, the recommendation is generic and does not tailor to the customer's specific scenario, making it less relevant and valuable for their current context."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. Error: 429 Client Error: Too Many Requests for url: https://validationtest.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-10-21
# [WARN] Failed to parse LLM response as JSON: Expecting value: line 1 column 1 (char 0)
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  Error: 429 Client Error: Too Many Requests for url: https://validationtest.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-10-21
# [WARN] Failed to parse LLM response as JSON: Expecting value: line 1 column 1 (char 0)
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   Error: 429 Client Error: Too Many Requests for url: https://validationtest.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-10-21
# [WARN] Failed to parse LLM response as JSON: Expecting value: line 1 column 1 (char 0)
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#   "valid": false,
#   "reasoning": "The recommendation lacks a clear connection to the customer's specific business needs or goals. While mentioning Copilot features in commonly used apps like Outlook, Teams, and PowerPoint is informative, it's too generic and does not provide a tailored use case or value-add insight for the customer. Additionally, there is no clear description of how any of the features will benefit the customer or contribute to their success. To be valid, the recommendation should ideally include a practical example or demonstrate how Copilot can address the customer's unique pain points or workflows."
# }
# 1
#
# Drafting emails in Outlook {
#   "valid": false,
#   "reasoning": "The recommendation 'Drafting emails in Outlook' is too vague and generic. It does not connect the use of Copilot's email drafting capabilities to a specific customer need or business goal. There is no context about why the customer would need help drafting emails or how the feature would benefit their workflow or improve efficiency. A valid suggestion would explain how Copilot could assist with a particular challenge the user faces, such as saving time by quickly generating professional responses to frequent queries or summarizing long email threads, tailored to their use case."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#   "valid": false,
#   "reasoning": "The recommendation is generic and does not clearly align with the customer's stated needs or goals. It does not demonstrate a specific Copilot feature or provide value-add insight that goes beyond describing Teams' general capabilities. For the recommendation to be valid, it should connect a specific Copilot feature—like summarizing chat threads, automating follow-ups, or generating action plans after meetings—to a relevant use case or business benefit for the customer. Without further tailoring or hands-on demonstration, it lacks the personalization required to be considered valid."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#   "valid": false,
#   "reasoning": "The recommendation lacks specifics on how Copilot would address the customer's needs or goals. There's no connection made between the customer's context or workflows and the value that Copilot can provide. Simply suggesting that the customer try a free version, without explaining how Copilot could benefit them or demonstrating its capabilities, does not qualify as a value-add recommendation. To be valid, the ambassador should have tailored the suggestion to the customer's situation and articulated how Copilot would contribute to their success or solve a specific problem."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#   "valid": false,
#   "reasoning": "The recommendation from the customer is a feature suggestion for Copilot—specifically, a request for a text-to-image capability in Outlook Copilot. While this notion could potentially enhance its functionality, the conversation does not include a value-add recommendation from the ambassador that links an existing Copilot feature to the customer's business needs or goals. A valid Copilot Value Add requires identifying a current Copilot capability, explaining how it can help the customer with their workflows, and demonstrating or describing its benefits. This conversation lacks those elements and is focused on a speculative enhancement rather than coaching on present capabilities."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#   "valid": false,
#   "reasoning": "The recommendation is generic and lacks personalization or alignment with a specific customer need or business goal. While it briefly mentions some Copilot features, it does not connect these capabilities to the customer's workflows, pain points, or objectives. Furthermore, the explanation is broad and does not provide hands-on examples or describe how the customer would benefit concretely from using Copilot in their own use cases."
# }
# 6
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The provided response mentions guided assistance and documentation but does not clearly include a Copilot-specific recommendation or demonstrate how Copilot features align with the customer's business needs or goals. The response lacks personalization and does not showcase a value-add insight, such as how Copilot can specifically save time, improve accuracy, or boost productivity in the customer’s context. Without any clear mention of Copilot capabilities or their application to the customer's use case, the recommendation does not meet the validation criteria."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#   "valid": false,
#   "reasoning": "While the ambassador mentions using Copilot AI to simplify email organization and improve workflow efficiency, the recommendation lacks specific details on how Copilot addresses the customer's stated need for 'merging emails' in the real estate industry or streamlining processes. The explanation does not clearly describe any Copilot features, such as summarizing emails, organizing them into categories, or automating responses, nor does it connect the functionality to the customer's goals or use case. There is also no demonstration or vivid description of Copilot's capabilities in action, making the recommendation feel generic and underexplored."
# }
# 8
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The entry does not demonstrate how a Copilot feature connects to the customer's specific business needs or goals, provide any value-added insight, or describe a relevant use case. Simply guiding and providing documentation with a link is helpful for general troubleshooting but does not qualify as a Copilot Value Add since it lacks any customization, actionable recommendations, or description of how Copilot's features can help the customer achieve their objectives or improve their workflows."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#   "valid": false,
#   "reasoning": "The recommendation is too vague and lacks a clear connection to the customer's specific business needs or goals. While the concept of driving productivity with accurate information is mentioned, there's no attempt to tailor the suggestion to a particular use case or explain how using Copilot Chat and Bing Experience will specifically benefit the customer. Additionally, the feature's functionality is not clearly described, and the recommendation does not demonstrate practical relevance to the customer's workflows or pain points."
# }
# 102.32223677635193

# %%
test_results
# Out:
#                                        test_name  sensitivity  precision  \
# 0                       loose_zero_shot_20_Test1     0.800000   0.888889
# 1                       loose_zero_shot_20_Test2     0.800000   0.800000
# 2  loose_zero_shot_20_no_negative_criteria_Test1     0.800000   1.000000
# 3  loose_zero_shot_20_no_negative_criteria_Test2     0.900000   0.818182
# 4                    loose_detailed_zero_shot_20     0.285714   1.000000
#
#    f1_score
# 0  0.842105
# 1  0.800000
# 2  0.888889
# 3  0.857143
# 4  0.444444

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''

You are an AI assistant that validates **Copilot Value Add** recommendations in customer support conversations. These recommendations highlight how **Microsoft 365 Copilot** (the AI assistant integrated into apps like Teams, Outlook, Word, etc.) can provide **additional value** beyond solving the customer’s immediate issue. A Copilot Value Add is essentially a **personalized suggestion** that goes the extra mile – it’s tailored to the customer’s unique situation and shows how Copilot can help them achieve their broader goals or improve an aspect of their work.

**What does a great Copilot Value Add look like?**  
It’s **customer-centric**: The ambassador (support agent) clearly links a Copilot feature to a **specific business benefit** for that customer. It demonstrates how using Copilot will contribute to the customer’s business or personal objectives (e.g., saving time, improving accuracy, boosting team collaboration). It also usually involves **showing Copilot in action** (like giving a quick demo or guiding the customer through using Copilot right there, so they experience its value first-hand). Throughout, it’s **tailored to the customer’s use case**: it addresses the customer’s own pain points and workflows, with context about their environment, rather than being a generic pitch. In short, a valid value-add recommendation feels like helpful coaching or insight, not a sales script.

If an ambassador is an external consultant working on behalf of the customer, or if the recommendation is part of a promotional campaign, it’s still crucial that they **define a relevant use case** so the customer can see the practical value. (For example, instead of just saying “Try Copilot’s new feature X!”, they should say something like “Since you often have to do Y, Copilot’s feature X could save you Z hours by...”). 

## Validation Criteria:

To mark the entry **Valid**, ensure the conversation’s recommendation:

  - **Aligns with Needs/Goals:** It explicitly connects a Copilot feature or capability with the customer’s stated **business needs or goals**. (Does it say *which* Copilot feature, and *how* it helps the customer reach their goal or solve a problem? e.g. “Using Copilot in Excel will help you analyze these sales figures 10x faster, so you can make your quarterly report deadline.”)

  - **Provides Value-Add Insight:** It goes beyond the original support issue’s resolution to offer something extra. The ambassador is clearly focused on the customer’s broader success: they show they **understand the customer’s business/technical context** and give a suggestion that genuinely benefits the customer or their business (not just pushing a random feature). It should feel like they’re building a relationship or trust, not just closing a ticket.

  - **Hands-On Interaction:** Whenever possible, the ambassador actually **demonstrates or walks the customer through the Copilot feature** in real-time. (For example, “Let’s have Copilot draft an email for you right now so you see how it works.”) This tangible experience helps the customer immediately grasp the feature’s value. *(If a live demo isn’t possible, at least the conversation should vividly describe how to use the feature or what it would do for them.)*

  - **Tailored to the Use Case:** The suggestion is not one-size-fits-all; it’s personalized. It references the customer’s unique scenario, data, or pain point and shows **how Copilot addresses that specific situation**. (It should sound like, “Given you mentioned [pain point/need], Copilot can [specific solution].” If it’s generic or irrelevant to what the customer cares about, that’s not good.)

  - **Context and Impact:** It provides enough context about the feature and how it will fit into or improve the customer’s **workflow or satisfaction**. It might mention how it would save time in their daily routine, reduce errors in their process, improve their team’s communication, etc. The customer should be able to imagine exactly when and why they’d use Copilot from this explanation.

If any of these elements are missing (e.g. the ambassador just says “Try Copilot, it’s cool!” without context, or suggests a feature that doesn’t match the customer’s goals), then the recommendation is **Invalid**. Also, if the ambassador fails to show or explain the feature, or the customer is left confused about why they’d use it, that’s not a successful value-add.

###EXAMPLES

Example 1 (Valid):
Conversation excerpt: After resolving a Teams call quality issue, the ambassador says: “Since you run many large meetings, have you tried Copilot in Teams? It can generate a quick summary of your meetings and highlight action items. For instance, in your last all-hands, Copilot could have pulled out the three next steps everyone agreed on – saving you the time of writing up notes. Shall I show you how to do that?” They then walk the customer through using Teams Copilot to summarize a recent meeting recording, and the customer reacts positively.
Analysis: The ambassador specifically links a Copilot feature (Teams meeting summaries) to the customer’s goal (not having to manually summarize large meetings). They provided a hands-on demonstration (“Shall I show you…”) and clearly tailored it to the customer’s scenario (their last all-hands meeting). The value (time saved, clearer action items) was explicit.

Example 2 (Invalid):
Conversation excerpt: The support issue was about a SharePoint file permission error, which the ambassador fixed. Then the ambassador adds: “By the way, you should check out Copilot – it’s awesome. It can do a lot of cool things with your data!” The customer asks if it can help with file permissions, and the ambassador just says, “Not exactly, but it’s still worth exploring. Lots of our clients love it.” The customer murmurs “okay…,” sounding uncertain, and the call ends.
Analysis: This recommendation is vague and not tied to the customer’s issue or goals. The ambassador didn’t specify any feature (just “Copilot” broadly) or show how it would actually help this customer. There was no demonstration or concrete example relevant to the customer’s context (file management). It comes off as a superficial pitch. From a PLG perspective, it’s not useful – it doesn’t educate or excite the user, so it likely won’t drive adoption.

**Output Format:**

Respond in JSON with:
```json
{
  "valid": true or false,
  "reasoning": "your explanation based on the validation criteria"
}
'''

# %%
test_results = analyse_test_prompt('few shot', few_shot_prompt, test_results, copilot_recommendation_20)

print(test_results)
# Out:
# 0
#
# Informed customer that Copilot is integrated into the apps like Outlook, Word, Excel, Teams, and more. It helps save time, enhance productivity, and make smarter decisions.
# Draft and summarize email thread in Outlook
# Draft and edit documents faster in Word.
# Analyze data effortlessly in Excel.
# Collaborate seamlessly and boost meeting productivity in Teams.
# Automate repetitive tasks and free up time for strategic work.
# Provided helpful article {
#   "valid": false,
#   "reasoning": "The recommendation is too general and lacks personalization to the customer's specific needs or goals. While it mentions several Copilot features and their benefits, it does not tie any of these features explicitly to the customer's own pain points or workflows. For example, it does not provide context about why the customer would benefit from drafting emails faster in Outlook, analyzing data in Excel, or automating tasks. There is no demonstration or direct engagement to show the customer how Copilot works in practice, nor does it highlight how Copilot fits into their unique scenarios. Merely listing features and broad benefits is not sufficient to qualify as a Copilot Value Add under the criteria."
# }
# 1
#
# - Given the administrator's objective of utilizing Microsoft Teams, I recommended that the customer employ Copilot within Microsoft Teams chat and channels. This will assist in enhancing meeting productivity, providing efficient summarization, and facilitating prompt responses.
#  {
#   "valid": false,
#   "reasoning": "The recommendation mentions general benefits of using Copilot in Teams (enhancing meeting productivity, providing summarization, and facilitating prompt responses), but it does not explicitly connect these capabilities to the customer's stated objective or specific needs. Additionally, there is no mention of hands-on interaction or personalization for the administrator's scenario. It lacks tailored context, such as *how* Copilot features within Teams chat or channels would align with their unique workflow or goals. For example, it could have referenced how Copilot can summarize discussions from a specific project chat or assist with task coordination based on meeting conversations. Without those elements, this suggestion feels generic and doesn't qualify as a proper Copilot Value Add."
# }
# 2
#
# Copilot in Outlook assists with email management by highlighting key messages, offering response suggestions, and arranging appointments according to your availability. In Teams, Copilot can assist in setting up and managing virtual meetings, providing live captions, and summarizing meeting notes. In PowerPoint, Copilot can enhance presentation creation by suggesting layouts, automating slide design, and integrating multimedia content seamlessly. {
#   "valid": false,
#   "reasoning": "The recommendation lacks personalization and does not connect Copilot features to the customer's specific goals or needs. Although it describes several Copilot capabilities across Outlook, Teams, and PowerPoint, it fails to contextualize the information for the customer’s scenario or workflow. Additionally, there is no hands-on interaction or demonstration of the features to provide tangible value. The suggestion is generic and reads like a product advertisement rather than a customer-centric value-add tailored to a specific use case."
# }
# 3
#
#  To save time I recommended summarizing email threads using copilot for Outlook {
#   "valid": false,
#   "reasoning": "The recommendation lacks sufficient context about the customer's specific needs or goals. While summarizing email threads using Copilot for Outlook is a useful feature, the ambassador did not indicate how this aligns with the customer's particular workflows, pain points, or business objectives. Additionally, there is no sign of a demonstration or explanation of how the feature works or what tangible benefits the customer would gain from using it. For example, they could mention how summarizing threads saves time when managing lengthy email discussions related to projects or decisions. Without these elements, the recommendation feels generic rather than tailored or value-adding."
# }
# 4
# Copilot recommendation details:
# The customer expressed a desire for forecasting capabilities in asset management to enable predictive analysis. We recommend Copilot for Excel, which will enhance data analysis, visualization, and reduce human error. By leveraging Copilot's features, the customer will benefit from more efficient asset tracking, improved decision-making, and increased productivity. {
#   "valid": false,
#   "reasoning": "While the recommendation mentions that Copilot for Excel can assist with forecasting capabilities and benefits such as reducing human error, improving decision-making, and increasing productivity, it fails to demonstrate or articulate how Copilot specifically addresses the customer's stated need for predictive analysis in asset management. No specific feature of Copilot for Excel (e.g., generating predictive models, trend analysis, or automated data insights) is described in a way directly tied to the customer's goals. Additionally, there is no hands-on interaction, example, or workflow tailored to their asset management scenario. The suggestion comes off as generic rather than personalized."
# }
# 5
#
# I also suggested the use of copilot in teams emphasizing on how it can help by summarizing meetings, scheduling appointments and giving important key note from meetings. This way, they stay organized and save time for other important tasks. {
#   "valid": true,
#   "reasoning": "The recommendation explicitly connects specific Copilot features in Teams (summarizing meetings, scheduling appointments, capturing key notes) to the customer's goal of staying organized and saving time for other important tasks. These features directly address common pain points for busy professionals who manage meetings and schedules. The advice is practical and highlights clear business benefits, namely improved organization and efficiency. While it would have been stronger with evidence of a hands-on demonstration or a tailored example tied to the customer’s specific workflow, the recommendation is still valid as it links relevant Copilot features to broader customer goals."
# }
# 6
# Copilot recommendation details:
# The customer aims to delete the tenant created by his father and start a new small organization. During our conversation, I recommended Copilot features in PowerPoint to create presentations from a file {
#   "valid": false,
#   "reasoning": "The recommendation to use Copilot features in PowerPoint for creating presentations from a file does not align with the customer's stated goal of deleting a tenant and starting a new small organization. While Copilot in PowerPoint could be useful for creating business presentations, the recommendation lacks context and tailoring to the customer's specific use case or broader goals, such as setting up their new organization or managing tenant-related transitions. Furthermore, there is no indication that the ambassador demonstrated the feature or provided a direct insight related to its immediate relevance for the customer’s current needs."
# }
# 7
# I recommended using Copilot in Outlook for auto-drafting emails and scheduling meetings. These features can help automate routine tasks, making communication more efficient and ensuring that meetings are organized and timely. {
#   "valid": false,
#   "reasoning": "While the recommendation mentions Copilot's capabilities in Outlook for auto-drafting emails and scheduling meetings, it falls short of meeting the validation criteria. The suggestion is not explicitly tied to the customer's specific needs, goals, or scenarios, which makes it generic rather than personalized. Furthermore, there is no indication of a hands-on demonstration or contextual insight into how Copilot would improve their workflow or address their pain points. For this recommendation to be valid, the ambassador would need to tailor it to the customer's unique situation (e.g., explaining how Copilot could streamline a particular communication or scheduling challenge they face) and ideally provide a walk-through or vivid description to help the customer see its value firsthand."
# }
# 8
# Copilot recommendation details:
# recommended Copilot in PowerPoint so that they can create presentations faster and with less effort. Copilot can suggest design improvements and summarize key points automatically. This allows them to build professional branding proposals, marketing pitches, and client presentations with ease and saves time, enhances creativity, and ensures their presentations are impactful.  {
#   "valid": true,
#   "reasoning": "The recommendation clearly connects Copilot in PowerPoint to the customer's potential goals, such as creating professional branding proposals, marketing pitches, and client presentations. It highlights specific features (e.g., suggesting design improvements and summarizing key points automatically) that address the pain point of creating presentations faster and with less effort. The benefits—saving time, enhancing creativity, and ensuring impactful presentations—are explicitly stated, demonstrating value to the customer. While there is no mention of a hands-on demo, the explanation is thorough and tailored to the customer's use case of creating marketing and client materials, making the recommendation valid overall."
# }
# 9
#
# Copilot in Outlook enhances email management by streamlining message drafting, summarizing conversations, and providing reply suggestions. It also enables effortless file retrieval from SharePoint and OneDrive using natural language queries, and offers data-driven insights from emails, supporting the organization's goal of centralized file storage.
#   {
#   "valid": false,
#   "reasoning": "While the recommendation highlights multiple features of Copilot in Outlook, it fails to explicitly connect them to the customer's stated business needs or goals. No specific mention of the customer's context or pain points is provided, such as the challenges they face with email management or file storage. Additionally, there is no hands-on demonstration or personalized example showing how these features would benefit the customer in their specific workflow. Without tailoring the recommendation to the customer's unique scenario, it comes across as generic rather than an actionable value-add."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# I educated customer about the capabilities of Copilot and how it can help when integrated into office apps. I mentioned its functions in commonly used office apps like Outlook Teams PowerPoint etc {
#   "valid": false,
#   "reasoning": "The recommendation is too generic and does not tie any specific Copilot feature to the customer's unique business needs or goals. Simply mentioning Copilot's capabilities across commonly used apps like Outlook, Teams, or PowerPoint does not provide any tailored insight or a clear value-add for the customer. Additionally, there is no hands-on interaction or demonstration, and no specific use case from the customer's context is addressed. Without a concrete example showing how Copilot can help this particular customer achieve their objectives or solve a pain point, the suggestion lacks relevance and impact."
# }
# 1
#
# Drafting emails in Outlook {
#   "valid": false,
#   "reasoning": "The recommendation mentions drafting emails in Outlook but does not provide enough context about how Copilot specifically benefits the customer in their unique use case. It fails to align with the customer's stated business needs or goals, does not offer value-add insight, and lacks personalization. Additionally, there is no mention of a hands-on interaction or demonstration to show the feature in action. Without connecting the suggestion to the customer’s workflows or challenges, the value of Copilot remains unclear."
# }
# 2
# Copilot recommendation details:
# I shared that copilot in Teams that helps in centralize your team’s communication, share files, and collaborate in real-time through group chats, channels, and video meetings. {
#   "valid": false,
#   "reasoning": "While the ambassador shared general information about Copilot in Teams, the recommendation lacks a connection to the customer’s specific business needs or goals. It does not reference a specific Copilot feature or explain how it could address the customer’s unique scenario, pain point, or workflow. There’s no demonstration or tailored example, which fails to illustrate the tangible value Copilot could bring to the customer’s use case. This makes the recommendation generic and unengaging."
# }
# 3
# Cx was not aware of Copilot, I have explained and share the detail and insist him to start using Free version of copilot {
#   "valid": false,
#   "reasoning": "While the ambassador introduced Copilot to the customer and encouraged them to use the free version, the recommendation lacks specificity and personalization. It does not identify a particular Copilot feature or explain how it addresses the customer’s needs or goals. Additionally, no hands-on demonstration or tailored example was provided to showcase its value in the customer's specific context. This seems like a generic pitch rather than a meaningful, customer-focused value-add suggestion."
# }
# 4
#
# The customer suggested that Copilot for Outlook should include a text-to-image feature similar to ChatGPT. This enhancement would make the tool more useful for replying to emails, providing a richer and more engaging communication experience. {
#   "valid": false,
#   "reasoning": "The recommendation to include a text-to-image feature in Copilot for Outlook is not a valid Copilot Value Add. While the suggestion for enhancing Copilot's features represents feedback, it does not align with the purpose of providing a tailored, customer-centric insight on how Copilot can address current needs or workflows. It also lacks a specific connection to the customer's stated goals within their existing context and does not describe how Copilot's current capabilities could provide value. Additionally, there is no demonstration of a hands-on interaction with an established Copilot feature, nor is it relevant to solving the customer’s immediate issue or enhancing their workflow with Copilot's existing functionalities."
# }
# 5
#
# Informed customer that Copilot seamlessly integrates into Microsoft 365 apps like Outlook, Word, Excel, Teams etc. It leverages cutting-edge AI to assist with features, like summarizing email thread, drafting documents, analyzing data, automating repetitive tasks, or generating creative ideas.
# https://learn.microsoft.com/en-us/copilot/microsoft-365/microsoft-365-copilot-overview
#  {
#   "valid": false,
#   "reasoning": "The recommendation is vague and does not address the customer's specific needs, goals, or pain points. While it mentions general capabilities of Copilot (summarizing emails, drafting documents, analyzing data, etc.), it fails to link any specific feature to a tangible business benefit for the customer. There is no tailored insight or example based on the customer’s context, nor is there any hands-on demonstration or clear explanation of how Copilot would improve their workflow. This comes across as a generic pitch rather than a personalized value-add suggestion."
# }
# 6
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The provided recommendation lacks personalization and does not connect Copilot's specific features or capabilities to the customer's unique needs or workflow. Simply offering general documentation and a link doesn't qualify as a value-add. To meet validation criteria, the recommendation must explicitly explain how Copilot could solve a problem or enhance the customer's success, ideally through a tailored demonstration or insight that ties directly to their stated goals. Without these elements, it fails to provide value-add insight or context."
# }
# 7
#
# The customer's business operates in the real estate industry, Observing their need for streamlining processes and addressing numerous questions regarding email management, I identified merging emails as a key requirement. To support this, I guided the customer using Copilot AI, leveraging its capabilities to simplify email organization and improve workflow efficiency tailored to their business needs. {
#   "valid": false,
#   "reasoning": "While the recommendation mentions using Copilot AI to simplify email organization and improve workflow efficiency, it lacks a specific description of *which Copilot feature* was demonstrated or suggested, and exactly *how* it addresses the customer's real estate business needs or their workflow. Furthermore, there is no mention of a hands-on demonstration or an example that shows Copilot in action tailored to the customer's specific pain point of merging emails, which would communicate its value to the customer. The suggestion comes across as generic and doesn't fully align with the validation criteria of providing a personalized value-add or actionable steps."
# }
# 8
#
# Guided and Provided Documentation and link {
#   "valid": false,
#   "reasoning": "The recommendation lacks information about a specific Copilot feature, how it addresses the customer's needs or goals, and what extra value it can deliver in their context. Simply guiding and providing documentation or links does not constitute a proper value-add suggestion. To be valid, the ambassador would need to connect a Copilot feature to the customer’s workflow or pain point, explain how it helps resolve an issue or improve productivity, and either demonstrate it directly or provide a detailed, relevant walkthrough."
# }
# 9
#
# I recommended Microsoft 365 Copilot Chat and Bing Experience to Customer because it has the ability to drive productivity with accurate information using search feature
#  {
#   "valid": false,
#   "reasoning": "The recommendation lacks specific tailoring to the customer's stated needs or goals. While the search feature in Microsoft 365 Copilot and Bing Experience is mentioned, there is no direct connection to the customer's workflow, pain points, or desired outcomes. Additionally, the suggestion does not provide a clear example or hands-on demonstration of how this feature could improve the customer's productivity in their specific scenario. It comes across as a generic statement rather than a customer-centric value-add recommendation."
# }
# 111.74787402153015
#                                        test_name  sensitivity  precision  \
# 0                       loose_zero_shot_20_Test1     0.800000   0.888889
# 1                       loose_zero_shot_20_Test2     0.800000   0.800000
# 2  loose_zero_shot_20_no_negative_criteria_Test1     0.800000   1.000000
# 3  loose_zero_shot_20_no_negative_criteria_Test2     0.900000   0.818182
# 4                    loose_detailed_zero_shot_20     0.285714   1.000000
# 5                                       few shot     0.200000   1.000000
#
#    f1_score
# 0  0.842105
# 1  0.800000
# 2  0.888889
# 3  0.857143
# 4  0.444444
# 5  0.333333

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store, true_positives, true_negatives, false_positives, false_negatives):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                try:
                    llm_res = json.loads(llm_res)
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON: {e}, moving to next case")  # Log the error
                    next
                    
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
# print test results store

# %%
# Out:
# 4
# 5
