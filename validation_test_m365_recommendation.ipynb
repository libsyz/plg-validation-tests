# %% [markdown]
# # Product Insight Validation Using LLMs: M365 Recommendations🔍
#
# ## Overview
#
# This notebooks aims to evaluate different prompting strategies and prompts for validating M365 Recommendations using a Large Language Model (LLM). The goal is to have a sandbox where we can fine-tune prompts using the same cross validation sets.
#
# ## Objectives
#
# - **Compare Prompting Strategies:** Test multiple prompts and strategies to determine which yields the best classification results.
# - **Evaluate Performance:** Measure the effectiveness of each strategy using precision, recall, and F1 score.
# - **Cross-Validation Approach:** Utilize a labeled dataset containing:
#   - **True Positives (TP):** Correctly identified valid insights.
#   - **True Negatives (TN):** Correctly identified invalid insights.
#   - **False Positives (FP):** Incorrectly marked invalid insights as valid.
#   - **False Negatives (FN):** Incorrectly marked valid insights as invalid.
#
# ## Methodology
#
# 1. **Load Product Insights**
#    - Import CSV files containing business goals for validation.
#
# 2. **Apply LLM-Based Validation**
#    - Building blocks for using LLM to validate, and cleaning inputs
#
# 3. **Evaluate Performance**
#    - Compute precision, recall, and F1 score to assess classification accuracy.
#    - Compare the effectiveness of different strategies based on their performance metrics.
#    - 3.1 Zero Shot Prompting
#    - 3.2 Few Shot Prompting
#    - 3.3 Multi-pass w/ Few Shot prompting
#
# 4. **Optimize for Accuracy**
#    - Identify the best-performing prompt and strategy for product insight validation.
#
# ## Tech Stack
#
# - **LLM Provider:** Azure OpenAI
# - **Model:** ChatGPT 4.0
# - **Data Processing:** Python (pandas, numpy)
# - **Evaluation Metrics:** precision, recall, F1 score
#
# ## Expected Outcomes
#
# - A clear understanding of which prompting strategy yields the best results.
# - A methodology/workflow that can be iteratively improved and scaled for future product insight validation tasks.

# %%
# let's import the packages we will need for this project

import requests # for connecting with Azure Open AI
import json # for parsing responses
import csv # for data processing
import pandas as pd # for data analysis 

# let's also import the config we will need to interact with the Azure Open AI API

from config import config_endpoint, config_key

# %% [markdown]
# # 1 - Load M365 Value Add Insights
#
# Let's take a glimpse at the data we have. All these M365 Value Add Insights  have been validated by human validators during the month of April '25
#
# These datasets will act as makeshift cross-validation sets, that we can use to test the performance of different prompting strategies and approaches.
#
#
# We have two datasets:
#
# - A small set of 20 cases ( 10 valid, 10 invalids ) for quick experimentation
# - A bigger set of 200 cases ( 100 valid, 100 invalids ) for testing and measuring results

# %%
# We load all the data 

m365_recommendation_20 = pd.read_csv('./cases/m365_value_add_cv20.csv')
m365_recommendation_200 = pd.read_csv('./cases/m365_value_add_cv200.csv')

# Now let's print one of the datasets to see its shape

m365_recommendation_20[:5]
# Out:
#       ID       Case Number                                 UPN  \
# 0  29059  2504090030004589  gig_wfh_balpa@microsoftsupport.com
# 1  28991  2503210040015077  gig_wfh_ayato@microsoftsupport.com
# 2  29031        2,5031E+15  gig_wfh_ahade@microsoftsupport.com
# 3  29019       2,50407E+15  gig_whi_masin@office365support.com
# 4  28909  2504060040001378  gig_wfh_revil@microsoftsupport.com
#
#               Line Of Business  \
# 0    Business Advisor Reactive
# 1    Business Advisor Reactive
# 2  Trials Nurturing Migrations
# 3              Business Assist
# 4    Business Advisor Reactive
#
#                                                                                                                                                                                                                                                                                                                                                                     Product Led Growth Conversation  \
# 0                                                                                                                                          \nProvided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand.
# 1   \nConnect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name.
# 2                                                                                                                                                                                                                   \nI recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently.
# 3                                                           \nI suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations.
# 4                                                                                                                                                                                                       \nI suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn
#
#    PLG Conversation Validation  \
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
#
#                                                                             PLG Conversation Comment
# 0  Valid: Addressed features related to business goal and mentioned how it will impact the customer.
# 1                                                                                              valid
# 2                                                                                          Valid PLG
# 3  Valid: Addressed features related to business goal and mentioned how it will impact the customer.
# 4  Valid: Addressed features related to business goal and mentioned how it will impact the customer.

# %%
# Column explanation
data = [
    ["Product Led Growth Conversation", "Raw Product Led Growth Conversation captured by the ambassador as they figure in the tracker"],
    ["PLG Conversation Validation", "Validation done by a human validator - 0 is invalid, 1 is valid"],
    ["PLG Conversation Comment", "Comment/Explanation provided by a human validator"]
]
column_data = pd.DataFrame(data, columns=["Column Name", "Explanation"])

pd.set_option("display.max_colwidth", None) 
column_data
# Out:
#                        Column Name  \
# 0  Product Led Growth Conversation
# 1      PLG Conversation Validation
# 2         PLG Conversation Comment
#
#                                                                                     Explanation
# 0  Raw Product Led Growth Conversation captured by the ambassador as they figure in the tracker
# 1                               Validation done by a human validator - 0 is invalid, 1 is valid
# 2                                             Comment/Explanation provided by a human validator

# %% [markdown]
# ## 1.1 Defining Performance
#
# These 2 datasets have already been evaluated by human validators.
#
# This means we can use the previous labels to calculate Sensitivity, Recall and F1 for this dataset, which will give us performance metrics we can analyse and optimise. We will be looking at the following metrics.
#
# # Performance Metrics
#
# ## Sensitivity (Recall)
# Sensitivity, also known as **recall**, measures the ability to correctly identify positive cases:
#
# $$
# \text{Sensitivity} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Negatives (FN)}}
# $$
#
# ## Precision
# Precision measures how many of the predicted positive cases were actually correct:
#
# $$
# \text{Precision} = \frac{\text{True Positives (TP)}}{\text{True Positives (TP)} + \text{False Positives (FP)}}
# $$
#
# ## F1 Score
# F1 Score is the harmonic mean of precision and recall, balancing both metrics:
#
# $$
# F1 = 2 \times \frac{\text{Precision} \times \text{Sensitivity}}{\text{Precision} + \text{Sensitivity}}
# $$

# %% [markdown]
# We will create a dataframe where we will store the results of our tests as we run them.

# %%
test_results = pd.DataFrame([], columns=["test_name", "sensitivity", "precision", "f1_score"])


test_results
# Out:
# Empty DataFrame
# Columns: [test_name, sensitivity, precision, f1_score]
# Index: []

# %% [markdown]
# ## 2. Setting Up Logic for LLM Validation and Analysis
#
# ### 2.1 Validation
#
# Let's start this section by defining a function that calls Azure Open AI with a system prompt, and an input provided by the user.
#
# The system prompt will contain the criteria to validate an insight, and the user input will be the entry registered by our agents.

# %%
HEADERS = {
    "Content-Type": "application/json",
    "api-key": config_key
}

def send_prompt(system_prompt, user_prompt, max_tokens=200):
    """Send a prompt to Azure OpenAI and return the response."""
    url = config_endpoint
    data = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens
    }
    
    try:
        response = requests.post(url, headers=HEADERS, json=data)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# %% [markdown]
# Let's test it out with a very naive example to make sure it works

# %%
res = send_prompt(
    "You are system dedicated to validate product feedback. You will only declare as valid feedback that has to do usability issues, anything else will be invalid. Always return json with two fields: { valid: can only be true or false, reason: your reasoning as to why the insight is valid or invalid }",
    "I could not use the app at all, the menu was very convoluted and crowded with icons. Very hard to read"
)

print(res)
# Out:
# ```json
# {
#   "valid": true,
#   "reason": "The feedback highlights a usability issue related to the menu being convoluted and cluttered, making it difficult to navigate and use the app effectively."
# }
# ```

# %% [markdown]
# The model is giving us back a JSON wrapped in Markdown. Let's create a function to clean it

# %%
def clean_llm_response(res):
    return res.replace("json", "").replace(r'\n', '').replace(r"\'", "'").replace("`", "").strip()

# %%
print(clean_llm_response(res))
# Out:
# {
#   "valid": true,
#   "reason": "The feedback highlights a usability issue related to the menu being convoluted and cluttered, making it difficult to navigate and use the app effectively."
# }

# %% [markdown]
# Great! We now have the basic building block for testing different validation prompts.

# %% [markdown]
# ###  2.2 Analysis of prompt performance
#
# Now we need a function that allows us to do the following:
#
# - 1. Iterate through the rows of one of our datasets.
# - 2. For each of the rows in each of the datasets
#     - 1. Ask the LLM to validate the entry
#     - 2. Evaluate if the LLM did a good job or not
#           - LLM => Valid, Human => Valid, then *true positive*
#           - LLM => Invalid, Human => Invalid, then *true negative*
#           - LLM => Valid, Human => Invalid, then *false positive*
#           - LLM => Invalid, Human => Valid, then *false negative*
#     - 3. Store this information
# - 4. Calculate Sensitivity, Recall and F1 for this prompt
# - 5. Add the results to our log in the `test_results` variable we created before

# %%
import time 
import ipdb;

def analyse_test_prompt(test_name, prompt, results_store, dataset):
    '''
    Returns an array with
    - The performance of a prompt 
    - A comparison dataframe that helps compare AI and validator scores and comments.  

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt: system prompt passed to the LLM to validate product feedback
      - results_store: dataframe where we can store the results
    '''
    comparison_columns = [
        "Insight",
        "AI validation",
        "human validation",
        "AI comment",
        "human comment",
        "Result type"
    ]

    comparison_dataframe = pd.DataFrame(columns=comparison_columns)
    
    start_time = time.time()

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    row_counter = 0
    for index, row in dataset.iterrows():
        # avoid token limit if needed every 10 rows 
        print(row_counter)
        if row_counter >= 10:
            print(f"Rate limit is close, continuing in {60} seconds...")
            time.sleep(61)
            row_counter = 0
                
        llm_res = send_prompt(prompt, row['Product Led Growth Conversation'])
        llm_res = clean_llm_response(llm_res)
        row_counter += 1
        print(row['Product Led Growth Conversation'],llm_res)

        try:
            llm_res = json.loads(llm_res)
        except json.JSONDecodeError as e:
            print(f"[WARN] Failed to parse LLM response as JSON: {e}")
            continue

        human_validation = row['PLG Conversation Validation']
        if llm_res['valid'] == True and human_validation == 1:
            tp += 1
            result_type = "True Positive"
        elif llm_res['valid'] == False and human_validation == 0:
            tn += 1
            result_type = "True Negative"
        elif llm_res['valid'] == True and human_validation == 0:
            fp += 1
            result_type = "False Positive"
        elif llm_res['valid'] == False and human_validation == 1:
            fn += 1
            result_type = "False Negative"

        new_comparison_row = {
            "Insight": row['Product Led Growth Conversation'],
            "AI validation": llm_res['valid'],
            "human validation": human_validation,
            "AI comment": llm_res['reasoning'],
            "human comment": row['PLG Conversation Comment'],
            "Result type": result_type
        }

        comparison_dataframe.loc[len(comparison_dataframe)] = new_comparison_row


    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return [results_store, comparison_dataframe]

# %% [markdown]
# Ok, our building blocks of logic are now ready. Let's start with some prompting

# %% [markdown]
# ## 3. Testing Prompting Approaches
#
# In this section we will test the performance of several prompting approaches to see which one seems performs better. Let's go!
#
#
# ### 3.1 Loose Zero Shot Prompt
#
# Zero-shot prompting is a technique used with large language models (LLMs) where the model is asked to perform a task without being given any specific examples of how to do it. We're relying entirely on the model's pre-existing knowledge and understanding to generate a response.
#
# In the prompt below, we describe high level criteria that is frequently mentioned by human validators to mark insights as valid or invalid. These are drawn from analysing the reasons as to why validators mark insights as valid or invalid.

# %%
loose_zero_shot_prompt = '''
You are a classifier for Microsoft 365 Product Led Growth (PLG) recommendations. Your task is to decide if a given conversation qualifies as a valid PLG recommendation, using a balanced and moderately lenient approach. Use a silent chain-of-thought internally, but do not include it in your output.

Evaluation Guidelines:
- A conversation is considered VALID if it:
   • Contains either an explicit or implied reference to a Microsoft 365 product, service, or feature.
   • Mentions benefits or improvements (such as enhanced collaboration, improved efficiency, or better user experience) that address a customer need, even if described in general terms.
   • Shows a clear intention to promote a product-led growth recommendation, even if not every detail is exhaustively specified.

- A conversation is considered INVALID if:
   • It has no reference (explicit or implied) to any Microsoft 365 product or feature.
   • It is overly generic or off-topic, focusing only on technical support, troubleshooting, billing, licensing, or subjects unrelated to a product-led growth context.
   • It primarily mentions unrelated tools (such as Copilot) without a clear connection to the customer benefit or Microsoft 365 context.

Additional Instructions:
- If a conversation is borderline but includes an indication of benefits related to Microsoft 365, lean towards marking it as VALID.
- Your response must be solely a JSON object with exactly two keys:
    • "valid": a boolean value (true if valid, false if invalid).
    • "m365PFcomment": a concise, one-sentence justification that captures the main reason for your decision.
- Do not include any extra text or chain-of-thought details in your output.
- The answer must be entirely in English and follow the exact JSON format below:

{
  "valid": true,
  "m365PFcomment": "Your explanation here."
}

Evaluate the provided conversation accordingly and output only the JSON result.
'''

# %%
# Test Loose Zero Shot Prompt here 
test_results = analyse_test_prompt('loose_zero_shot_20', loose_zero_shot_prompt, test_results, m365_recommendation_20)
# Out:
# 0
#
# Provided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft Teams and highlights its benefits like scheduling, collaboration, chat, and file management to enhance productivity and branding, aligning with PLG principles."
# }
# 1
#
# Connect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name. {
#   "valid": true,
#   "m365PFcomment": "The recommendation explicitly connects the customer's business domain to Microsoft 365, addressing a customer need to build their brand and improve professional identity."
# }
# 2
#
# I recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft 365 features and highlights their benefits in improving scheduling efficiency."
# }
# 3
#
# I suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations. {
#   "valid": true,
#   "m365PFcomment": "The conversation highlights Azure Active Directory features that enhance security and operational efficiency, aligning with Microsoft 365 product benefits."
# }
# 4
#
# I suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly recommends using Microsoft 365's calendar sharing feature to address scheduling and task streamlining needs."
# }
# 5
#
# In our discussion, I suggested cx to utilizing Microsoft SharePoint which helps organizations manage,  share content, and collaborate on communication sites. This solution aims to enhance overall collaboration with your team and share information that engages abroad audience. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references SharePoint and highlights its benefits for collaboration and content sharing, addressing customer needs."
# }
# 6
#
# Based on the customer's needs, I suggested using MS PowerPoint to create branded templates. Here are the steps: start by opening PowerPoint and creating a new presentation. Access the Slide Master view to design a consistent layout for all slides, incorporating your brand's logo, colors, and fonts. Customize various slide layouts such as title slides, content slides, and section headers to match your brand's style. Once the design is complete, save the presentation as a PowerPoint template file. To use the template, open PowerPoint, select "New," and choose your template from the available options. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft PowerPoint and suggests a branded template creation workflow, highlighting a user benefit in alignment with M365 capabilities."
# }
# 7
#
# To use OneDrive's new features for better file sharing, device integration, and cloud storage. For example, they can store and access project files from anywhere for efficient collaboration. {
#   "valid": true,
#   "m365PFcomment": "The conversation highlights OneDrive's features and benefits related to file sharing, collaboration, and cloud storage, addressing customer needs and promoting product growth."
# }
# 8
#
# As customer is mainly focused with customer interactions, I have advised to seamlessly book and manage appointments, to use Bookings app. This will give her the option to sync it with Teams and Calendar and will have a more professional look {
#   "valid": true,
#   "m365PFcomment": "The recommendation explicitly mentions the Microsoft Bookings app as a solution, including its integration with Teams and Calendar to enhance customer interactions and professionalism."
# }
# 9
#
# I recommended Add external customers and guests to any meeting in Teams because the business is focused on structural engineering projects that require frequent collaboration with clients, contractors, and regulatory bodies. I choose Add external customers and guests to any meeting because it has a feature that allows the firm to include all relevant parties in virtual meetings, ensuring real-time communication and alignment on project goals and timelines. {
#   "valid": true,
#   "m365PFcomment": "The conversation mentions a Microsoft Teams feature and highlights its benefit of enabling real-time communication and collaboration for structural engineering projects."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# Advised to purchase from admin.microsoft.com > Sign in  Click Marketplace or Billing > Purchase Services > All Products  Look for Microsoft 365 Business Standard >click Details  Select a plan > Microsoft 365 Business Standard > Subscription length “Monthly” >Billing frequency “Monthly” > Buy. https://learn.microsoft.com/en-us/microsoft-365/commerce/try-or-buy-microsoft-365?view=o365-worldwide {
#   "valid": false,
#   "m365PFcomment": "The conversation is focused on instructions for purchasing and billing rather than promoting product-led growth benefits or features of Microsoft 365."
# }
# 1
#
# As per what it was talked to the customer during the meeting, they have needs for Learning Premium license, as they need to connect to another Learning provider they have purchased before (LMS) and they need to have their content within Viva Learning {
#   "valid": true,
#   "m365PFcomment": "The conversation references Microsoft Viva Learning and highlights its integration capabilities to meet the customer's needs, demonstrating a product-led growth opportunity."
# }
# 2
#
# Customer didn't use Shared Mailboxes. Created some shared mailboxes for their generic adresses instead of creating users with licenses.   {
#   "valid": false,
#   "m365PFcomment": "The conversation focuses on licensing and mailbox setup without referencing benefits or promoting a broader Microsoft 365 product-led growth context."
# }
# 3
#
# Given the customer's interest in using Outlook and uploading all his PST files to the Microsoft 365 business account, I recommended features to stay organized using email folders. This way, he can work with his old emails while staying focused on new incoming emails. {
#   "valid": true,
#   "m365PFcomment": "The conversation references Outlook and promotes organization features, addressing customer needs with Microsoft 365 functionality."
# }
# 4
#
# Recommend cx to use Teams to send payments request, since cx is using Teams already to share files and communicate with her clients, recommend Teams to take payments from her clients as well, with this she can enhance her clients experience since she will only need one app to work with clients and this will increase her productivity reducing the time spending in share her account number, instead she will only need to send a payment request via Teams.   {
#   "valid": true,
#   "m365PFcomment": "The recommendation emphasizes using Microsoft Teams to enhance client experience and productivity by consolidating communication, file sharing, and payment requests into one app."
# }
# 5
#
# I recommended LinkedIn to help the customer engage with clients and grow their new law firm. By joining local industry groups, attending relevant legal events, and sharing insights, they can strengthen connections and establish themselves as thought leaders. LinkedIn's visibility features make their firm more easily discoverable, helping them expand their reach and build lasting relationships with clients. This aligns with their goal of fostering engagement and trust in their new firm. {
#   "valid": false,
#   "m365PFcomment": "The conversation focuses on LinkedIn without any mention or implied reference to Microsoft 365 products or their benefits."
# }
# 6
#
# I recommended shared mailbox because the business is construction . I choose shared mailbox because it has a feature that can help the customer create a mailbox for free to communicate with external clients and improve the email management. {
#   "valid": true,
#   "m365PFcomment": "The recommendation of a shared mailbox highlights a specific Microsoft 365 feature focused on email management and improved communication in a business context."
# }
# 7
#
# Since this customer wanted to try using Copilot in the desktop applications of Excel and PowerPoint, I explained while confirming on the website that it can be made available by changing the license agreement to Microsoft 365 Business Standard or a higher tier. {
#   "valid": true,
#   "m365PFcomment": "The conversation references Excel and PowerPoint desktop applications in the context of upgrading to a Microsoft 365 license, promoting adoption of a higher-tier product."
# }
# 8
#
# To meet the client's needs, I recommended using Microsoft Teams and Outlook. This combination enhances communication across the entire company. It helps manage all internal and external communications easily and quickly, whether on mobile or computer. This integration will enable the client to better engage with customers and enhance overall communication.  {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft Teams and Outlook while outlining their benefits in improving company-wide communication and customer engagement."
# }
# 9
#
# To address the customer's need to migrate her mailboxes to Microsoft 365, I recommended purchasing a Business License. This will facilitate the migration from Google Workspace to Microsoft 365, allowing her to leverage enhanced collaboration tools, integrated services, advanced security, and scalability. {
#   "valid": true,
#   "m365PFcomment": "The recommendation explicitly relates to Microsoft 365 Business Licenses and highlights benefits such as enhanced collaboration and integrated services, addressing customer needs."
# }
# 92.83789587020874
# /var/folders/xv/5lp8ff8s7j55zh1lrpr9ddkw0000gn/T/ipykernel_46441/1549519253.py:62: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_store = pd.concat([results_store, new_results_row], ignore_index=True)

# %%
test_results
# Out:
#             test_name  sensitivity  precision  f1_score
# 0  loose_zero_shot_20          1.0   0.588235  0.740741

# %%
loose_zero_shot_no_negative_criteria = """
What You Do
You check Microsoft 365 feedback to see if it helps improve the product. Good feedback is clear, useful, and related to Microsoft 365 (not Copilot).

- A conversation is considered VALID if it:
   • Contains either an explicit or implied reference to a Microsoft 365 product, service, or feature.
   • Mentions benefits or improvements (such as enhanced collaboration, improved efficiency, or better user experience) that address a customer need, even if described in general terms.
   • Shows a clear intention to promote a product-led growth recommendation, even if not every detail is exhaustively specified.

Additional Instructions:
- If a conversation is borderline but includes an indication of benefits related to Microsoft 365, lean towards marking it as VALID.
- Your response must be solely a JSON object with exactly two keys:
    • "valid": a boolean value (true if valid, false if invalid).
    • "m365PFcomment": a concise, one-sentence justification that captures the main reason for your decision.
- Do not include any extra text or chain-of-thought details in your output.
- The answer must be entirely in English and follow the exact JSON format below:

{
  "valid": true,
  "m365PFcomment": "Your explanation here."
}

Evaluate the provided conversation accordingly and output only the JSON result.

"""

# %%
test_results = analyse_test_prompt('loose_zero_shot_20_no_negative_criteria', loose_zero_shot_no_negative_criteria, test_results, m365_recommendation_20)
# Out:
# 0
#
# Provided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand. {
#   "valid": true,
#   "m365PFcomment": "The feedback highlights multiple benefits of Microsoft Teams, including productivity enhancement and brand building."
# }
# 1
#
# Connect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name. {
#   "valid": true,
#   "m365PFcomment": "The feedback explicitly references Microsoft 365 and provides a clear user benefit of improved branding and customization for business emails and domains."
# }
# 2
#
# I recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently. {
#   "valid": true,
#   "m365PFcomment": "The feedback mentions Microsoft Bookings and shared calendar features, highlighting their benefits in streamlining scheduling and managing appointments efficiently."
# }
# 3
#
# I suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations. {
#   "valid": false,
#   "m365PFcomment": "Azure Active Directory is not a Microsoft 365 product, so the feedback is not related to Microsoft 365 improvement."
# }
# 4
#
# I suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn {
#   "valid": true,
#   "m365PFcomment": "The feedback explicitly references calendar sharing in Microsoft 365 and highlights its benefit for synchronizing schedules and streamlining tasks."
# }
# 5
#
# In our discussion, I suggested cx to utilizing Microsoft SharePoint which helps organizations manage,  share content, and collaborate on communication sites. This solution aims to enhance overall collaboration with your team and share information that engages abroad audience. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft SharePoint and highlights its benefits for content sharing and team collaboration."
# }
# 6
#
# Based on the customer's needs, I suggested using MS PowerPoint to create branded templates. Here are the steps: start by opening PowerPoint and creating a new presentation. Access the Slide Master view to design a consistent layout for all slides, incorporating your brand's logo, colors, and fonts. Customize various slide layouts such as title slides, content slides, and section headers to match your brand's style. Once the design is complete, save the presentation as a PowerPoint template file. To use the template, open PowerPoint, select "New," and choose your template from the available options. {
#   "valid": true,
#   "m365PFcomment": "The conversation explicitly references Microsoft PowerPoint and provides instructions that enhance branding and consistency, addressing customer needs effectively."
# }
# 7
#
# To use OneDrive's new features for better file sharing, device integration, and cloud storage. For example, they can store and access project files from anywhere for efficient collaboration. {
#   "valid": true,
#   "m365PFcomment": "The feedback references OneDrive's features and highlights benefits like file sharing, device integration, and efficient collaboration."
# }
# 8
#
# As customer is mainly focused with customer interactions, I have advised to seamlessly book and manage appointments, to use Bookings app. This will give her the option to sync it with Teams and Calendar and will have a more professional look {
#   "valid": true,
#   "m365PFcomment": "The conversation promotes using Microsoft Bookings to improve customer interactions and mentions integration with Teams and Calendar for enhanced functionality."
# }
# 9
#
# I recommended Add external customers and guests to any meeting in Teams because the business is focused on structural engineering projects that require frequent collaboration with clients, contractors, and regulatory bodies. I choose Add external customers and guests to any meeting because it has a feature that allows the firm to include all relevant parties in virtual meetings, ensuring real-time communication and alignment on project goals and timelines. {
#   "valid": true,
#   "m365PFcomment": "The feedback highlights a Teams feature that enhances collaboration and communication, addressing the needs of structural engineering projects."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# Advised to purchase from admin.microsoft.com > Sign in  Click Marketplace or Billing > Purchase Services > All Products  Look for Microsoft 365 Business Standard >click Details  Select a plan > Microsoft 365 Business Standard > Subscription length “Monthly” >Billing frequency “Monthly” > Buy. https://learn.microsoft.com/en-us/microsoft-365/commerce/try-or-buy-microsoft-365?view=o365-worldwide {
#   "valid": true,
#   "m365PFcomment": "The conversation references Microsoft 365 Business Standard with purchasing instructions, directly relating to a Microsoft 365 product and its features."
# }
# 1
#
# As per what it was talked to the customer during the meeting, they have needs for Learning Premium license, as they need to connect to another Learning provider they have purchased before (LMS) and they need to have their content within Viva Learning {
#   "valid": true,
#   "m365PFcomment": "The feedback relates to Viva Learning within Microsoft 365 and highlights the need for integration with an external LMS to enhance functionality."
# }
# 2
#
# Customer didn't use Shared Mailboxes. Created some shared mailboxes for their generic adresses instead of creating users with licenses.   {
#   "valid": true,
#   "m365PFcomment": "The feedback highlights the use of shared mailboxes, a Microsoft 365 feature, to optimize licensing and address generic email management needs."
# }
# 3
#
# Given the customer's interest in using Outlook and uploading all his PST files to the Microsoft 365 business account, I recommended features to stay organized using email folders. This way, he can work with his old emails while staying focused on new incoming emails. {
#   "valid": true,
#   "m365PFcomment": "The feedback references Outlook within Microsoft 365 and suggests organizational features to improve email management and efficiency."
# }
# 4
#
# Recommend cx to use Teams to send payments request, since cx is using Teams already to share files and communicate with her clients, recommend Teams to take payments from her clients as well, with this she can enhance her clients experience since she will only need one app to work with clients and this will increase her productivity reducing the time spending in share her account number, instead she will only need to send a payment request via Teams.   {
#   "valid": true,
#   "m365PFcomment": "The recommendation to use Teams for payment requests highlights improved productivity by consolidating communication, file sharing, and payments into one app, directly enhancing the client experience."
# }
# 5
#
# I recommended LinkedIn to help the customer engage with clients and grow their new law firm. By joining local industry groups, attending relevant legal events, and sharing insights, they can strengthen connections and establish themselves as thought leaders. LinkedIn's visibility features make their firm more easily discoverable, helping them expand their reach and build lasting relationships with clients. This aligns with their goal of fostering engagement and trust in their new firm. {
#   "valid": false,
#   "m365PFcomment": "The feedback focuses on LinkedIn's features rather than Microsoft 365 products or services."
# }
# 6
#
# I recommended shared mailbox because the business is construction . I choose shared mailbox because it has a feature that can help the customer create a mailbox for free to communicate with external clients and improve the email management. {
#   "valid": true,
#   "m365PFcomment": "The feedback highlights the benefit of using a Microsoft 365 feature, shared mailbox, to improve email management for a business need."
# }
# 7
#
# Since this customer wanted to try using Copilot in the desktop applications of Excel and PowerPoint, I explained while confirming on the website that it can be made available by changing the license agreement to Microsoft 365 Business Standard or a higher tier. {
#   "valid": false,
#   "m365PFcomment": "The feedback focuses on Copilot rather than addressing specific improvements or benefits related to Microsoft 365 core products or features."
# }
# 8
#
# To meet the client's needs, I recommended using Microsoft Teams and Outlook. This combination enhances communication across the entire company. It helps manage all internal and external communications easily and quickly, whether on mobile or computer. This integration will enable the client to better engage with customers and enhance overall communication.  {
#   "valid": true,
#   "m365PFcomment": "The feedback references Microsoft Teams and Outlook, highlighting benefits like improved communication and user engagement, which align with Microsoft 365 goals."
# }
# 9
#
# To address the customer's need to migrate her mailboxes to Microsoft 365, I recommended purchasing a Business License. This will facilitate the migration from Google Workspace to Microsoft 365, allowing her to leverage enhanced collaboration tools, integrated services, advanced security, and scalability. {
#   "valid": true,
#   "m365PFcomment": "The feedback explicitly references Microsoft 365 and highlights benefits such as enhanced collaboration, integrated services, advanced security, and scalability."
# }
# 90.1812059879303

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.714286  0.833333
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.562500  0.692308

# %% [markdown]
# ### 3.2 Detailed Zero Shot Prompt
#
# In the prompt below, we provide a detailed list of criteria based on the latest version of the insights framework available at GigPlus. This has a detailed set of tiered criteria.

# %%
detailed_zero_shot_prompt = '''
You are an AI assistant that validates **Microsoft 365 Value Add** recommendations within customer conversations. These recommendations should be **customer-centric** – meaning they tie Microsoft 365 features to the customer’s unique needs in a way that clearly adds value beyond the initial support issue.

**What is a “Value Add” recommendation?**  
It’s a personalized suggestion in a support conversation that goes beyond solving the original problem, showing the customer how an additional Microsoft 365 feature or product can help them achieve their business/personal goals or improve their experience. For example, after resolving a customer’s email issue, an ambassador might recommend using Microsoft Teams for better collaboration, explaining how it can streamline their team’s communication (that’s a value-add recommendation).

## Validation Criteria:

A **valid** M365 Value Add conversation will **clearly do all or most of the following**:

1. **Align with Customer’s Goals:** Explicitly link the Microsoft 365 feature/product to the customer’s specific business or personal objectives. (Does the conversation show how this feature helps achieve the customer’s stated goals or solve a stated pain point?)

2. **Provide Additional Value:** Go beyond the original issue to deliver extra benefit. The ambassador builds rapport and provides insights or best practices, not just a fix. (Is the ambassador focusing on the customer’s broader needs, and offering guidance that adds value to their business or workflow?)

3. **Hands-On Demonstration:** Where possible, involve a **show-and-tell**. The ambassador might walk the customer through the feature or offer a demo/trial so the customer can see the benefit in real-time. (Does the conversation include actually demonstrating the feature or describing a concrete example scenario? This isn’t always possible, but it strongly enhances the value if done.)

4. **Tailored to the Use Case:** The recommendation is customized to the customer’s situation. (Is it clear the ambassador considered the customer’s industry, use case, or environment? The advice should address **their** specific pain points, not just be a generic sales pitch.)

5. **Context and Impact:** The conversation provides context for how the feature fits into the customer’s workflow and how it will improve their experience or outcomes. (Does it say **why** this feature matters for them? e.g. “By using this, your team can save 2 hours a week on X,” or “This will make it easier for you to collaborate when working remotely.”)

If the conversation’s **value-add recommendation** strongly meets the above points, mark it **Valid**. If it’s missing one or more key elements (for example, it’s generic, not clearly tied to the customer’s goals, or lacks any context), mark it **Invalid**. 

> **Note:** Even when suggesting a Microsoft 365 feature as part of a broader campaign or agenda, it should still be framed in terms of the customer’s own use case and benefits. If a recommendation is given without linking to a customer need (e.g. just pushing a product feature with no context), it’s not truly customer-centric and should be considered **Invalid** because it doesn’t show the customer why that feature matters to them.

### Output Format:

- Your response must be solely a JSON object with exactly two keys:
    • "valid": a boolean value (true if valid, false if invalid).
    • "m365PFcomment": a concise, one-sentence justification that captures the main reason for your decision.
- Do not include any extra text or chain-of-thought details in your output.
- The answer must be entirely in English and follow the exact JSON format below:

{
  "valid": true,
  "m365PFcomment": "Your explanation here."
}


'''

# %%
test_results = analyse_test_prompt('detailed_zero_shot_20', detailed_zero_shot_prompt, test_results, m365_recommendation_20)
# Out:
# 0
#
# Provided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand. {
#   "valid": false,
#   "m365PFcomment": "The recommendation is too generic and does not directly align with the customer's specific goals or use case, lacking clear context for why Teams specifically matters to them."
# }
# 1
#
# Connect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name. {
#   "valid": true,
#   "m365PFcomment": "The recommendation clearly aligns with the customer's goal of building their brand by connecting their company domain to Microsoft 365, and hands-on assistance provided adds tangible value to their workflow and identity."
# }
# 2
#
# I recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks a clear connection to the customer’s specific goals or pain points and does not provide tailored context or impact."
# }
# 3
#
# I suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks explicit alignment with the customer's unique goals and does not provide context on how these features address a specific use case or pain point for the customer."
# }
# 4
#
# I suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn {
#   "valid": false,
#   "m365PFcomment": "The recommendation is too generic and does not tie the feature to a specific customer goal or pain point, lacking personalization or context for their workflow."
# }
# 5
#
# In our discussion, I suggested cx to utilizing Microsoft SharePoint which helps organizations manage,  share content, and collaborate on communication sites. This solution aims to enhance overall collaboration with your team and share information that engages abroad audience. {
#   "valid": false,
#   "m365PFcomment": "The recommendation is generic and does not explicitly tie SharePoint to the customer's specific goals or use case."
# }
# 6
#
# Based on the customer's needs, I suggested using MS PowerPoint to create branded templates. Here are the steps: start by opening PowerPoint and creating a new presentation. Access the Slide Master view to design a consistent layout for all slides, incorporating your brand's logo, colors, and fonts. Customize various slide layouts such as title slides, content slides, and section headers to match your brand's style. Once the design is complete, save the presentation as a PowerPoint template file. To use the template, open PowerPoint, select "New," and choose your template from the available options. {
#   "valid": false,
#   "m365PFcomment": "The recommendation provides steps for creating branded templates but lacks a clear alignment to the customer's specific goals or needs, making it generic rather than personalized."
# }
# 7
#
# To use OneDrive's new features for better file sharing, device integration, and cloud storage. For example, they can store and access project files from anywhere for efficient collaboration. {
#   "valid": false,
#   "m365PFcomment": "The recommendation is generic and does not tie OneDrive's features to a specific customer goal or use case to demonstrate added value."
# }
# 8
#
# As customer is mainly focused with customer interactions, I have advised to seamlessly book and manage appointments, to use Bookings app. This will give her the option to sync it with Teams and Calendar and will have a more professional look {
#   "valid": true,
#   "m365PFcomment": "The recommendation is tailored to the customer's focus on customer interactions, linking Microsoft Bookings to their goal of managing appointments professionally while integrating with Teams and Calendar for added value."
# }
# 9
#
# I recommended Add external customers and guests to any meeting in Teams because the business is focused on structural engineering projects that require frequent collaboration with clients, contractors, and regulatory bodies. I choose Add external customers and guests to any meeting because it has a feature that allows the firm to include all relevant parties in virtual meetings, ensuring real-time communication and alignment on project goals and timelines. {
#   "valid": true,
#   "m365PFcomment": "The recommendation is tailored to the customer’s structural engineering business, linking Teams' guest access feature to their need for collaboration with external stakeholders on projects, ensuring real-time communication and alignment."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# Advised to purchase from admin.microsoft.com > Sign in  Click Marketplace or Billing > Purchase Services > All Products  Look for Microsoft 365 Business Standard >click Details  Select a plan > Microsoft 365 Business Standard > Subscription length “Monthly” >Billing frequency “Monthly” > Buy. https://learn.microsoft.com/en-us/microsoft-365/commerce/try-or-buy-microsoft-365?view=o365-worldwide {
#   "valid": false,
#   "m365PFcomment": "The conversation provides transactional guidance but does not explicitly link Microsoft 365 Business Standard to the customer's goals or offer any customer-centric context or value beyond the purchasing instructions."
# }
# 1
#
# As per what it was talked to the customer during the meeting, they have needs for Learning Premium license, as they need to connect to another Learning provider they have purchased before (LMS) and they need to have their content within Viva Learning {
#   "valid": true,
#   "m365PFcomment": "The recommendation for the Viva Learning Premium license is valid as it aligns with the customer’s need to integrate their LMS and manage their content within Viva Learning, addressing their specific requirement for seamless learning management."
# }
# 2
#
# Customer didn't use Shared Mailboxes. Created some shared mailboxes for their generic adresses instead of creating users with licenses.   {
#   "valid": false,
#   "m365PFcomment": "The conversation does not explicitly tie shared mailboxes to the customer's goals or provide additional value beyond resolving the initial issue."
# }
# 3
#
# Given the customer's interest in using Outlook and uploading all his PST files to the Microsoft 365 business account, I recommended features to stay organized using email folders. This way, he can work with his old emails while staying focused on new incoming emails. {
#   "valid": false,
#   "m365PFcomment": "The recommendation focuses on email organization but does not go beyond the immediate issue or explicitly link to a broader value tied to the customer's goals."
# }
# 4
#
# Recommend cx to use Teams to send payments request, since cx is using Teams already to share files and communicate with her clients, recommend Teams to take payments from her clients as well, with this she can enhance her clients experience since she will only need one app to work with clients and this will increase her productivity reducing the time spending in share her account number, instead she will only need to send a payment request via Teams.   {
#   "valid": true,
#   "m365PFcomment": "The recommendation is valid as it aligns with the customer's existing use of Teams for client communication and clearly demonstrates how adding payment requests can enhance client experience and productivity by streamlining workflows within a single app."
# }
# 5
#
# I recommended LinkedIn to help the customer engage with clients and grow their new law firm. By joining local industry groups, attending relevant legal events, and sharing insights, they can strengthen connections and establish themselves as thought leaders. LinkedIn's visibility features make their firm more easily discoverable, helping them expand their reach and build lasting relationships with clients. This aligns with their goal of fostering engagement and trust in their new firm. {
#   "valid": false,
#   "m365PFcomment": "The recommendation focuses on LinkedIn, which is not part of Microsoft 365, and does not demonstrate value from a Microsoft 365 feature aligned with the customer's goals."
# }
# 6
#
# I recommended shared mailbox because the business is construction . I choose shared mailbox because it has a feature that can help the customer create a mailbox for free to communicate with external clients and improve the email management. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks specific alignment with the customer's goals and does not provide tailored context or demonstrate how the shared mailbox adds value to their construction business workflow."
# }
# 7
#
# Since this customer wanted to try using Copilot in the desktop applications of Excel and PowerPoint, I explained while confirming on the website that it can be made available by changing the license agreement to Microsoft 365 Business Standard or a higher tier. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks a clear alignment with the customer’s goals and does not provide context or tailored benefits for why upgrading the license would matter to them specifically."
# }
# 8
#
# To meet the client's needs, I recommended using Microsoft Teams and Outlook. This combination enhances communication across the entire company. It helps manage all internal and external communications easily and quickly, whether on mobile or computer. This integration will enable the client to better engage with customers and enhance overall communication.  {
#   "valid": true,
#   "m365PFcomment": "The recommendation aligns with the customer's goal of enhancing communication and provides value by showing how Teams and Outlook integration can streamline both internal and external engagement across devices."
# }
# 9
#
# To address the customer's need to migrate her mailboxes to Microsoft 365, I recommended purchasing a Business License. This will facilitate the migration from Google Workspace to Microsoft 365, allowing her to leverage enhanced collaboration tools, integrated services, advanced security, and scalability. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks detail on how the specific features of the Business License directly align with the customer's migration needs or broader goals beyond the initial issue."
# }
# 90.73076510429382

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.588235  0.740741
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.529412  0.666667
# 2                    detailed_zero_shot_20          0.3   0.500000  0.375000

# %% [markdown]
# ### 3.1 Few-Shot Prompt
#
# Few-shot prompting is a technique in prompt engineering that aims to augment LLMs by providing a small number of examples within the prompt itself. This allows the model to learn and adapt to a specific task without requiring extensive fine-tuning.
#
# In the prompt below, we will provide a few positive and negative examples for each of the categories, and see its impact on performance.

# %%
few_shot_prompt = '''

You are an AI assistant that validates **Microsoft 365 Value Add** recommendations within customer conversations. These recommendations should be **customer-centric** – meaning they tie Microsoft 365 features to the customer’s unique needs in a way that clearly adds value beyond the initial support issue.

**What is a “Value Add” recommendation?**  
It’s a personalized suggestion in a support conversation that goes beyond solving the original problem, showing the customer how an additional Microsoft 365 feature or product can help them achieve their business/personal goals or improve their experience. For example, after resolving a customer’s email issue, an ambassador might recommend using Microsoft Teams for better collaboration, explaining how it can streamline their team’s communication (that’s a value-add recommendation).

## Validation Criteria:

A **valid** M365 Value Add conversation will **clearly do all or most of the following**:

1. **Align with Customer’s Goals:** Explicitly link the Microsoft 365 feature/product to the customer’s specific business or personal objectives. (Does the conversation show how this feature helps achieve the customer’s stated goals or solve a stated pain point?)

2. **Provide Additional Value:** Go beyond the original issue to deliver extra benefit. The ambassador builds rapport and provides insights or best practices, not just a fix. (Is the ambassador focusing on the customer’s broader needs, and offering guidance that adds value to their business or workflow?)

3. **Hands-On Demonstration:** Where possible, involve a **show-and-tell**. The ambassador might walk the customer through the feature or offer a demo/trial so the customer can see the benefit in real-time. (Does the conversation include actually demonstrating the feature or describing a concrete example scenario? This isn’t always possible, but it strongly enhances the value if done.)

4. **Tailored to the Use Case:** The recommendation is customized to the customer’s situation. (Is it clear the ambassador considered the customer’s industry, use case, or environment? The advice should address **their** specific pain points, not just be a generic sales pitch.)

5. **Context and Impact:** The conversation provides context for how the feature fits into the customer’s workflow and how it will improve their experience or outcomes. (Does it say **why** this feature matters for them? e.g. “By using this, your team can save 2 hours a week on X,” or “This will make it easier for you to collaborate when working remotely.”)

If the conversation’s **value-add recommendation** strongly meets the above points, mark it **Valid**. If it’s missing one or more key elements (for example, it’s generic, not clearly tied to the customer’s goals, or lacks any context), mark it **Invalid**. 

> **Note:** Even when suggesting a Microsoft 365 feature as part of a broader campaign or agenda, it should still be framed in terms of the customer’s own use case and benefits. If a recommendation is given without linking to a customer need (e.g. just pushing a product feature with no context), it’s not truly customer-centric and should be considered **Invalid** from a Product-Led Growth (PLG) perspective, because it doesn’t show the customer why that feature matters to them.

### Output Format:

Provide the answer as a JSON object with two keys:  
- **"m365VAvalid"** – `"Valid"` if the conversation meets the criteria, or `"Invalid"` if it does not.  
- **"m365VAcomment"** – A brief explanation. If **invalid**, explain what is missing or how it fell short, and **challenge the ambassador** to improve it (e.g. “what could be added or done better?”). Include a note on why, from a PLG standpoint, the current conversation isn’t as useful (perhaps it’s too generic, not aligned to needs, etc.). If **valid**, give a short reason citing how it met the key criteria.

### Examples:

- **Example 1 – Valid:**  
  *Conversation Summary:* The customer’s goal was to improve team collaboration. After helping with their SharePoint site issue, the ambassador suggests using Microsoft Teams for project discussions. The ambassador says, “Since your goal is faster team collaboration, let’s set up a Teams channel for your project. For example, you mentioned keeping track of file versions – in Teams, files are automatically shared and version-controlled. I can walk you through setting up your first channel now.” They then guide the customer through creating a Teams channel and share best practices.  
  *Why It’s Valid:* This clearly **aligns with the customer’s goal** (faster team collaboration). It **adds value** beyond the original SharePoint issue by introducing Teams. The ambassador gives a **hands-on walkthrough** (setting up a channel in real-time). It’s **tailored** to the customer’s project context (mentioning file version concerns the customer had). And it provides **context** on how Teams will fit into their workflow (centralizing files and discussions for the project).  


### Output Format:

- Your response must be solely a JSON object with exactly two keys:
    • "valid": a boolean value (true if valid, false if invalid).
    • "m365PFcomment": a concise, one-sentence justification that captures the main reason for your decision.
- Do not include any extra text or chain-of-thought details in your output.
- The answer must be entirely in English and follow the exact JSON format below:

{
  "valid": true,
  "m365PFcomment": "Your explanation here."
}

These are the business goals and microsoft 365 value add conversations captured. if the following is empty, mark the entry as invalid and explain why:
 Business Goals or Needs
 M365 Value Add 
'''

# %%
test_results = analyse_test_prompt('few_shot_20', few_shot_prompt, test_results, m365_recommendation_20 )

print(test_results)
# Out:
# 0
#
# Provided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand. {
#   "valid": false,
#   "m365PFcomment": "The recommendation is too generic and lacks alignment with specific customer goals or pain points. It needs to clearly tie the features of Teams to the customer's unique objectives or workflow to effectively demonstrate value."
# }
# 1
#
# Connect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name. {
#   "valid": true,
#   "m365PFcomment": "The recommendation aligns with the customer's goal of building their brand by connecting their business domain to Microsoft 365, which strengthens brand identity. The ambassador provided hands-on guidance, tailored the action to the customer's specific branding need, and added value by enhancing their professional image through the use of a custom domain."
# }
# 2
#
# I recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks specific alignment to the business goals or needs and does not demonstrate how Bookings or shared calendars directly address the company's objectives. To improve, clarify the company's exact scheduling pain points (e.g., managing client appointments, syncing team schedules) and explain how these features offer tailored solutions."
# }
# 3
#
# I suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations. {
#   "valid": false,
#   "m365PFcomment": "The suggestion is generic and does not clearly align with the customer's specific goals or needs. There is no indication of the customer's unique pain points or how these advanced features address them. To improve, the ambassador should explicitly connect the recommendation to a stated customer goal or need and tailor the advice to their situation for a more customer-centric approach."
# }
# 4
#
# I suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn {
#   "valid": false,
#   "m365PFcomment": "The entry lacks specific business goals or needs from the customer, making the recommendation generic and not clearly aligned with the customer’s situation or objectives."
# }
# 5
#
# In our discussion, I suggested cx to utilizing Microsoft SharePoint which helps organizations manage,  share content, and collaborate on communication sites. This solution aims to enhance overall collaboration with your team and share information that engages abroad audience. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks specific alignment with the customer’s unique goals or stated needs, instead providing a generic introduction to SharePoint's features. Challenge: What specific pain point or objective of the customer could SharePoint address for them, and how could you tailor your suggestion to their workflow or industry use case?"
# }
# 6
#
# Based on the customer's needs, I suggested using MS PowerPoint to create branded templates. Here are the steps: start by opening PowerPoint and creating a new presentation. Access the Slide Master view to design a consistent layout for all slides, incorporating your brand's logo, colors, and fonts. Customize various slide layouts such as title slides, content slides, and section headers to match your brand's style. Once the design is complete, save the presentation as a PowerPoint template file. To use the template, open PowerPoint, select "New," and choose your template from the available options. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks clear alignment with specific customer goals or needs as none are explicitly outlined, and it does not detail how branded templates improve their workflow or address a particular pain point. Adding customer-centric context and linking it to their objectives would make this suggestion more valuable."
# }
# 7
#
# To use OneDrive's new features for better file sharing, device integration, and cloud storage. For example, they can store and access project files from anywhere for efficient collaboration. {
#   "valid": false,
#   "m365PFcomment": "The conversation lacks specific customer goals or needs to align the recommendation with, making it generic and not tailored to their unique situation; more context about the customer's workflow or pain points is needed to demonstrate the impact of OneDrive's features."
# }
# 8
#
# As customer is mainly focused with customer interactions, I have advised to seamlessly book and manage appointments, to use Bookings app. This will give her the option to sync it with Teams and Calendar and will have a more professional look {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks specific alignment to the customer's stated goals and pain points, and does not clearly explain how Bookings will improve their workflow or outcomes. It needs more tailored context, such as why Bookings is relevant for their customer interactions or how the Teams/Calendar integration specifically benefits them."
# }
# 9
#
# I recommended Add external customers and guests to any meeting in Teams because the business is focused on structural engineering projects that require frequent collaboration with clients, contractors, and regulatory bodies. I choose Add external customers and guests to any meeting because it has a feature that allows the firm to include all relevant parties in virtual meetings, ensuring real-time communication and alignment on project goals and timelines. {
#   "valid": true,
#   "m365PFcomment": "The recommendation is valid as it aligns with the firm's goal of frequent collaboration with external stakeholders, adds value by enabling seamless virtual meetings with all parties, and is tailored specifically to their structural engineering project needs."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# Advised to purchase from admin.microsoft.com > Sign in  Click Marketplace or Billing > Purchase Services > All Products  Look for Microsoft 365 Business Standard >click Details  Select a plan > Microsoft 365 Business Standard > Subscription length “Monthly” >Billing frequency “Monthly” > Buy. https://learn.microsoft.com/en-us/microsoft-365/commerce/try-or-buy-microsoft-365?view=o365-worldwide {
#   "valid": false,
#   "m365PFcomment": "The entry lacks any information about the customer's business goals or needs and does not provide a value-add recommendation tailored to their context. It's purely instructional for purchasing a Microsoft 365 subscription without showing how it aligns with their challenges or objectives."
# }
# 1
#
# As per what it was talked to the customer during the meeting, they have needs for Learning Premium license, as they need to connect to another Learning provider they have purchased before (LMS) and they need to have their content within Viva Learning {
#   "valid": false,
#   "m365PFcomment": "The entry lacks detail about how the Viva Learning Premium license specifically addresses the customer's need to connect their LMS or integrate content – it does not show alignment to their goals or provide tailored value-add context."
# }
# 2
#
# Customer didn't use Shared Mailboxes. Created some shared mailboxes for their generic adresses instead of creating users with licenses.   {
#   "valid": false,
#   "m365PFcomment": "The conversation lacks any alignment to the customer's broader business goals or pain points, and no additional value or context was provided about how shared mailboxes enhance workflows or solve customer-specific challenges."
# }
# 3
#
# Given the customer's interest in using Outlook and uploading all his PST files to the Microsoft 365 business account, I recommended features to stay organized using email folders. This way, he can work with his old emails while staying focused on new incoming emails. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks a tailored connection to the customer’s broader needs or goals beyond organizing emails. To improve, the ambassador could have aligned this suggestion to a specific workflow or demonstrated additional Outlook features (e.g., automated email rules or search functionality) to show practical value that supports the customer's unique use case."
# }
# 4
#
# Recommend cx to use Teams to send payments request, since cx is using Teams already to share files and communicate with her clients, recommend Teams to take payments from her clients as well, with this she can enhance her clients experience since she will only need one app to work with clients and this will increase her productivity reducing the time spending in share her account number, instead she will only need to send a payment request via Teams.   {
#   "valid": true,
#   "m365PFcomment": "The recommendation aligns with the customer’s goal of enhancing client experience and increasing productivity by consolidating tasks into one app (Teams). It provides additional value by introducing the payment request feature, tailored to her existing use of Teams for client communication and file sharing."
# }
# 5
#
# I recommended LinkedIn to help the customer engage with clients and grow their new law firm. By joining local industry groups, attending relevant legal events, and sharing insights, they can strengthen connections and establish themselves as thought leaders. LinkedIn's visibility features make their firm more easily discoverable, helping them expand their reach and build lasting relationships with clients. This aligns with their goal of fostering engagement and trust in their new firm. {
#   "valid": false,
#   "m365PFcomment": "The recommendation focused entirely on LinkedIn, which is not a Microsoft 365 product. There is no alignment with Microsoft 365 features or tools such as Teams, SharePoint, or Outlook that could add specific value to the customer's business goal. A proper M365 Value Add recommendation should incorporate features directly within Microsoft 365 tailored to the customer's goals."
# }
# 6
#
# I recommended shared mailbox because the business is construction . I choose shared mailbox because it has a feature that can help the customer create a mailbox for free to communicate with external clients and improve the email management. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks clear alignment with the customer's specific business goals or needs beyond mentioning the construction industry. While the shared mailbox feature is useful, the explanation does not tailor the suggestion to the customer's unique requirements (e.g., how it specifically helps their construction business). Additionally, no context or demonstration is provided to show the feature's impact. To improve, the ambassador could provide a concrete example of how a shared mailbox could enhance communication or email management in a construction project setting."
# }
# 7
#
# Since this customer wanted to try using Copilot in the desktop applications of Excel and PowerPoint, I explained while confirming on the website that it can be made available by changing the license agreement to Microsoft 365 Business Standard or a higher tier. {
#   "valid": false,
#   "m365VAcomment": "The recommendation is too generic and not tied to the customer's specific goals or needs beyond their initial interest in trying Copilot. It lacks a tailored explanation of how Copilot in Excel and PowerPoint could address their workflows, pain points, or business objectives. To make this valid, the ambassador should relate the benefits of Copilot to the customer's specific use cases (like improving data analysis or automating repetitive tasks in presentations), and possibly provide hands-on examples of the value Copilot would bring."
# }
# 8
#
# To meet the client's needs, I recommended using Microsoft Teams and Outlook. This combination enhances communication across the entire company. It helps manage all internal and external communications easily and quickly, whether on mobile or computer. This integration will enable the client to better engage with customers and enhance overall communication.  {
#   "valid": false,
#   "m365VAcomment": "The recommendation lacks specific alignment to the customer's stated goals or pain points and provides no clear context, tailored use case, or example of how Teams and Outlook integration will improve communication or engagement workflows. To make this valid, elaborate on the customer's exact challenges, and provide a tailored demonstration or detailed explanation of how Teams or Outlook would work in their specific scenario."
# }
# 9
#
# To address the customer's need to migrate her mailboxes to Microsoft 365, I recommended purchasing a Business License. This will facilitate the migration from Google Workspace to Microsoft 365, allowing her to leverage enhanced collaboration tools, integrated services, advanced security, and scalability. {
#   "valid": false,
#   "m365PFcomment": "The recommendation lacks clear alignment with the customer's broader business needs beyond mailbox migration. It's generic and does not tailor the value of Microsoft 365 tools (like collaboration or security) to the customer's specific goals or pain points. To improve, explicitly tie these features to her unique situation—why does she need enhanced collaboration or scalability specifically? And how will this transform her workflow or business outcomes?"
# }
# 97.653067111969
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.588235  0.740741
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.529412  0.666667
# 2                    detailed_zero_shot_20          0.3   0.500000  0.375000
# 3                              few_shot_20          0.2   0.666667  0.307692

# %%
test_results
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.588235  0.740741
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.529412  0.666667
# 2                    detailed_zero_shot_20          0.3   0.500000  0.375000
# 3                              few_shot_20          0.2   0.666667  0.307692

# %%
few_shot_prompt_v2_w_cot = '''

You are an AI assistant that validates **Microsoft 365 Value Add** recommendations within customer conversations.

Your task is to assess whether a conversation contains a **Valid** value-add recommendation based on the following five criteria. Think through them step by step before deciding:

1. **Provide Value** – Does the suggestion help the customer achieve a goal or improve their experience?
2. **Feature Recommendation** – Is there a recommendation of a feature or product in the Microsoft 365 ecosystem?
3. **Tailored to the Use Case** – Is the recommendation clearly customized to the customer’s context, industry, or situation?
4. **Context and Impact** – Does the ambassador explain *why* the recommendation matters or how it will improve the customer’s outcomes?


Use the following **Chain of Thought** approach:
- Think through each of the five criteria above.
- If **most or all are met**, mark the entry as **Valid**.
- If any **key element is missing** or the recommendation feels generic, mark it as **Invalid**.

> **Notes:** 
- A generic, unspecific entry without alignment to customer goals is **Invalid**, even if it technically mentions a Microsoft 365 feature. True value-add means showing the **why it matters** for that customer.
- An entry that recommends Copilot is automatically invalid

--- 

### Valid Examples 

- I recommended Onedrive for business because it gives the user the platform to save her personal files with the use of 1 TB of cloud storage. I chose Onedrive for business because it can be synced to different device so she can access it anywhere. I demo on how to use Onedrive for business.

- I recommended using Designer. This tool will help him generate creative photos based on descriptions, making his ideas clearer. Additionally, Designer will save time, enhance creativity with various design options, improve clarity with visually appealing ideas, and increase social media engagement with high-quality images."

- I recommended that the customer use Power BI, which can consolidate their Excel reports into interactive dashboards, giving them real-time insights into customer trends."

- I recommended that the customer use Microsoft Purview to protect sensitive legal contracts, allowing them to encrypt and restrict access to confidential files." 

### Invalid Examples

- Explained about Win 11 and ran a check, processor doesn't meet. User said - .I will have to go out and buy a new computer

- I recommended the customer to use Excel to organize data

- I recommended the customer to use Teams to collaborate better

- I recommended the customer to use Microsoft security tools

---

### Evaluation Instructions:

Evaluate the conversation using the chain of thought steps above.


### Response

- Your response must be solely a JSON object with exactly two keys:
    • "valid": a boolean value (true if valid, false if invalid).
    • "reasoning": a concise, one-sentence justification that captures the main reason for your decision.
- Do not include any extra text or chain-of-thought details in your output.
- The answer must be entirely in English and follow the exact JSON format below:

{
  "valid": true,
  "reasoning": "Your explanation here."
}

'''

# %%
analysis = analyse_test_prompt('few_shot_prompt_v2_w_cot', few_shot_prompt_v2_w_cot, test_results, m365_recommendation_20)

test_results = analysis[0]
comparison_dataframe = analysis[1]
# Out:
# 0
#
# Provided an overview of the Teams application, highlighting how it enables to schedule appointments, collaborate on meetings, chat, and manage files all in one place. This solution can significantly enhance productivity and help build your brand. {
#   "valid": false,
#   "reasoning": "The recommendation lacks specific tailoring to the customer's context and does not explain why Teams is uniquely relevant for their goals or industry."
# }
# 1
#
# Connect business domain to Microsoft 365 - Based on customer's need to build their brand, I recommended connecting their company domain to Microsoft 365 and I assisted customer to purchase business domain from Squarespace. Guided customer to set up the domain on Microsoft 365 and changed the customer's username and primary email from onmicrosoft.com to their company domain name. {
#   "valid": true,
#   "reasoning": "The recommendation directly helps the customer build their brand, involves connecting a business domain to Microsoft 365, is tailored to their need, and includes guidance on setup to improve their professional branding experience."
# }
# 2
#
# I recommended using Bookings and shared calendar features to streamline scheduling for the company. These tools can help manage appointments and daily schedules efficiently. {
#   "valid": false,
#   "reasoning": "The recommendation mentions Microsoft 365 features but lacks tailored context and specific impact related to the customer's situation or industry needs."
# }
# 3
#
# I suggested customer to purchase a premium Azure Active Directory license to enhance their security and identity management. It provides advanced features like Conditional Access, seamless single sign-on, detailed reporting, and improved device management, helping them safeguard their organization and streamline operations. {
#   "valid": true,
#   "reasoning": "The recommendation is tailored to the customer's need for security and identity management, highlights specific features of Azure Active Directory, and explains the value in safeguarding and streamlining operations."
# }
# 4
#
# I suggested utilizing calendar sharing within Microsoft 365 to synchronize schedules and streamline daily tasks. Share calendar and contacts in Microsoft 365 - Outlook | Microsoft Learn {
#   "valid": false,
#   "reasoning": "The recommendation is generic and lacks specific context or explanation of why calendar sharing is beneficial for the customer’s unique situation."
# }
# 5
#
# In our discussion, I suggested cx to utilizing Microsoft SharePoint which helps organizations manage,  share content, and collaborate on communication sites. This solution aims to enhance overall collaboration with your team and share information that engages abroad audience. {
#   "valid": false,
#   "reasoning": "The recommendation mentions SharePoint but lacks tailored context to the customer's specific goals, industry, or situation, making it generic and unspecific."
# }
# 6
#
# Based on the customer's needs, I suggested using MS PowerPoint to create branded templates. Here are the steps: start by opening PowerPoint and creating a new presentation. Access the Slide Master view to design a consistent layout for all slides, incorporating your brand's logo, colors, and fonts. Customize various slide layouts such as title slides, content slides, and section headers to match your brand's style. Once the design is complete, save the presentation as a PowerPoint template file. To use the template, open PowerPoint, select "New," and choose your template from the available options. {
#   "valid": false,
#   "reasoning": "The recommendation is detailed and provides step-by-step guidance, but it lacks explicit tailoring to the customer's context or why branded templates would help address their specific needs."
# }
# 7
#
# To use OneDrive's new features for better file sharing, device integration, and cloud storage. For example, they can store and access project files from anywhere for efficient collaboration. {
#   "valid": false,
#   "reasoning": "The recommendation mentions OneDrive's features but lacks tailoring to the specific customer's context and does not sufficiently explain the impact or why it matters for their outcomes."
# }
# 8
#
# As customer is mainly focused with customer interactions, I have advised to seamlessly book and manage appointments, to use Bookings app. This will give her the option to sync it with Teams and Calendar and will have a more professional look {
#   "valid": true,
#   "reasoning": "The recommendation meets all criteria as it suggests using Bookings to improve appointment management, integrates with Teams and Calendar for better customer interactions, and explains the professional impact tailored to the customer's focus on customer interactions."
# }
# 9
#
# I recommended Add external customers and guests to any meeting in Teams because the business is focused on structural engineering projects that require frequent collaboration with clients, contractors, and regulatory bodies. I choose Add external customers and guests to any meeting because it has a feature that allows the firm to include all relevant parties in virtual meetings, ensuring real-time communication and alignment on project goals and timelines. {
#   "valid": true,
#   "reasoning": "The recommendation provides value by addressing the customer's need for external collaboration, suggests a specific Microsoft 365 feature, and explains how it improves project communication and alignment in their structural engineering context."
# }
# 10
# Rate limit is close, continuing in 60 seconds...
#
# Advised to purchase from admin.microsoft.com > Sign in  Click Marketplace or Billing > Purchase Services > All Products  Look for Microsoft 365 Business Standard >click Details  Select a plan > Microsoft 365 Business Standard > Subscription length “Monthly” >Billing frequency “Monthly” > Buy. https://learn.microsoft.com/en-us/microsoft-365/commerce/try-or-buy-microsoft-365?view=o365-worldwide {
#   "valid": false,
#   "reasoning": "The recommendation focuses solely on purchasing instructions without tying it to any specific customer goal, use case, or feature benefit, which fails to meet the value-add criteria."
# }
# 1
#
# As per what it was talked to the customer during the meeting, they have needs for Learning Premium license, as they need to connect to another Learning provider they have purchased before (LMS) and they need to have their content within Viva Learning {
#   "valid": true,
#   "reasoning": "The recommendation of Viva Learning with a Learning Premium license is tailored to the customer's need to integrate their existing LMS and consolidate content, providing clear value and addressing their specific use case."
# }
# 2
#
# Customer didn't use Shared Mailboxes. Created some shared mailboxes for their generic adresses instead of creating users with licenses.   {
#   "valid": false,
#   "reasoning": "The recommendation focuses on creating shared mailboxes but does not explain why this change benefits the customer or how it aligns with their goals, making it generic and not sufficiently value-add."
# }
# 3
#
# Given the customer's interest in using Outlook and uploading all his PST files to the Microsoft 365 business account, I recommended features to stay organized using email folders. This way, he can work with his old emails while staying focused on new incoming emails. {
#   "valid": false,
#   "reasoning": "The recommendation lacks customization to the customer's specific goals or industry and does not clearly explain the importance or impact of using email folders."
# }
# 4
#
# Recommend cx to use Teams to send payments request, since cx is using Teams already to share files and communicate with her clients, recommend Teams to take payments from her clients as well, with this she can enhance her clients experience since she will only need one app to work with clients and this will increase her productivity reducing the time spending in share her account number, instead she will only need to send a payment request via Teams.   {
#   "valid": true,
#   "reasoning": "The recommendation effectively adds value by streamlining the customer's workflow through Teams, is tailored to their use case by integrating payment requests into an app they already use, and explains the impact on productivity and client experience."
# }
# 5
#
# I recommended LinkedIn to help the customer engage with clients and grow their new law firm. By joining local industry groups, attending relevant legal events, and sharing insights, they can strengthen connections and establish themselves as thought leaders. LinkedIn's visibility features make their firm more easily discoverable, helping them expand their reach and build lasting relationships with clients. This aligns with their goal of fostering engagement and trust in their new firm. {
#   "valid": false,
#   "reasoning": "LinkedIn is not part of the Microsoft 365 ecosystem, so the recommendation does not meet the necessary feature-related criteria to be valid."
# }
# 6
#
# I recommended shared mailbox because the business is construction . I choose shared mailbox because it has a feature that can help the customer create a mailbox for free to communicate with external clients and improve the email management. {
#   "valid": true,
#   "reasoning": "The recommendation of shared mailboxes is tailored to the customer's construction business context and explains its value in improving communication and email management with external clients."
# }
# 7
#
# Since this customer wanted to try using Copilot in the desktop applications of Excel and PowerPoint, I explained while confirming on the website that it can be made available by changing the license agreement to Microsoft 365 Business Standard or a higher tier. {
#   "valid": false,
#   "reasoning": "Recommendations involving Copilot are automatically invalid per the criteria provided."
# }
# 8
#
# To meet the client's needs, I recommended using Microsoft Teams and Outlook. This combination enhances communication across the entire company. It helps manage all internal and external communications easily and quickly, whether on mobile or computer. This integration will enable the client to better engage with customers and enhance overall communication.  {
#   "valid": false,
#   "reasoning": "The recommendation lacks sufficient tailoring to the customer's specific context and does not explain why Microsoft Teams and Outlook are the best solutions for their particular needs."
# }
# 9
#
# To address the customer's need to migrate her mailboxes to Microsoft 365, I recommended purchasing a Business License. This will facilitate the migration from Google Workspace to Microsoft 365, allowing her to leverage enhanced collaboration tools, integrated services, advanced security, and scalability. {
#   "valid": true,
#   "reasoning": "The recommendation directly addresses the customer's need to migrate mailboxes by suggesting a Business License, explaining the benefits of enhanced collaboration, integrated services, security, and scalability tailored to the migration context."
# }
# 90.74756193161011
# /var/folders/xv/5lp8ff8s7j55zh1lrpr9ddkw0000gn/T/ipykernel_98685/2732883171.py:92: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_store = pd.concat([results_store, new_results_row], ignore_index=True)

# %%
from IPython.display import FileLink, display

display(test_results)

display(comparison_dataframe)

comparison_dataframe.to_csv("comparison_dataframe_copilot_insights.csv", index=False)

FileLink("comparison_dataframe_copilot_insights.csv")
# Out:
#                                  test_name  sensitivity  precision  f1_score
# 0                       loose_zero_shot_20          1.0   0.588235  0.740741
# 1  loose_zero_shot_20_no_negative_criteria          0.9   0.529412  0.666667
# 2                    detailed_zero_shot_20          0.3   0.500000  0.375000
# 3                              few_shot_20          0.2   0.666667  0.307692
# 4                       few_shot_v2_cot_20          0.6   0.600000  0.600000

# %%
def analyse_multipass_prompt(test_name, prompt_product, prompt_deployment, results_store, true_positives, true_negatives, false_positives, false_negatives):
    '''
    Evaluates the performance of a prompt 

    Args:
      - test_name: name of the test, can be used as an identifier
      - prompt_product: system prompt passed to the LLM to validate product feedback
      - prompt_deployment: system prompt passed to the LLM to validate deployment blockers
      - results_store: dataframe where we can store the results
    '''
    start_time = time.time()
    
    dataframes = [
        [true_positives, True], # first value contains the data, the second what we would like the model to return for every row
        [true_negatives, False], # for instance, the llm should evaluate all true positives as valid to have 100% accuracy 
        [false_positives, False],
        [false_negatives, True]
    ]

    # counters to evaluate metrics
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    llm_call_counter = 0
    for dataframe in dataframes:
        data, expectation = dataframe
        
        for index, row in data.iterrows():
            # avoid token limit if needed every 10 rows 
            print(llm_call_counter)
            if llm_call_counter >= 10:
                print(f"Rate limit is close, continuing in {60} seconds...")
                time.sleep(61)
                llm_call_counter = 0
                
                
            llm_res = send_prompt(prompt_product, row['Feedback'])
            llm_res = clean_llm_response(llm_res)
            llm_call_counter += 1

            print(llm_res)
            # if we did not get a TP or an TN, we use the other prompt
            llm_res = json.loads(llm_res)
            if expectation != llm_res['valid']:
                llm_res = send_prompt(prompt_deployment, row['Feedback'])
                llm_res = clean_llm_response(llm_res)
                try:
                    llm_res = json.loads(llm_res)
                except json.JSONDecodeError as e:
                    print(f"Error parsing JSON: {e}, moving to next case")  # Log the error
                    next
                    
                llm_call_counter += 1
                
            
            
            print(llm_res)
            
            if expectation == True and llm_res['valid'] == True:
                tp += 1
            elif expectation == True and llm_res['valid'] == False:
                fn += 1
            elif expectation == False and llm_res['valid'] == True:
                fp += 1
            elif expectation == False and llm_res['valid'] == False:
                tn += 1

    sensitivity = tp / ( tp + fn )
    precision = tp / ( tp + fp )
    f_1 = 2 * ( precision * sensitivity ) / ( precision + sensitivity )
    new_results_row = pd.DataFrame({"test_name": [test_name] ,"sensitivity": [sensitivity] , "precision": [precision] , "f1_score": [f_1]  })

    test_values = results_store["test_name"].values
    
    if test_name in test_values:
        index_to_replace = results_store[results_store["test_name"] == test_name].index[0]
        results_store.loc[index_to_replace] = new_results_row.iloc[0] 
    else:
        results_store = pd.concat([results_store, new_results_row], ignore_index=True)
    end_time = time.time()
    print(end_time - start_time) 
    return results_store

# %% [markdown]
# Now, let's break down the prompts with their examples

# %% [markdown]
# ## Results
#
# Here we have the performance of several prompting strategies on our makeshift cross validation sample.

# %%
# print test results store
